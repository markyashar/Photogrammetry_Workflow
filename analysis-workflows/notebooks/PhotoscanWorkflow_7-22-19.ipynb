# %% [markdown]
# # Overview
# This Jupyter notebook helps you create a 3D model using the Photoscan photogrammetry software, leveraging the computing power of a high-performance compute cluster. It assumes that your photographs are stored in a folder on [Box](http://berkeley.box.com), and the results of each step are saved back to Box.
#
# If you want to manually edit the results of any step in the process, you can sync or download the project file and photos from Box to any computer with Photoscan installed (version 1.5 or higher), make your edits, and move the changes back to Box before proceeding with the next computationally-intensive processing step.
#
# This Jupyter notebook should be considered as a test to develop recommendations and findings and not necessarily specific solutions that should be implemented as is. Rather, users should modify this notebook for further testing and experimentation and as is suitable to their specific needs, workflows, and frameworks.

# %% [markdown]
# ### Software versions
# This notebook has been tested using:
# * python 3.5 kernel
# * boxsdk (2.0.0a2)
# * Photoscan 1.3 or later (for example, Photoscan 1.4.3)

# %% [markdown]
# ## Workflow at a glance
# The photogrammetry workflow laid out here involves the following steps. Each listed step has its own section in the notebook.
# 1. **Overview**: the overview that you're currently reading
# 2. **Source Files**: defines where various source files are located.
# 3. **Box Setup**: connects this notebook to Box so it can access the photos you've stored there.
# 4. **Project Setup**: pulls your images into the computing cluster, and creates a new Photoscan (psx) file if needed.
# 5. **Align Photos**: arranges the photos you've taken, relative to one another. 1% to 8% of the expected processing time.
# 6. **Build Dense Cloud**: creates the a point cloud from the photographs. The most computationally-intensive step, which can take 50%-96% of the total model generation time, depending on your settings. This step is run using GPU nodes on the cluster, which improve performance.
# 7. **Build Mesh**: connecting the point cloud together to build a mesh takes around 30% of the processing time on lower quality settings, or as little as 2% on higher quality settings.
# 8. **Build Texture**: building the texture takes between 8% (medium quality) and 1% (ultra high quality) of the processing time.
# 9. **Export Results**: exporting the photomosaic and OBJ files, and moving them to Box.

# %% [markdown]
# # Project Setup
# This step connects the notebook to Box. Before you get started, make sure you have a folder in Box for your project. That folder should have a folder inside it called "images" that has all the photos you want to use for your 3D model. This workflow will also create a new folder, "files", that contains the project files-- you don't have to set that up in advance.
#
# **MYashar: As far as things stand now, none of the code in this Jupyter notebook actually tries to access or download files from an "images" subfolder on Box or creates a new "files" folder containing the project files on Box. Rather,
# image files are retrieved from the (top) Box project folder. In my case, I created a folder in Box called'myBoxFolderName' and put all of the *.jpg image files there, and this is where the code accesses and retrieves the image files on Box.**
#
# Click the code box below, and then click the "run cell" button in the toolbar. This will run the code and move to the next box.
#
# After you run the next code box, your user name on the cluster should appear at the bottom.

# %%
# !conda create -n py3.5 python=3.5
# !conda install -n py3.5 pip
# !module load python/3.5
# !conda list
# !source activate py3.5
! module load qt
# !pip install --user boxsdk==2.0.0a2
# !python --version
# !which python
# !which python3
# !python3 --version
# !which jupyter
# !jupyter nbextension enable --py widgetsnbextension
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
# !pip install boxsdk==2.0.0a2
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, VBox, interact_manual
import ipywidgets as widgets
from IPython.display import display
usernamearray = %sx whoami
username = usernamearray[0]
print('user name: ', username)

def f(x):
    return x

def pn(projectName):
    return projectName

def smf(mountFolder):
    return mountFolder

def bpf(boxFolder):
    return boxFolder

def scp(containerPath):
    return containerPath

def idd(imageDataPath):
    return imageDataPath

def hfp(homePath):
    return homePath

def rf(runPath):
    return runPath


#Define widgets and defaults
pntextbox=widgets.Text(value='projectname', description='Project Name')
# singularitymountfoldertextbox =widgets.Text(value='/scratch/', description='Singularity Mount Folder') 
singularitymountfoldertextbox =widgets.Text(value='/scratch/')
# singularitymountfoldertextbox =widgets.Text(value='/global/scratch/myashar/projectname/', description='Singularity Mount Folder') 
boxfoldertextbox =widgets.Text(value='myBoxFolderName', description='Box Project Folder') 
# Need to make sure that a folder called 'myBoxFolderName' is created in Box and the images are in that folder.
# scptextbox=widgets.Text(value='/global/scratch/groups/dh/photoscan13.img', description='Path to Container')
# scptextbox=widgets.Text(value='/global/scratch/groups/dh/photoscan_1_4_3.simg', description='Path to Container')
scptextbox=widgets.Text(value='/global/scratch/myashar/container/photoscan_1_4_3.simg', description='Path to Container')
iddtextbox=widgets.Text(value='/global/scratch/' + username + '/imageData', description='Image Data')
hometextbox=widgets.Text(value='/global/home/users/' + username + '/', description='Home Folder')
runtextbox=widgets.Text(value='/global/scratch/' + username + '/'  + pntextbox.value + '/', description='Run Folder')
# Out:
# /bin/sh: module: command not found
# /bin/sh: module: command not found
# Python 2.7.5
# /bin/python
# /global/software/sl-7.x86_64/modules/langs/python/3.5/bin/python3
# Python 3.5.4 :: Anaconda custom (64-bit)
# /global/software/sl-7.x86_64/modules/langs/python/3.5/bin/jupyter
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
# /global/home/users/myashar/.conda/envs/py3.5/bin/python
# 3.5.5 |Anaconda, Inc.| (default, May 13 2018, 21:12:35)
# [GCC 7.2.0]
# sys.version_info(major=3, minor=5, micro=5, releaselevel='final', serial=0)
# user name:  myashar

# %%
import sys
print(sys.executable)
print(sys.path)
print(sys.version)
# !conda list
# Out:
# /global/home/users/myashar/.conda/envs/py3.5/bin/python
# ['', '/global/home/users/myashar/.conda/envs/py3.5/lib/python35.zip', '/global/home/users/myashar/.conda/envs/py3.5/lib/python3.5', '/global/home/users/myashar/.conda/envs/py3.5/lib/python3.5/plat-linux', '/global/home/users/myashar/.conda/envs/py3.5/lib/python3.5/lib-dynload', '/global/home/users/myashar/.local/lib/python3.5/site-packages', '/global/home/users/myashar/.conda/envs/py3.5/lib/python3.5/site-packages', '/global/home/users/myashar/.local/lib/python3.5/site-packages/IPython/extensions', '/global/home/users/myashar/.ipython']
# 3.5.5 |Anaconda, Inc.| (default, May 13 2018, 21:12:35)
# [GCC 7.2.0]

# %% [markdown]
# ## Project set up
# After you run the code box below, a set of text boxes will appear. Click in the text boxes and enter the following values:
# * **Project name**: The name of your project. Will be used for some of the folders on the cluster that will be created to process the project.
# * **Mount folder**: Where your photos will be uploaded for processing. Unless you know specifically this should be somewhere else, leave this as /scratch/
# * **Box project folder**: The name of the folder on Box that has your photos in it.
# * **Path to container**: The location on the cluster where the container with the Photoscan software is installed. At Berkeley, this container is at /global/scratch/groups/dh/photoscan13.img --> photoscan_1_4_3.simg
# * **Home folder**: Your home folder on the cluster.
# * **Run folder**: The folder where the various job scripts to trigger the processing steps will be stored. Default: /global/scratch/your-user-name/your-project-name/
#
# **MYashar: Make sure that the latest version of the Chrome or Safari browser is being used; otherwise the widget
# text boxes and the sliders (later on), may not work.**
#
# When you're done filling in the text boxes, hit the "run cell" button again.

# %%
# Enter the projectname
interact(pn, projectName=pntextbox)

# Enter the Singularity Mount Folder here, this is defined inside the Singularity container:
interact(smf, mountFolder=singularitymountfoldertextbox)

# Enter the Box Project folder
interact(bpf, boxFolder=boxfoldertextbox)

# MYashar -- maybe add a part here: Enter the Box Image folder
# interact(bif, boxImageFolder=boximagetextbox)   (?)

# Enter the path to the Singularity container hosting Photoscan
interact(scp, containerPath=scptextbox)

# Enter the path to where the iamge files from Box should be placed on the scrath drive
# interact(idd, imageDataPath=iddtextbox)

# Enter the path to the user home folder where Box oauth information is stored in files.
interact(hfp, homePath=hometextbox)

# Enter the path to the run home folder where processing will be conducted and intermediate files created.
interact(rf, runPath=runtextbox)
# Out:
# interactive(children=(Text(value='projectname', description='Project Name'), Output()), _dom_classes=('widget-…
# interactive(children=(Text(value='/scratch/', description='mountFolder'), Output()), _dom_classes=('widget-int…
# interactive(children=(Text(value='myBoxFolderName', description='Box Project Folder'), Output()), _dom_classes…
# interactive(children=(Text(value='/global/scratch/myashar/container/photoscan_1_4_3.simg', description='Path t…
# interactive(children=(Text(value='/global/home/users/myashar/', description='Home Folder'), Output()), _dom_cl…
# interactive(children=(Text(value='/global/scratch/myashar/projectname/', description='Run Folder'), Output()),…
# <function __main__.rf(runPath)>

# %% [markdown]
# ## Creating project folders
# The code box below creates the project folders (e.g. run folder, scratch images directory) on the cluster if they don't already exist.

# %%
projectname =  pntextbox.value

# Defines all paths and filenames
import os

usernamearray = %sx whoami
username = usernamearray[0]
print('user name: ', username)
print('project name: ', projectname)

runFolder = os.path.join(runtextbox.value, '')
homeFolder =  os.path.join(hometextbox.value, '')
print('run folder: ', runFolder)
print('home folder: ', homeFolder)

# Creates the run folder if it does not exist
if ( not os.path.isdir(runFolder)):
    print('run folder does not exist, creating.')
    os.mkdir(runFolder)

singularitymountfolder = os.path.join(singularitymountfoldertextbox.value, '')
print('Singulariy Mount Folder: ', singularitymountfolder)
boxProjectFolder = boxfoldertextbox.value
projectFile = '/' + projectname + '.psx'
datazipFile = '/' + projectname + '.files.zip'
dataFolder = '/' + projectname + '.files'
print('Box Project Folder: ',boxProjectFolder)
print('project file: ', projectFile)
print('data zip file: ', datazipFile)
print('data folder: ', dataFolder)

projectfileid = ''
jpgFile = projectname + '.jpg'
print('jpg file: ',jpgFile)

scratchImageDataDirectory = runFolder + 'images/'
print('Scratch Image Data Directory: ', scratchImageDataDirectory)
# Creates the image folder if it does not exist
if ( not os.path.isdir(scratchImageDataDirectory)):
    print('images folder does not exist, creating.')
    os.mkdir(scratchImageDataDirectory)

slurmScript = runFolder + 'slurmscript.sh'
execScript = runFolder + 'execscript.sh'
scratchExecScript = singularitymountfolder + 'execscript.sh'
commandScript = runFolder + 'commandscript.sh'
print('Slurm script: ', slurmScript)
print('exec script: ', execScript)
print('scratch exec script: ', scratchExecScript)
print('command script: ', commandScript)


singularityContainerPath = scptextbox.value
#/global/scratch/groups/dh/photoscan_1_4_3.simg
print("Singularity Container Path", singularityContainerPath)
# Out:
# user name:  myashar
# project name:  projectname
# run folder:  /global/scratch/myashar/projectname/
# home folder:  /global/home/users/myashar/
# Singulariy Mount Folder:  /scratch/
# Box Project Folder:  myBoxFolderName
# project file:  /projectname.psx
# data zip file:  /projectname.files.zip
# data folder:  /projectname.files
# jpg file:  projectname.jpg
# Scratch Image Data Directory:  /global/scratch/myashar/projectname/images/
# Slurm script:  /global/scratch/myashar/projectname/slurmscript.sh
# exec script:  /global/scratch/myashar/projectname/execscript.sh
# scratch exec script:  /scratch/execscript.sh
# command script:  /global/scratch/myashar/projectname/commandscript.sh
# Singularity Container Path /global/scratch/myashar/container/photoscan_1_4_3.simg

# %% [markdown]
# ## Box setup
#
# To connect Box with this notebook, you need to go through some one-time configuration steps the first time you use this notebook for any project. Please run the *BoxAuthenticationBootstrap.ipynb* notebook, then return to the code cells below to finish setup. After you finish the last cell, you should see *Folder name:  All Files*.
#
# If you run this notebook again for another project, you won't have to run *BoxAuthenticationBootstrap.ipynb* again, and can just continue to the code below.

# %%
# Might want to make sure that *.cfg files that were created in earlier runs are copied to home directory.
# !cp *.cfg ~/

# %%
def store_tokens(access_token, refresh_token):
    
    """Callback for storing refresh tokens. (For now we ignore access tokens)."""
    with open(homeFolder,'apptoken.cfg', 'w') as f:
     f.write(refresh_token.strip())

# %%
# !pwd
# Out:
# /global/scratch/myashar/projectname/images

# %%
import os

CLIENT_ID = None
CLIENT_SECRET = None
REDIRECT_URI = None

# CLIENT_ID = '7fv9qix8gzo77vhwidetl426az41xneg'
# CLIENT_SECRET = 'agzSPeOv8Zmmj8iupLJFcl9lWolaBqtY'
# REDIRECT_URI ='https://berkeley.app.box.com/folder/0'

# Read app info from text file
# with open(homeFolder +'app.cfg', 'r') as app_cfg:
with open('app.cfg', 'r') as app_cfg:    
    CLIENT_ID = app_cfg.readline()
    CLIENT_SECRET = app_cfg.readline()
    REDIRECT_URI = app_cfg.readline()

# %%
REFRESH_TOKEN = None

# Read app info from text file
# with open(homeFolder + 'apptoken.cfg', 'r') as apptoken_cfg:
with open('apptoken.cfg', 'r') as apptoken_cfg:
    REFRESH_TOKEN = apptoken_cfg.readline()

# %%
from boxsdk import OAuth2
from boxsdk import Client
# !pwd
# Do OAuth2 authorization.
oauth = OAuth2(
    client_id=CLIENT_ID.strip(),
    client_secret=CLIENT_SECRET.strip(),
    refresh_token=REFRESH_TOKEN.strip(),
    store_tokens=store_tokens
)

client = Client(oauth)

root_folder = client.folder(folder_id='0').get()
print ("Folder name: ", root_folder['name'] )

items = client.folder(folder_id='0').get_items(limit=100, offset=0)
print ("items: ", items )
# !pwd
# Out:
# /global/scratch/myashar/projectname/images
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-0e31b0846ade> in <module>()
#      12 client = Client(oauth)
#      13
# ---> 14 root_folder = client.folder(folder_id='0').get()
#      15 print ("Folder name: ", root_folder['name'] )
#      16
#
# ~/.conda/envs/py3.5/lib/python3.5/site-packages/boxsdk/util/api_call_decorator.py in call(*args, **kwargs)
#      54                 instance = instance.clone(instance._session.with_default_network_request_kwargs(extra_network_parameters))
#      55                 # pylint: enable=protected-access
# ---> 56             response = self._func_that_makes_an_api_call(instance, *args, **kwargs)
#      57             return response
#      58         return call
#
# ~/.conda/envs/py3.5/lib/python3.5/site-packages/boxsdk/object/item.py in get(self, fields, etag)
#     131         # pylint:disable=arguments-differ
#     132         headers = {'If-None-Match': etag} if etag is not None else None
# --> 133         return super(Item, self).get(fields=fields, headers=headers)
#     134
#     135     @api_call
#
# ~/.conda/envs/py3.5/lib/python3.5/site-packages/boxsdk/util/api_call_decorator.py in call(*args, **kwargs)
#      54                 instance = instance.clone(instance._session.with_default_network_request_kwargs(extra_network_parameters))
#      55                 # pylint: enable=protected-access
# ---> 56             response = self._func_that_makes_an_api_call(instance, *args, **kwargs)
#      57             return response
#      58         return call
#
# ~/.conda/envs/py3.5/lib/python3.5/site-packages/boxsdk/object/base_object.py in get(self, fields, headers)
#      83         url = self.get_url()
#      84         params = {'fields': ','.join(fields)} if fields else None
# ---> 85         box_response = self._session.get(url, params=params, headers=headers)
#      86         return self.__class__(self._session, self._object_id, box_response.json())
#      87
#
# ~/.conda/envs/py3.5/lib/python3.5/site-packages/boxsdk/session/box_session.py in get(self, url, **kwargs)
#     443             `unicode`
#     444         """
# --> 445         response = self._prepare_and_send_request('GET', url, **kwargs)
#     446         return BoxResponse(response)
#     447
#
# ~/.conda/envs/py3.5/lib/python3.5/site-packages/boxsdk/session/box_session.py in _prepare_and_send_request(self, method, url, headers, auto_session_renewal, expect_json_response, attempt_number, **kwargs)
#     347             attempt_number,
#     348             file_stream_positions=file_stream_positions,
# --> 349             **kwargs
#     350         )
#     351
#
# ~/.conda/envs/py3.5/lib/python3.5/site-packages/boxsdk/session/box_session.py in _make_request(self, method, url, headers, auto_session_renewal, expect_json_response, attempt_number, **kwargs)
#     428             expect_json_response=expect_json_response,
#     429             file_stream_positions=file_stream_positions,
# --> 430             **kwargs
#     431         )
#     432
#
# ~/.conda/envs/py3.5/lib/python3.5/site-packages/boxsdk/session/box_session.py in _retry_request_if_necessary(self, network_response, attempt_number, *args, **kwargs)
#     229         """
#     230         if network_response.status_code == 401 and kwargs['auto_session_renewal']:
# --> 231             self._renew_session(network_response.access_token_used)
#     232             kwargs['auto_session_renewal'] = False
#     233             return self._make_request(*args, **kwargs)
#
# ~/.conda/envs/py3.5/lib/python3.5/site-packages/boxsdk/session/box_session.py in _renew_session(self, access_token_used)
#     194             `unicode`
#     195         """
# --> 196         self._oauth.refresh(access_token_used)
#     197
#     198     @staticmethod
#
# ~/.conda/envs/py3.5/lib/python3.5/site-packages/boxsdk/auth/oauth2.py in refresh(self, access_token_to_refresh)
#     207                 # be refreshed, or if we don't currently have any active access
#     208                 # token, we make the request to refresh the token.
# --> 209                 return self._refresh(access_token_to_refresh)
#     210             else:
#     211                 # If the active access token (self._access_token) is not the same as the token needs to be refreshed,
#
# ~/.conda/envs/py3.5/lib/python3.5/site-packages/boxsdk/auth/oauth2.py in _refresh(self, access_token)
#     162             data['box_device_name'] = self._box_device_name
#     163
# --> 164         return self.send_token_request(data, access_token)
#     165
#     166     def _get_tokens(self):
#
# ~/.conda/envs/py3.5/lib/python3.5/site-packages/boxsdk/auth/oauth2.py in send_token_request(self, data, access_token, expect_refresh_token)
#     296         except (ValueError, KeyError):
#     297             raise BoxOAuthException(network_response.status_code, network_response.content, url, 'POST')
# --> 298         self._store_tokens(access_token, refresh_token)
#     299         return self._access_token, self._refresh_token
#     300
#
# ~/.conda/envs/py3.5/lib/python3.5/site-packages/boxsdk/auth/oauth2.py in _store_tokens(self, access_token, refresh_token)
#     231         self._update_current_tokens(access_token, refresh_token)
#     232         if self._store_tokens_callback is not None:
# --> 233             self._store_tokens_callback(access_token, refresh_token)
#     234
#     235     def _get_and_update_current_tokens(self):
#
# <ipython-input-28-5aa2facb4e1a> in store_tokens(access_token, refresh_token)
#       2
#       3     """Callback for storing refresh tokens. (For now we ignore access tokens)."""
# ----> 4     with open(homeFolder,'apptoken.cfg', 'w') as f:
#       5      f.write(refresh_token.strip())
#
# TypeError: an integer is required (got type str)

# %% [markdown]
# ## Finding folder on box
# The function below looks for your project folder on Box.

# %%
def find_folder_id(folder_name):
    print ('find_folder_id folder_name: ', folder_name)
    folderlist = client.search(query=folder_name, result_type='folder', limit=100, offset=0)
    
    print ('find_folder_id folderlist: ', folderlist)
    
    if len(folderlist) == 0:
        print('folder not found: ', folder_name)
        return 0
    else:
        for fldr in folderlist:
            if fldr['name'] == folder_name :
                return fldr['id']
            
        return 0

# %% [markdown]
# ## Create command scripts template
# This code writes out a execute file that includes the license install as the first step each time to enable any HPC node. This is a temporary workaround until release 1.3 is installed on Savio and a license server is configured.

# %%
# script for singularity to run
import os, stat
os.system('export XAUTHORITY=/global/home/users/myashar/.Xauthority')
os.system('export DISPLAY=:0')
# !module load qt
os.system("module load qt")

# execScriptTemplate = 'export RLM_LICENSE=5053@lmgr0.brc.berkeley.edu \n\
# /opt/photoscan-pro/photoscan.sh -r  /scratch/commandscript.sh \n'

# I needed to run the following for my particular case instead:
execScriptTemplate = 'export RLM_LICENSE=5053@lmgr0.brc.berkeley.edu \n\
/usr/local/photoscan-pro/photoscan.sh -r  /scratch/commandscript.sh \n'

with open(execScript, 'w') as f:
    f.write(execScriptTemplate)
    
os.chmod(execScript,  0o755)
# Out:
# /bin/sh: module: command not found

# %%
# batch script
os.system('export XAUTHORITY=/global/home/users/myashar/.Xauthority')
os.system('export DISPLAY=:0')
# !module load qt
os.system("module load qt")
os.environ['QT_QPA_PLATFORM']='offscreen'

batchtemplate = '#!/bin/bash  \n\
# Job name: \n\
#SBATCH --job-name=' + projectname + '\n\
# \n\
# Account: \n\
#SBATCH --account=ac_scsguest \n\
# \n\
# Partition: \n\
#SBATCH --partition=savio \n\
# \n\
# Wall clock limit: \n\
#SBATCH --time={} \n\
# \n\
## Command(s) to run: \n\
## source activate py3.5 \n\

singularity -d exec -B ' + runFolder + ':' + singularitymountfolder + '  ' + singularityContainerPath + '  ' + scratchExecScript + ' -platform offscreen \n' 
# !export DISPLAY=':0.0'
# !export XAUTHORITY=/global/home/users/myashar/.Xauthority
# !export DISPLAY=:0

# %% [markdown]
# ## Function for updating project file
# Multiple times in the workflow, the project folder needs to be updated on Box in order to enable making edits through the desktop version of Photoscan. This sets up a utility function that pushes the project
# file into the working directory on Savio. It assumes that the project folder will only contain one project file and one zipped archive.

# %%
import os
import shutil

def update_project_file_in_box():

    newFolderId = find_folder_id(boxProjectFolder)
    print ("Box folder id: ", newFolderId  )
    
    # create a zipped archive of the data folder
    shutil.make_archive(runFolder + dataFolder, 'zip', runFolder + dataFolder)
    
    projectfilelist = client.search(query=projectFile, result_type='file', limit=10, 
                                offset=0, ancestor_folders=[client.folder(folder_id=newFolderId)],
                                file_extensions=['psx'] )  
    
    print ("project file list: ", projectfilelist  )
    
    # if project file is not yet in folder, upload both the project file and the data zip file
    if len(projectfilelist) == 0 or len(projectfilelist) > 1: 
        print ("project file not found. " )
        upload_folder = client.folder(folder_id=newFolderId).get()
        print("upload_folder: ", upload_folder)
        projectpsx = upload_folder.upload(runFolder + projectFile)  
        print ("project file id: ", projectpsx['id'] )
        projectzip = upload_folder.upload(runFolder + datazipFile)
        print("projectzip: ", projectzip)
        print ("data zip file id: ", projectzip['id'] )
        return
    else:
        datazipfilelist = client.search(query=datazipFile, result_type='file', limit=10, 
                                offset=0, ancestor_folders=[client.folder(folder_id=newFolderId)])
                                #file_extensions=['zip'] )  
        print ("datazip file list: ", datazipfilelist  )
        
        projectfileid = projectfilelist[0]['id']
        print ("project file id: ", projectfileid )
        datazipfileid = datazipfilelist[0]['id']
        print ("data zip file list: ", datazipfileid  )
    
        update_file = client.file(file_id=projectfileid).get()
        update_zip_file = client.file(file_id=datazipfileid).get()

        # upload a new version of the project file
        print ('begin project file update.' )
        psxfile = update_file.update_contents(runFolder + projectFile)  
        zipfile = update_zip_file.update_contents(runFolder + datazipFile)
        print ('update psx result: ', psxfile ,'   update zip result: ', zipfile )

# %% [markdown]
# ## Fetching images from Box
# The code below retrieves the images from your project directory on Box, and puts them in the project folder on the cluster that you specified above.
#
# When you run it, it will check for the number of files in the folder on Box, and list each of them as it downloads. Please wait until you see *Download complete* before moving to the next step -- this can take some time if you have a lot of images, or large images.

# %%
import os
import shutil 
print("boxProjectFolder:",boxProjectFolder)

os.chdir(scratchImageDataDirectory)
print ('retrieving images from folder: ', boxProjectFolder)
print ('downloading images to directory: ', scratchImageDataDirectory)

# test folder contents
items = client.folder(folder_id='0').get_items(limit=25, offset=0)
if type(items) is list:
    print ('number of files in top folder: ', len(items) )
    
    targetfolderId = ''
    for item in items:
        if item['type'] == 'folder':
            print('folder name: ', item['name'])
            if item['name'] == boxProjectFolder:
                targetfolderId = item['id']
                print('targetfolderId: ', targetfolderId)
        
    if targetfolderId is not None:
        tgtitems = client.folder(folder_id=targetfolderId).get_items(limit=200, offset=0)
        if type(tgtitems) is list:
            print ('number of files in target folder: ', len(tgtitems) ) 
        
        # download all image files
        for tgtitem in tgtitems:
            if  not tgtitem['type'] == 'folder' and tgtitem['name'].endswith('.JPG'):
                # If necessary, remember to change '.JPG' to '.jpg' here
                print('downloading: ', tgtitem['name'])
                imagecontent = client.file(file_id=tgtitem['id']).content()
                newfile = open(scratchImageDataDirectory + tgtitem['name'], 'wb')
                newfile.write(imagecontent)
                newfile.close()
        print ('Download complete')
# Out:
# boxProjectFolder: myBoxFolderName
# retrieving images from folder:  myBoxFolderName
# downloading images to directory:  /global/scratch/myashar/projectname/images/
# number of files in top folder:  7
# folder name:  Astronomy-Microscopy Summit
# folder name:  My Box Notes
# folder name:  myBoxFolderName
# targetfolderId:  53223729428
# folder name:  myBoxFolderName_Test1
# folder name:  savio_tests
# folder name:  test_data
# folder name:  workshop
# number of files in target folder:  46
# downloading:  IMG_0324.JPG
# downloading:  IMG_0325.JPG
# downloading:  IMG_0326.JPG
# downloading:  IMG_0327.JPG
# downloading:  IMG_0328.JPG
# downloading:  IMG_0329.JPG
# downloading:  IMG_0330.JPG
# downloading:  IMG_0331.JPG
# downloading:  IMG_0332.JPG
# downloading:  IMG_0333.JPG
# downloading:  IMG_0334.JPG
# downloading:  IMG_0335.JPG
# downloading:  IMG_0336.JPG
# downloading:  IMG_0337.JPG
# downloading:  IMG_0338.JPG
# downloading:  IMG_0339.JPG
# downloading:  IMG_0340.JPG
# downloading:  IMG_0341.JPG
# downloading:  IMG_0342.JPG
# downloading:  IMG_0346.JPG
# Download complete

# %% [markdown]
# ## Function for retrieving project file
# This code sets up a function to bring an updated project file back from Box, e.g. after you've made changes using the desktop version of Photoscan, and you want to run a subsequent processing step on a cluster.

# %%
import os
import shutil 
def retrieve_project_file():
    newFolderId = find_folder_id(boxProjectFolder)
    tgtitems = client.folder(folder_id=newFolderId).get_items(limit=1000, offset=0)

    # download the project file
    for tgtitem in tgtitems:
        if  not tgtitem['type'] == 'folder' and tgtitem['name'].endswith('.psx'):
            print('downloading: ', tgtitem['name'])
            imagecontent = client.file(file_id=tgtitem['id']).content()
            newfile = open(runFolder + tgtitem['name'], 'wb')
            newfile.write(imagecontent)
            newfile.close()
            print("new file: ", newfile)
            print('project file download complete.')
            
        if  not tgtitem['type'] == 'folder' and tgtitem['name'].endswith('.zip'):
            
            # delete the old folder
            # !rm -rf $runFolder$dataFolder
            
            print('downloading: ', tgtitem['name'])
            imagecontent = client.file(file_id=tgtitem['id']).content()
            newfile = open(runFolder + tgtitem['name'], 'wb')
            newfile.write(imagecontent)
            newfile.close()
            shutil.unpack_archive(runFolder + datazipFile, runFolder + dataFolder ,'zip')
            
            print('data zip file download complete.')

# %% [markdown]
# # Project setup
#
# This section pulls your images onto the computing cluster and creates and uploads a Photoscan .psx file if it doesn't already exist.

# %% [markdown]
# ## Set up job script
#
# This code sets up the job script that will be run on the cluster, in order to pull in your images.

# %%
def hrs(xhrs):
    return xhrs
def mins(xmins):
    return xmins

#Define widgets and defaults
hrslider=widgets.IntSlider(description='Estimated Hours:',  value=1, min=0, max=23,step=1)
minslider=widgets.IntSlider(description='Estimated Minutes:',  value=0, min=0, max=59,step=1)

# %%
# Enter the estimated hours and minutes to create the project and add photos
interact(hrs, xhrs=hrslider)
interact(mins, xmins=minslider)
# Out:
# interactive(children=(IntSlider(value=0, description='Estimated Hours:', max=23), Output()), _dom_classes=('wi…
# interactive(children=(IntSlider(value=2, description='Estimated Minutes:', max=59), Output()), _dom_classes=('…
# <function __main__.mins(xmins)>

# %%
import os, stat
os.system('export XAUTHORITY=/global/home/users/myashar/.Xauthority')
os.system('export DISPLAY=:0')
os.system("module load qt")
os.environ['QT_QPA_PLATFORM']='offscreen'
files = [ singularitymountfolder + 'images/' + f for f in os.listdir(scratchImageDataDirectory) ] 

template = '#!/usr/bin/env python3 \n\
import PhotoScan \n\
import time \n\
doc = PhotoScan.app.document \n\
chunk = PhotoScan.app.document.addChunk() \n\
chunk.addPhotos( {} ) \n\
doc.save(path=\"{}\", chunks = [doc.chunk])\n '
# !export DISPLAY=':0.0'
# !export XAUTHORITY=/global/home/users/myashar/.Xauthority
# !export DISPLAY=:0
output = template.format(str(files), singularitymountfolder + projectFile)
print('output: ', output)

with open(commandScript, 'w') as f:  
    f.write(output)

os.chmod(commandScript,  0o755)

#set time limit for this batch run
minstring = str(minslider.value)
if minslider.value < 10:
    minstring = '0' + str(minslider.value)
estimateTime = str(hrslider.value) + ':' + minstring + ':00'
print('estimateTime: ', estimateTime)
outputbatchscript = batchtemplate.format(estimateTime)
with open(slurmScript, 'w') as f:  
    f.write(outputbatchscript)
    
os.chmod(slurmScript,  0o755)
# Out:
# output:  #!/usr/bin/env python3
# import PhotoScan
# import time
# doc = PhotoScan.app.document
# chunk = PhotoScan.app.document.addChunk()
# chunk.addPhotos( ['/scratch/images/IMG_0338.JPG', '/scratch/images/IMG_0325.JPG', '/scratch/images/IMG_0333.JPG', '/scratch/images/IMG_0329.JPG', '/scratch/images/IMG_0330.JPG', '/scratch/images/IMG_0334.JPG', '/scratch/images/IMG_0337.JPG', '/scratch/images/IMG_0346.JPG', '/scratch/images/IMG_0327.JPG', '/scratch/images/IMG_0336.JPG', '/scratch/images/apptoken.cfg', '/scratch/images/IMG_0324.JPG', '/scratch/images/IMG_0340.JPG', '/scratch/images/IMG_0342.JPG', '/scratch/images/app.cfg', '/scratch/images/IMG_0339.JPG', '/scratch/images/IMG_0335.JPG', '/scratch/images/IMG_0331.JPG', '/scratch/images/IMG_0328.JPG', '/scratch/images/IMG_0326.JPG', '/scratch/images/IMG_0341.JPG', '/scratch/images/IMG_0332.JPG'] )
# doc.save(path="/scratch//projectname.psx", chunks = [doc.chunk])
#
# estimateTime:  0:02:00

# %% [markdown]
# ## Run job
# The code below will run the job on the cluster, pulling in your images from Box, and will display the job ID.

# %%
os.system('export XAUTHORITY=/global/home/users/myashar/.Xauthority')
os.system('export DISPLAY=:0')
os.environ['QT_QPA_PLATFORM']='offscreen'
os.system("module load qt")
os.chdir(runFolder)
print(runFolder)
out = !sbatch slurmscript.sh   
print(out)   
print ('Execute image loading output: ', out ) 
jobId =  out[0].split()[3]
print (jobId)
# Out:
# /global/scratch/myashar/projectname/
# ['Submitted batch job 4807120']
# Execute image loading output:  ['Submitted batch job 4807120']
# 4807120

# %%
# print the users queue and the job status by id
# !squeue -u $username
print('--------------------------------')
# !scontrol show job $jobId
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            4807120     savio projectn  myashar PD       0:00      1 (Resources)
# --------------------------------
# JobId=4807120 JobName=projectname
#    UserId=myashar(43974) GroupId=ucb(501) MCS_label=N/A
#    Priority=377307 Nice=0 Account=ac_scsguest QOS=savio_normal
#    JobState=PENDING Reason=Resources Dependency=(null)
#    Requeue=0 Restarts=0 BatchFlag=1 Reboot=0 ExitCode=0:0
#    RunTime=00:00:00 TimeLimit=00:02:00 TimeMin=N/A
#    SubmitTime=2019-07-18T16:51:29 EligibleTime=2019-07-18T16:51:29
#    StartTime=2019-07-18T16:53:07 EndTime=2019-07-18T16:55:07 Deadline=N/A
#    PreemptTime=None SuspendTime=None SecsPreSuspend=0
#    LastSchedEval=2019-07-18T16:53:04
#    Partition=savio AllocNode:Sid=jupyter:425871
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=(null) SchedNodeList=n0027.savio1
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    TRES=cpu=1,mem=62.50G,node=1
#    Socks/Node=* NtasksPerN:B:S:C=0:0:*:* CoreSpec=*
#    MinCPUsNode=1 MinMemoryNode=62.50G MinTmpDiskNode=0
#    Features=(null) DelayBoot=00:00:00
#    Gres=(null) Reservation=(null)
#    OverSubscribe=NO Contiguous=0 Licenses=(null) Network=(null)
#    Command=/global/scratch/myashar/projectname/slurmscript.sh
#    WorkDir=/global/scratch/myashar/projectname
#    StdErr=/global/scratch/myashar/projectname/slurm-4807120.out
#    StdIn=/dev/null
#    StdOut=/global/scratch/myashar/projectname/slurm-4807120.out
#    Power=

# %% [markdown]
# ## Upload project file
# If there isn't a "data" subfolder inside your project folder on Box already, the code below will first create it. The code will then upload a new Photoscan project file and associated data files to Box.
#
# **MYashar: As far as things stand now with the code, no such "data" subfolder is created on Box.**
#
# If a Photoscan project file with the same name already exists in the folder on Box, this code will *not* overwrite it.
#
# Please note: New folders in Box can take several minutes to register, so this step may take a few minutes. If you get a "file not found" error in the next step, wait a minute or two and retry.

# %%
from boxsdk.exception import BoxAPIException

newFolderId = find_folder_id(boxProjectFolder)
print('folder id: ', newFolderId)

if newFolderId == 0:
    newFolder = client.folder(folder_id='0').create_subfolder(boxProjectFolder)
    newFolderId = newFolder['id']
    print ("folder created" )
else: 
    print ("folder exists" )
    
print ("folder id: ", newFolderId )
# print("new folder: ", newFolder)
update_project_file_in_box()
# Out:
# find_folder_id folder_name:  myBoxFolderName
# find_folder_id folderlist:  [<Box Folder - 53223729428 (myBoxFolderName)>, <Box Folder - 52394687398 (myBoxFolderName_Test1)>]
# folder id:  53223729428
# folder exists
# folder id:  53223729428
# find_folder_id folder_name:  myBoxFolderName
# find_folder_id folderlist:  [<Box Folder - 53223729428 (myBoxFolderName)>, <Box Folder - 52394687398 (myBoxFolderName_Test1)>]
# Box folder id:  53223729428
# project file list:  [<Box File - 317022687393 (projectname.psx)>]
# datazip file list:  [<Box File - 317017752277 (projectname.files.zip)>, <Box File - 319186364581 (README.docx)>, <Box File - 319043117371 (slurm-generate_model_output.txt)>, <Box File - 319044387168 (slurm-build_texture.txt)>, <Box File - 319044323866 (slurm-export_photomosaic_format_output.txt)>, <Box File - 319035518579 (slurm-export_dense_cloud.txt)>, <Box File - 319043284628 (slurm-pull_images_from_Box.txt)>, <Box File - 319043305927 (slurm-build_dense_cloud.txt)>, <Box File - 319041408570 (slurm-build_mesh.txt)>]
# project file id:  317022687393
# data zip file list:  317017752277
# begin project file update.
# update psx result:  <Box File - 317022687393>    update zip result:  <Box File - 317017752277>

# %% [markdown]
# ## OFFLINE: Image masking
# If you need to mask any images before building the dense cloud, please launch your desktop version of Photoscan, make those changes, and save the modified .psx file back to your folder on Box before proceeding with the next step.

# %% [markdown]
# # Align photos and Build Dense Cloud
#
# The code below will retrieve the project file from Box. This will ensure that you're working with the latest version, even if you've made changes offline (such as image masking).

# %%
retrieve_project_file()
# Out:
# find_folder_id folder_name:  myBoxFolderName
# find_folder_id folderlist:  [<Box Folder - 53223729428 (myBoxFolderName)>, <Box Folder - 52394687398 (myBoxFolderName_Test1)>]
# downloading:  projectname.files.zip
# data zip file download complete.
# downloading:  projectname.psx
# new file:  <_io.BufferedWriter name='/global/scratch/myashar/projectname/projectname.psx'>
# project file download complete.

# %% [markdown]
# ## Set up job script
#
# Run the code box below, then choose your estimated run time for the job. The default run time is 3 hours, which should cover most projects with under 75 photos. If you have more photos, please increase the run time.
#
# **Maurice: make this a different widget with default run time of 3 hours**

# %%
# Enter the estimated hours and minutes to create the project and add photos
interact(hrs, xhrs=hrslider)
interact(mins, xmins=minslider)
# Out:
# interactive(children=(IntSlider(value=0, description='Estimated Hours:', max=23), Output()), _dom_classes=('wi…
# interactive(children=(IntSlider(value=2, description='Estimated Minutes:', max=59), Output()), _dom_classes=('…
# <function __main__.mins(xmins)>

# %% [markdown]
# ## Set up parameters
# Choose the quality settings for the dense cloud build after running the cells below.

# %%
def chc(txt):
    return txt

pselchoice=widgets.Dropdown(description='Preselection', value='GenericPreselection', options=['GenericPreselection', 'ReferencePreselection'])
qualchoice=widgets.Dropdown(description='Quality', value='MediumQuality', options=['UltraQuality', 'HighQuality', 'MediumQuality',  'LowQuality', 'LowestQuality'] )
fltrchoice=widgets.Dropdown(description='Filter', value='ModerateFiltering', options=['NoFiltering', 'MildFiltering', 'ModerateFiltering',  'AggressiveFiltering']  )
accchoice=widgets.Dropdown(description='Accuracy', value='MediumAccuracy', options= ['HighestAccuracy', 'HighAccuracy', 'MediumAccuracy',  'LowAccuracy', 'LowestAccuracy']  )
afchoice=widgets.Dropdown(description='Adaptive Fitting', options=['True', 'False'])

# %%
interact(chc, txt=pselchoice)
interact(chc, txt=qualchoice)
interact(chc, txt=fltrchoice)
interact(chc, txt=accchoice)
interact(chc, txt=afchoice)
# Out:
# interactive(children=(Dropdown(description='Preselection', options=('GenericPreselection', 'ReferencePreselect…
# interactive(children=(Dropdown(description='Quality', index=2, options=('UltraQuality', 'HighQuality', 'Medium…
# interactive(children=(Dropdown(description='Filter', index=2, options=('NoFiltering', 'MildFiltering', 'Modera…
# interactive(children=(Dropdown(description='Accuracy', index=2, options=('HighestAccuracy', 'HighAccuracy', 'M…
# interactive(children=(Dropdown(description='Adaptive Fitting', options=('True', 'False'), value='True'), Outpu…
# <function __main__.chc(txt)>

# %% [markdown]
# ## Create job script
# The next cell will create and display the job script that will be run on the cluster.

# %%
# Creates job script for building dense cloud

import os, stat

template = '#!/usr/bin/env python3 \n\
import PhotoScan \n\
import time \n\
print( "start time: ", time.time()) \n\
doc = PhotoScan.app.document \n\
doc.open(\"{}\") \n\
chunk = doc.chunk \n\
chunk.matchPhotos(accuracy=PhotoScan.{}, preselection=PhotoScan.{}) \n\
chunk.alignCameras(adaptive_fitting={}) \n\
## In Photoscan version 1.4.* the dense cloud generation task has been split into two parts - \n\
## depth maps generation and dense cloud generation:   \n\
chunk.buildDepthMaps(quality=PhotoScan.{}, filter=PhotoScan.{} ) \n\
chunk.buildDenseCloud(point_colors = True) \n\
doc.save(\"{}\") \n\
print( "stop time: ", time.time()) \n'
         
output = template.format(singularitymountfolder + projectFile, accchoice.value, pselchoice.value, afchoice.value, qualchoice.value, fltrchoice.value, singularitymountfolder + projectFile)

print('output: ', output)

with open(commandScript, 'w') as f:  
    f.write(output)

    
#Set time limit for this batch run
minstring = str(minslider.value)
if minslider.value < 10:
    minstring = '0' + str(minslider.value)
estimateTime = str(hrslider.value) + ':' + minstring + ':00'
print('estimateTime: ', estimateTime)
outputbatchscript = batchtemplate.format(estimateTime)
#outputbatchscript = batchtemplate.format('01:30:00')
with open(slurmScript, 'w') as f:  
    f.write(outputbatchscript)
# Out:
# output:  #!/usr/bin/env python3
# import PhotoScan
# import time
# print( "start time: ", time.time())
# doc = PhotoScan.app.document
# doc.open("/scratch//projectname.psx")
# chunk = doc.chunk
# chunk.matchPhotos(accuracy=PhotoScan.MediumAccuracy, preselection=PhotoScan.GenericPreselection)
# chunk.alignCameras(adaptive_fitting=True)
# ## In Photoscan version 1.4.* the dense cloud generation task has been split into two parts -
# ## depth maps generation and dense cloud generation:
# chunk.buildDepthMaps(quality=PhotoScan.MediumQuality, filter=PhotoScan.ModerateFiltering )
# chunk.buildDenseCloud(point_colors = True)
# doc.save("/scratch//projectname.psx")
# print( "stop time: ", time.time())
#
# estimateTime:  0:05:00

# %% [markdown]
# ## Run dense cloud build
# Running the following code box will submit your job to the cluster. Your job ID will be printed below.

# %%
os.system('export XAUTHORITY=/global/home/users/myashar/.Xauthority')
os.system('export DISPLAY=:0')
os.environ['QT_QPA_PLATFORM']='offscreen'
os.system("module load qt")
os.chdir(runFolder)
print(runFolder)
out = !sbatch slurmscript.sh   
    
print ('Execute the dense cloud build output: ', out ) 
jobId =  out[0].split()[3]
print (jobId)
# Out:
# /global/scratch/myashar/projectname/
# Execute the dense cloud build output:  ['Submitted batch job 4810073']
# 4810073

# %% [markdown]
# ## Check on job status
# Building the dense cloud is the longest-running phase of the photogrammetry process. Depending on how many photos you have, and the quality settings you've chosen, the job could run for anywhere from minutes to hours. Run the following code box to check on the status of the dense cloud build. You can run it multiple times for new updates.

# %%
# print the users queue and the job status by id
# !squeue -u $username
# !squeue -u $USER
print('--------------------------------')
# !scontrol show job $jobId
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
# --------------------------------
# JobId=4810073 JobName=projectname
#    UserId=myashar(43974) GroupId=ucb(501) MCS_label=N/A
#    Priority=381693 Nice=0 Account=ac_scsguest QOS=savio_normal
#    JobState=COMPLETED Reason=None Dependency=(null)
#    Requeue=0 Restarts=0 BatchFlag=1 Reboot=0 ExitCode=0:0
#    RunTime=00:01:26 TimeLimit=00:05:00 TimeMin=N/A
#    SubmitTime=2019-07-19T19:18:54 EligibleTime=2019-07-19T19:18:54
#    StartTime=2019-07-19T20:05:03 EndTime=2019-07-19T20:06:29 Deadline=N/A
#    PreemptTime=None SuspendTime=None SecsPreSuspend=0
#    LastSchedEval=2019-07-19T20:05:03
#    Partition=savio AllocNode:Sid=jupyter:425871
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=n0062.savio1
#    BatchHost=n0062.savio1
#    NumNodes=1 NumCPUs=20 NumTasks=0 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    TRES=cpu=20,mem=62.50G,node=1,billing=20
#    Socks/Node=* NtasksPerN:B:S:C=0:0:*:* CoreSpec=*
#    MinCPUsNode=1 MinMemoryNode=62.50G MinTmpDiskNode=0
#    Features=(null) DelayBoot=00:00:00
#    Gres=(null) Reservation=(null)
#    OverSubscribe=NO Contiguous=0 Licenses=(null) Network=(null)
#    Command=/global/scratch/myashar/projectname/slurmscript.sh
#    WorkDir=/global/scratch/myashar/projectname
#    StdErr=/global/scratch/myashar/projectname/slurm-4810073.out
#    StdIn=/dev/null
#    StdOut=/global/scratch/myashar/projectname/slurm-4810073.out
#    Power=

# %% [markdown]
# ## Display log message
# As an optional step, you can run the code below to see the log file once the job is done. It includes technical information about the points that were found in each photo, rectifying disparities between photos, etc.

# %%
# print the log file if necessary
slurmlogfilename = 'slurm-' + jobId + '.out'
with open(slurmlogfilename, 'r') as fin:
    print(fin.read(), end="")
# Out:
# Enabling debugging
# Ending argument loop
# Singularity version: 2.6-dist
# Exec'ing: /usr/libexec/singularity/cli/exec.exec
# Evaluating args: '-B /global/scratch/myashar/projectname/:/scratch/ /global/scratch/myashar/container/photoscan_1_4_3.simg /scratch/execscript.sh -platform offscreen'
# VERBOSE [U=43974,P=85427]  message_init()                            Set messagelevel to: 5
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Initialize configuration file: /etc/singularity/singularity.conf
# DEBUG   [U=43974,P=85427]  singularity_config_parse()                Starting parse of configuration file /etc/singularity/singularity.conf
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key allow setuid = 'yes'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key max loop devices = '256'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key allow pid ns = 'yes'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key config passwd = 'yes'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key config group = 'yes'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key config resolv_conf = 'yes'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key mount proc = 'yes'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key mount sys = 'yes'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key mount dev = 'yes'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key mount devpts = 'yes'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key mount home = 'no'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key mount tmp = 'yes'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key mount hostfs = 'no'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key bind path = '/etc/localtime'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key bind path = '/etc/hosts'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key bind path = '/global/scratch'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key bind path = '/global/home/users'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key user bind control = 'yes'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key enable overlay = 'no'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key mount slave = 'yes'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key sessiondir max size = '16'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key allow container squashfs = 'yes'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key allow container extfs = 'yes'
# VERBOSE [U=43974,P=85427]  singularity_config_parse()                Got config key allow container dir = 'yes'
# DEBUG   [U=43974,P=85427]  singularity_config_parse()                Finished parsing configuration file '/etc/singularity/singularity.conf'
# DEBUG   [U=43974,P=85427]  singularity_config_get_value_impl()       No configuration entry found for 'always use nv'; returning default value 'NULL'
# VERBOSE [U=0,P=85260]      message_init()                            Set messagelevel to: 5
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Initialize configuration file: /etc/singularity/singularity.conf
# DEBUG   [U=0,P=85260]      singularity_config_parse()                Starting parse of configuration file /etc/singularity/singularity.conf
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key allow setuid = 'yes'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key max loop devices = '256'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key allow pid ns = 'yes'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key config passwd = 'yes'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key config group = 'yes'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key config resolv_conf = 'yes'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key mount proc = 'yes'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key mount sys = 'yes'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key mount dev = 'yes'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key mount devpts = 'yes'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key mount home = 'no'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key mount tmp = 'yes'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key mount hostfs = 'no'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key bind path = '/etc/localtime'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key bind path = '/etc/hosts'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key bind path = '/global/scratch'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key bind path = '/global/home/users'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key user bind control = 'yes'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key enable overlay = 'no'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key mount slave = 'yes'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key sessiondir max size = '16'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key allow container squashfs = 'yes'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key allow container extfs = 'yes'
# VERBOSE [U=0,P=85260]      singularity_config_parse()                Got config key allow container dir = 'yes'
# DEBUG   [U=0,P=85260]      singularity_config_parse()                Finished parsing configuration file '/etc/singularity/singularity.conf'
# VERBOSE [U=0,P=85260]      singularity_registry_init()               Initializing Singularity Registry
# VERBOSE [U=0,P=85260]      singularity_registry_set()                Adding value to registry: 'LIBEXECDIR' = '/usr/libexec'
# DEBUG   [U=0,P=85260]      singularity_registry_set()                Returning singularity_registry_set(libexecdir, /usr/libexec) = 0
# VERBOSE [U=0,P=85260]      singularity_registry_set()                Adding value to registry: 'COMMAND' = 'exec'
# DEBUG   [U=0,P=85260]      singularity_registry_set()                Returning singularity_registry_set(COMMAND, exec) = 0
# VERBOSE [U=0,P=85260]      singularity_registry_set()                Adding value to registry: 'MESSAGELEVEL' = '5'
# DEBUG   [U=0,P=85260]      singularity_registry_set()                Returning singularity_registry_set(MESSAGELEVEL, 5) = 0
# VERBOSE [U=0,P=85260]      singularity_registry_set()                Adding value to registry: 'VERSION' = '2.6-dist'
# DEBUG   [U=0,P=85260]      singularity_registry_set()                Returning singularity_registry_set(version, 2.6-dist) = 0
# VERBOSE [U=0,P=85260]      singularity_registry_set()                Adding value to registry: 'LOCALSTATEDIR' = '/var'
# DEBUG   [U=0,P=85260]      singularity_registry_set()                Returning singularity_registry_set(localstatedir, /var) = 0
# VERBOSE [U=0,P=85260]      singularity_registry_set()                Adding value to registry: 'SYSCONFDIR' = '/etc'
# DEBUG   [U=0,P=85260]      singularity_registry_set()                Returning singularity_registry_set(sysconfdir, /etc) = 0
# VERBOSE [U=0,P=85260]      singularity_registry_set()                Adding value to registry: 'BINDPATH' = ',/global/scratch/myashar/projectname/:/scratch/'
# DEBUG   [U=0,P=85260]      singularity_registry_set()                Returning singularity_registry_set(BINDPATH, ,/global/scratch/myashar/projectname/:/scratch/) = 0
# VERBOSE [U=0,P=85260]      singularity_registry_set()                Adding value to registry: 'BINDIR' = '/usr/bin'
# DEBUG   [U=0,P=85260]      singularity_registry_set()                Returning singularity_registry_set(bindir, /usr/bin) = 0
# VERBOSE [U=0,P=85260]      singularity_registry_set()                Adding value to registry: 'IMAGE' = '/global/scratch/myashar/container/photoscan_1_4_3.simg'
# DEBUG   [U=0,P=85260]      singularity_registry_set()                Returning singularity_registry_set(IMAGE, /global/scratch/myashar/container/photoscan_1_4_3.simg) = 0
# DEBUG   [U=0,P=85260]      singularity_registry_get()                Returning NULL on 'HOME'
# DEBUG   [U=0,P=85260]      singularity_registry_get()                Returning NULL on 'TARGET_UID'
# DEBUG   [U=0,P=85260]      singularity_registry_get()                Returning NULL on 'TARGET_GID'
# DEBUG   [U=0,P=85260]      singularity_priv_init()                   Initializing user info
# DEBUG   [U=0,P=85260]      singularity_priv_init()                   Set the calling user's username to: myashar
# DEBUG   [U=0,P=85260]      singularity_priv_init()                   Marking uinfo structure as ready
# DEBUG   [U=0,P=85260]      singularity_priv_init()                   Obtaining home directory
# VERBOSE [U=0,P=85260]      singularity_priv_init()                   Set home (via getpwuid()) to: /global/home/users/myashar
# VERBOSE [U=0,P=85260]      singularity_suid_init()                   Running SUID program workflow
# VERBOSE [U=0,P=85260]      singularity_suid_init()                   Checking program has appropriate permissions
# VERBOSE [U=0,P=85260]      singularity_suid_init()                   Checking configuration file is properly owned by root
# VERBOSE [U=0,P=85260]      singularity_suid_init()                   Checking if singularity.conf allows us to run as suid
# DEBUG   [U=0,P=85260]      singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow setuid, yes)
# DEBUG   [U=0,P=85260]      singularity_config_get_value_impl()       Returning configuration value allow setuid='yes'
# DEBUG   [U=0,P=85260]      singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow setuid, yes) = 1
# DEBUG   [U=0,P=85260]      singularity_registry_get()                Returning NULL on 'NOSUID'
# VERBOSE [U=0,P=85260]      singularity_priv_userns()                 Invoking the user namespace
# DEBUG   [U=0,P=85260]      singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow user ns, yes)
# DEBUG   [U=0,P=85260]      singularity_config_get_value_impl()       No configuration entry found for 'allow user ns'; returning default value 'yes'
# DEBUG   [U=0,P=85260]      singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow user ns, yes) = 1
# VERBOSE [U=0,P=85260]      singularity_priv_userns()                 Not virtualizing USER namespace: running as SUID
# DEBUG   [U=0,P=85260]      singularity_priv_userns()                 Returning singularity_priv_init(void)
# DEBUG   [U=0,P=85260]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=85260]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=85260]  singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_multi_impl() No configuration entry found for 'autofs bug path'; returning default value ''
# VERBOSE [U=43974,P=85260]  singularity_runtime_autofs()              No autofs bug path in configuration, skipping
# VERBOSE [U=43974,P=85260]  singularity_registry_set()                Adding value to registry: 'DAEMON_START' = '(null)'
# DEBUG   [U=43974,P=85260]  singularity_registry_set()                Returning singularity_registry_set(DAEMON_START, (null)) = 0
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning value from registry: 'DAEMON_START' = '(null)'
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=85260]  singularity_daemon_init()                 Not joining a daemon, daemon join not set
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'WRITABLE'
# VERBOSE [U=43974,P=85260]  main()                                    Instantiating read only container image object
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning value from registry: 'IMAGE' = '/global/scratch/myashar/container/photoscan_1_4_3.simg'
# DEBUG   [U=43974,P=85260]  singularity_image_init()                  Calling image_init for each file system module
# DEBUG   [U=43974,P=85260]  singularity_image_dir_init()              Opening file descriptor to directory: /global/scratch/myashar/container/photoscan_1_4_3.simg
# DEBUG   [U=43974,P=85260]  singularity_image_dir_init()              This is not a directory based image
# DEBUG   [U=43974,P=85260]  singularity_image_squashfs_init()         Checking if writable image requested
# DEBUG   [U=43974,P=85260]  singularity_image_squashfs_init()         Opening file descriptor to image: /global/scratch/myashar/container/photoscan_1_4_3.simg
# VERBOSE [U=43974,P=85260]  singularity_image_squashfs_init()         Checking that file pointer is a Singularity image
# DEBUG   [U=43974,P=85260]  singularity_image_squashfs_init()         Checking for magic in the top of the file
# VERBOSE [U=43974,P=85260]  singularity_image_squashfs_init()         File is a valid SquashFS image
# DEBUG   [U=43974,P=85260]  singularity_image_init()                  got image_init type for squashfs
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow container squashfs, yes)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value allow container squashfs='yes'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow container squashfs, yes) = 1
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       No configuration entry found for 'limit container paths'; returning default value 'NULL'
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       No configuration entry found for 'limit container owners'; returning default value 'NULL'
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       No configuration entry found for 'limit container groups'; returning default value 'NULL'
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'CLEANUPDIR'
# VERBOSE [U=43974,P=85260]  singularity_registry_set()                Adding value to registry: 'CLEANUPD_FD' = '-1'
# DEBUG   [U=43974,P=85260]  singularity_registry_set()                Returning singularity_registry_set(CLEANUPD_FD, -1) = 0
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'NOSESSIONCLEANUP'
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'NOCLEANUP'
# DEBUG   [U=43974,P=85260]  singularity_cleanupd()                    Not running a cleanup thread, no 'SINGULARITY_CLEANUPDIR' defined
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=85260]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_ipc()
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow ipc ns, yes)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       No configuration entry found for 'allow ipc ns'; returning default value 'yes'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow ipc ns, yes) = 1
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'UNSHARE_IPC'
# VERBOSE [U=43974,P=85260]  singularity_runtime_ns_ipc()              Not virtualizing IPC namespace on user request
# DEBUG   [U=43974,P=85260]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_pid()
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow pid ns, yes)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value allow pid ns='yes'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow pid ns, yes) = 1
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'UNSHARE_PID'
# VERBOSE [U=43974,P=85260]  singularity_runtime_ns_pid()              Not virtualizing PID namespace on user request
# DEBUG   [U=43974,P=85260]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_net()
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# VERBOSE [U=43974,P=85260]  singularity_runtime_ns_net()              Not virtualizing network namespace on user request
# DEBUG   [U=43974,P=85260]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_mnt()
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount slave, yes)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value mount slave='yes'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount slave, yes) = 1
# DEBUG   [U=43974,P=85260]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=85260]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=85260]      singularity_runtime_ns_mnt()              Virtualizing FS namespace
# DEBUG   [U=0,P=85260]      singularity_runtime_ns_mnt()              Virtualizing mount namespace
# DEBUG   [U=0,P=85260]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=85260]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=85260]  singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=85260]  singularity_runtime_ns_mnt()              Making mounts slave
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       No configuration entry found for 'memory fs type'; returning default value 'tmpfs'
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=85260]  singularity_sessiondir()                  Setting sessiondir
# VERBOSE [U=43974,P=85260]  singularity_sessiondir()                  Using session directory: /var/singularity/mnt/session
# DEBUG   [U=43974,P=85260]  singularity_sessiondir()                  Checking for session directory: /var/singularity/mnt/session
# DEBUG   [U=43974,P=85260]  singularity_sessiondir()                  Obtaining the default sessiondir size
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value sessiondir max size='16'
# DEBUG   [U=43974,P=85260]  singularity_sessiondir()                  Converted sessiondir size to: 16
# DEBUG   [U=43974,P=85260]  singularity_sessiondir()                  Creating the sessiondir size mount option length
# DEBUG   [U=43974,P=85260]  singularity_sessiondir()                  Got size length of: 9
# DEBUG   [U=43974,P=85260]  singularity_sessiondir()                  Creating the sessiondir size mount option string
# DEBUG   [U=43974,P=85260]  singularity_sessiondir()                  Checking to make sure the string was allocated correctly
# DEBUG   [U=43974,P=85260]  singularity_sessiondir()                  Mounting sessiondir tmpfs: /var/singularity/mnt/session
# VERBOSE [U=43974,P=85260]  singularity_registry_set()                Adding value to registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=85260]  singularity_registry_set()                Returning singularity_registry_set(SESSIONDIR, /var/singularity/mnt/session) = 0
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=85260]  singularity_image_mount()                 Figuring out which mount module to use...
# DEBUG   [U=43974,P=85260]  singularity_image_mount()                 Calling squashfs_mount
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value max loop devices='256'
# DEBUG   [U=43974,P=85260]  singularity_image_bind()                  Entered singularity_image_bind()
# DEBUG   [U=43974,P=85260]  singularity_image_bind()                  Converting max_loop_devs_string to int: '256'
# DEBUG   [U=43974,P=85260]  singularity_image_bind()                  Converted max_loop_devs_string to int: '256' -> 256
# DEBUG   [U=43974,P=85260]  singularity_image_bind()                  Checking if this image has been properly opened
# DEBUG   [U=43974,P=85260]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=85260]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=85260]      singularity_image_bind()                  Finding next available loop device...
# DEBUG   [U=0,P=85260]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=85260]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=85260]  singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=85260]  singularity_image_bind()                  Found available loop device: /dev/loop0
# DEBUG   [U=43974,P=85260]  singularity_image_bind()                  Setting LO_FLAGS_AUTOCLEAR
# DEBUG   [U=43974,P=85260]  singularity_image_bind()                  Using image offset: 31
# DEBUG   [U=43974,P=85260]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=85260]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=85260]      singularity_image_bind()                  Setting loop device flags
# DEBUG   [U=0,P=85260]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=85260]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=85260]  singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=85260]  singularity_image_bind()                  Using loop device: /dev/loop0
# VERBOSE [U=43974,P=85260]  singularity_image_squashfs_mount()        Mounting squashfs image: /dev/loop0 -> /var/singularity/mnt/container
# DEBUG   [U=43974,P=85260]  action_ready()                            Checking if container is valid at: /var/singularity/mnt/container
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=85260]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=85260]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=85260]      singularity_runtime_overlayfs()           Creating overlay_final directory: /var/singularity/mnt/final
# DEBUG   [U=0,P=85260]      s_mkpath()                                Directory exists, returning '0': /var/singularity/mnt/final
# DEBUG   [U=0,P=85260]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=85260]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=85260]  singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=85260]  singularity_registry_set()                Adding value to registry: 'OVERLAYFS_ENABLED' = '(null)'
# DEBUG   [U=43974,P=85260]  singularity_registry_set()                Returning singularity_registry_set(OVERLAYFS_ENABLED, (null)) = 0
# DEBUG   [U=43974,P=85260]  singularity_runtime_overlayfs()           Checking if overlayfs should be used
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value enable overlay='no'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(enable overlay, try)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value enable overlay='no'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(enable overlay, try) = 0
# VERBOSE [U=43974,P=85260]  singularity_runtime_overlayfs()           Not enabling overlayFS via configuration
# DEBUG   [U=43974,P=85260]  singularity_runtime_overlayfs()           Binding container directory to final home /var/singularity/mnt/container->/var/singularity/mnt/final
# DEBUG   [U=43974,P=85260]  container_statdir_update()                Get stat for container directories
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# VERBOSE [U=43974,P=85260]  singularity_runtime_mounts()              Running all mount components
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value mount dev='yes'
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_dev()           Checking configuration file for 'mount dev'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount dev, yes)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value mount dev='yes'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount dev, yes) = 1
# VERBOSE [U=43974,P=85260]  singularity_runtime_mount_dev()           Bind mounting /dev
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_kernelfs()      Checking configuration file for 'mount proc'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount proc, yes)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value mount proc='yes'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount proc, yes) = 1
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'PIDNS_ENABLED'
# VERBOSE [U=43974,P=85260]  singularity_runtime_mount_kernelfs()      Bind-mounting host /proc
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_kernelfs()      Checking configuration file for 'mount sys'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount sys, yes)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value mount sys='yes'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount sys, yes) = 1
# VERBOSE [U=43974,P=85260]  singularity_runtime_mount_kernelfs()      Mounting /sys
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount hostfs, no)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value mount hostfs='no'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount hostfs, no) = 0
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_hostfs()        Not mounting host file systems per configuration
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_binds()         Checking configuration file for 'bind path'
# VERBOSE [U=43974,P=85260]  singularity_runtime_mount_binds()         Found 'bind path' = /etc/localtime, /etc/localtime
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /etc/localtime
# DEBUG   [U=43974,P=85260]  check_mounted()                           Checking if currently mounted: /etc/localtime
# DEBUG   [U=43974,P=85260]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=85260]  check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=85260]  singularity_runtime_mount_binds()         Binding '/etc/localtime' to '/var/singularity/mnt/final//etc/localtime'
# VERBOSE [U=43974,P=85260]  singularity_mount()                       Ignored, try to mount /var/singularity/mnt/final/etc/localtime outside of container /usr/share/zoneinfo/Etc/UTC
# VERBOSE [U=43974,P=85260]  singularity_mount()                       Ignored, try to mount /var/singularity/mnt/final/etc/localtime outside of container /usr/share/zoneinfo/Etc/UTC
# VERBOSE [U=43974,P=85260]  singularity_runtime_mount_binds()         Found 'bind path' = /etc/hosts, /etc/hosts
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /etc/hosts
# DEBUG   [U=43974,P=85260]  check_mounted()                           Checking if currently mounted: /etc/hosts
# DEBUG   [U=43974,P=85260]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=85260]  check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=85260]  singularity_runtime_mount_binds()         Binding '/etc/hosts' to '/var/singularity/mnt/final//etc/hosts'
# VERBOSE [U=43974,P=85260]  singularity_runtime_mount_binds()         Found 'bind path' = /global/scratch, /global/scratch
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /global/scratch
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning value from registry: 'OVERLAYFS_ENABLED' = '(null)'
# WARNING [U=43974,P=85260]  singularity_runtime_mount_binds()         Non existent bind point (directory) in container: '/global/scratch'
# VERBOSE [U=43974,P=85260]  singularity_runtime_mount_binds()         Found 'bind path' = /global/home/users, /global/home/users
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /global/home/users
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning value from registry: 'OVERLAYFS_ENABLED' = '(null)'
# WARNING [U=43974,P=85260]  singularity_runtime_mount_binds()         Non existent bind point (directory) in container: '/global/home/users'
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_home()          Checking that home directry is configured: /global/home/users/myashar
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_home()          Checking if home directories are being influenced by user
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'NOHOME'
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'HOME'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount home, yes)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value mount home='no'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount home, yes) = 0
# VERBOSE [U=43974,P=85260]  singularity_runtime_mount_home()          Skipping home dir mounting (per config)
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_userbinds()     Checking for environment variable 'SINGULARITY_BINDPATH'
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning value from registry: 'BINDPATH' = ',/global/scratch/myashar/projectname/:/scratch/'
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_userbinds()     Checking for 'user bind control' in config
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(user bind control, yes)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value user bind control='yes'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(user bind control, yes) = 1
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_userbinds()     Parsing SINGULARITY_BINDPATH for user-specified bind mounts.
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_userbinds()     Found bind: /global/scratch/myashar/projectname/ -> container:/scratch/
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_userbinds()     Checking if bind point is already mounted: /scratch/
# DEBUG   [U=43974,P=85260]  check_mounted()                           Checking if currently mounted: /scratch/
# DEBUG   [U=43974,P=85260]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=85260]  check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=85260]  singularity_runtime_mount_userbinds()     Binding '/global/scratch/myashar/projectname/' to '/var/singularity/mnt/final//scratch/'
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_userbinds()     Unsetting environment variable 'SINGULARITY_BINDPATH'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount tmp, yes)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value mount tmp='yes'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount tmp, yes) = 1
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=85260]  check_mounted()                           Checking if currently mounted: /tmp
# DEBUG   [U=43974,P=85260]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=85260]  check_mounted()                           Iterating through /proc/mounts
# DEBUG   [U=43974,P=85260]  s_mkpath()                                Directory exists, returning '0': /tmp
# VERBOSE [U=43974,P=85260]  singularity_runtime_mount_tmp()           Mounting directory: /tmp
# DEBUG   [U=43974,P=85260]  check_mounted()                           Checking if currently mounted: /var/tmp
# DEBUG   [U=43974,P=85260]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=85260]  check_mounted()                           Iterating through /proc/mounts
# DEBUG   [U=43974,P=85260]  s_mkpath()                                Directory exists, returning '0': /var/tmp
# VERBOSE [U=43974,P=85260]  singularity_runtime_mount_tmp()           Mounting directory: /var/tmp
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_scratch()       Getting SINGULARITY_SCRATCHDIR from environment
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'SCRATCHDIR'
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_scratch()       Not mounting scratch directory: Not requested
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_cwd()           Checking to see if we should mount current working directory
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_cwd()           Getting current working directory
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_cwd()           Checking for contain option
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=85260]  singularity_runtime_mount_cwd()           Checking if current directory already available within container: /global/scratch/myashar/projectname
# VERBOSE [U=43974,P=85260]  singularity_runtime_mount_cwd()           Not mounting CWD, directory does not exist within container: /global/scratch/myashar/projectname
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# VERBOSE [U=43974,P=85260]  singularity_runtime_files()               Running file components
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=85260]  singularity_runtime_files_passwd()        Called singularity_file_passwd_create()
# DEBUG   [U=43974,P=85260]  singularity_runtime_files_passwd()        Checking configuration option: 'config passwd'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config passwd, yes)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value config passwd='yes'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config passwd, yes) = 1
# VERBOSE [U=43974,P=85260]  singularity_runtime_files_passwd()        Checking for template passwd file: /var/singularity/mnt/final/etc/passwd
# VERBOSE [U=43974,P=85260]  singularity_runtime_files_passwd()        Creating template of /etc/passwd
# DEBUG   [U=43974,P=85260]  copy_file()                               Called copy_file(/var/singularity/mnt/final/etc/passwd, /var/singularity/mnt/session/passwd)
# DEBUG   [U=43974,P=85260]  copy_file()                               Opening source file: /var/singularity/mnt/final/etc/passwd
# DEBUG   [U=43974,P=85260]  copy_file()                               Opening destination file: /var/singularity/mnt/session/passwd
# DEBUG   [U=43974,P=85260]  copy_file()                               Calling fstat() on source file descriptor: 6
# DEBUG   [U=43974,P=85260]  copy_file()                               Cloning permission string of source to dest
# DEBUG   [U=43974,P=85260]  copy_file()                               Copying file data...
# DEBUG   [U=43974,P=85260]  copy_file()                               Done copying data, closing file pointers
# DEBUG   [U=43974,P=85260]  copy_file()                               Returning copy_file(/var/singularity/mnt/final/etc/passwd, /var/singularity/mnt/session/passwd) = 0
# VERBOSE [U=43974,P=85260]  singularity_runtime_files_passwd()        Creating template passwd file and appending user data: /var/singularity/mnt/session/passwd
# DEBUG   [U=43974,P=85260]  container_file_bind()                     Called file_bind(/var/singularity/mnt/session/passwd, /etc/passwd)
# VERBOSE [U=43974,P=85260]  container_file_bind()                     Binding file '/var/singularity/mnt/session/passwd' to '/var/singularity/mnt/final/etc/passwd'
# DEBUG   [U=43974,P=85260]  envar_set()                               Setting environment variable: 'HOME' = '/global/home/users/myashar'
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=85260]  singularity_runtime_files_group()         Called singularity_file_group_create()
# DEBUG   [U=43974,P=85260]  singularity_runtime_files_group()         Checking configuration option: 'config group'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config group, yes)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value config group='yes'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config group, yes) = 1
# VERBOSE [U=43974,P=85260]  singularity_runtime_files_group()         Creating template of /etc/group for containment
# DEBUG   [U=43974,P=85260]  copy_file()                               Called copy_file(/var/singularity/mnt/final/etc/group, /var/singularity/mnt/session/group)
# DEBUG   [U=43974,P=85260]  copy_file()                               Opening source file: /var/singularity/mnt/final/etc/group
# DEBUG   [U=43974,P=85260]  copy_file()                               Opening destination file: /var/singularity/mnt/session/group
# DEBUG   [U=43974,P=85260]  copy_file()                               Calling fstat() on source file descriptor: 6
# DEBUG   [U=43974,P=85260]  copy_file()                               Cloning permission string of source to dest
# DEBUG   [U=43974,P=85260]  copy_file()                               Copying file data...
# DEBUG   [U=43974,P=85260]  copy_file()                               Done copying data, closing file pointers
# DEBUG   [U=43974,P=85260]  copy_file()                               Returning copy_file(/var/singularity/mnt/final/etc/group, /var/singularity/mnt/session/group) = 0
# VERBOSE [U=43974,P=85260]  singularity_runtime_files_group()         Updating group file with user info
# DEBUG   [U=43974,P=85260]  singularity_runtime_files_group()         Getting supplementary group info
# DEBUG   [U=43974,P=85260]  singularity_runtime_files_group()         Skipping duplicate supplementary group
# VERBOSE [U=43974,P=85260]  singularity_runtime_files_group()         Found supplementary group membership in: 600
# VERBOSE [U=43974,P=85260]  singularity_runtime_files_group()         Adding user's supplementary group ('savio') info to template group file
# VERBOSE [U=43974,P=85260]  singularity_runtime_files_group()         Found supplementary group membership in: 6206
# VERBOSE [U=43974,P=85260]  singularity_runtime_files_group()         Adding user's supplementary group ('matlab') info to template group file
# VERBOSE [U=43974,P=85260]  singularity_runtime_files_group()         Found supplementary group membership in: 10000
# VERBOSE [U=43974,P=85260]  singularity_runtime_files_group()         Adding user's supplementary group ('ac_scsguest') info to template group file
# DEBUG   [U=43974,P=85260]  container_file_bind()                     Called file_bind(/var/singularity/mnt/session/group, /etc/group)
# VERBOSE [U=43974,P=85260]  container_file_bind()                     Binding file '/var/singularity/mnt/session/group' to '/var/singularity/mnt/final/etc/group'
# DEBUG   [U=43974,P=85260]  singularity_runtime_files_resolvconf()    Checking configuration option
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config resolv_conf, yes)
# DEBUG   [U=43974,P=85260]  singularity_config_get_value_impl()       Returning configuration value config resolv_conf='yes'
# DEBUG   [U=43974,P=85260]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config resolv_conf, yes) = 1
# DEBUG   [U=43974,P=85260]  container_file_bind()                     Called file_bind(/etc/resolv.conf, /etc/resolv.conf)
# VERBOSE [U=43974,P=85260]  container_file_bind()                     Binding file '/etc/resolv.conf' to '/var/singularity/mnt/final/etc/resolv.conf'
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'CONTAINLIBS'
# VERBOSE [U=43974,P=85260]  singularity_runtime_enter()               Containing all rootfs components
# DEBUG   [U=43974,P=85260]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=85260]      singularity_priv_escalate()               Clearing supplementary GIDs.
# VERBOSE [U=0,P=85260]      singularity_runtime_enter_chroot()        Entering container file system root: /var/singularity/mnt/final
# DEBUG   [U=0,P=85260]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=85260]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=85260]  singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=85260]  singularity_runtime_enter_chroot()        Changing dir to '/' within the new root
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Cloning environment
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Counted 57 environment elements
# DEBUG   [U=43974,P=85260]  singularity_registry_get()                Returning NULL on 'CLEANENV'
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Cleaning environment
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_CHECKPOINT_IMAGE_DIR=/var/slurm/checkpoint
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NODELIST=n0062.savio1
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_NAME=projectname
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: SLURMD_NODENAME=n0062.savio1
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_TOPOLOGY_ADDR=ib-savio.ib-savio-02.n0062.savio1
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: HOSTNAME=n0062.savio1
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_PRIO_PROCESS=0
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NODE_ALIASES=(null)
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: SHELL=/bin/bash
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: TERM=xterm-color
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_QOS=savio_normal
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: CLICOLOR=1
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_TOPOLOGY_ADDR_PATTERN=switch.switch.node
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_libexecdir=/usr/libexec
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_libexecdir
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_COMMAND=exec
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_COMMAND
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NNODES=1
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: USER=myashar
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_MESSAGELEVEL=5
# DEBUG   [U=43974,P=85260]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_MESSAGELEVEL
# ...
# [CPU] estimating 446x796x96 disparity using 446x796x8u tiles
# timings: rectify: 0.015549 disparity: 0.383966 borders: 0.014371 filter: 0.017992 fill: 0
# [CPU] estimating 380x724x128 disparity using 380x724x8u tiles
# timings: rectify: 0.012076 disparity: 0.324204 borders: 0.010653 filter: 0.01412 fill: 0
# [CPU] estimating 314x714x128 disparity using 314x714x8u tiles
# timings: rectify: 0.0098 disparity: 0.265825 borders: 0.008449 filter: 0.01155 fill: 0
# [CPU] estimating 243x656x160 disparity using 243x656x8u tiles
# timings: rectify: 0.006991 disparity: 0.1958 borders: 0.006854 filter: 0.009034 fill: 0
# [CPU] estimating 306x783x160 disparity using 306x783x8u tiles
# timings: rectify: 0.016859 disparity: 0.299101 borders: 0.009238 filter: 0.012422 fill: 1e-06
# [CPU] estimating 418x794x128 disparity using 418x794x8u tiles
# timings: rectify: 0.014409 disparity: 0.383549 borders: 0.012224 filter: 0.016308 fill: 0
# [CPU] estimating 522x789x128 disparity using 522x789x8u tiles
# timings: rectify: 0.018078 disparity: 0.451886 borders: 0.016251 filter: 0.020757 fill: 1e-06
# [CPU] estimating 545x833x128 disparity using 545x833x8u tiles
# timings: rectify: 0.01994 disparity: 0.500463 borders: 0.017178 filter: 0.022072 fill: 0
# [CPU] estimating 517x760x128 disparity using 517x760x8u tiles
# timings: rectify: 0.01704 disparity: 0.448597 borders: 0.01362 filter: 0.01827 fill: 0
# [CPU] estimating 462x747x160 disparity using 462x747x8u tiles
# timings: rectify: 0.01523 disparity: 0.420407 borders: 0.01183 filter: 0.016462 fill: 1e-06
# [CPU] estimating 354x640x160 disparity using 354x640x8u tiles
# timings: rectify: 0.017889 disparity: 0.319739 borders: 0.007253 filter: 0.010224 fill: 0
# [CPU] estimating 325x748x160 disparity using 325x748x8u tiles
# timings: rectify: 0.010724 disparity: 0.273272 borders: 0.008897 filter: 0.011773 fill: 0
# [CPU] estimating 397x755x128 disparity using 397x755x8u tiles
# timings: rectify: 0.012876 disparity: 0.33723 borders: 0.009522 filter: 0.013236 fill: 0
# [CPU] estimating 446x796x96 disparity using 446x796x8u tiles
# timings: rectify: 0.013469 disparity: 0.378316 borders: 0.014154 filter: 0.017726 fill: 1e-06
# [CPU] estimating 501x776x96 disparity using 501x776x8u tiles
# timings: rectify: 0.017465 disparity: 0.433496 borders: 0.015078 filter: 0.019389 fill: 0
# [CPU] estimating 453x720x128 disparity using 453x720x8u tiles
# timings: rectify: 0.014131 disparity: 0.374445 borders: 0.011172 filter: 0.01514 fill: 0
# [CPU] estimating 361x707x128 disparity using 361x707x8u tiles
# timings: rectify: 0.011242 disparity: 0.288024 borders: 0.008795 filter: 0.012073 fill: 1e-06
# [CPU] estimating 293x654x128 disparity using 293x654x8u tiles
# timings: rectify: 0.008679 disparity: 0.235023 borders: 0.008275 filter: 0.010807 fill: 0
# [CPU] estimating 341x689x192 disparity using 341x689x8u tiles
# timings: rectify: 0.010859 disparity: 0.288781 borders: 0.008629 filter: 0.011625 fill: 0
# [CPU] estimating 427x756x160 disparity using 427x756x8u tiles
# timings: rectify: 0.014155 disparity: 0.388858 borders: 0.011228 filter: 0.015329 fill: 0
# [CPU] estimating 473x736x160 disparity using 473x736x8u tiles
# timings: rectify: 0.015736 disparity: 0.37926 borders: 0.012404 filter: 0.016354 fill: 0
# [CPU] estimating 618x808x128 disparity using 618x808x8u tiles
# timings: rectify: 0.022531 disparity: 0.567708 borders: 0.019158 filter: 0.024896 fill: 1e-06
# [CPU] estimating 530x721x128 disparity using 530x721x8u tiles
# timings: rectify: 0.017798 disparity: 0.432493 borders: 0.015277 filter: 0.019271 fill: 0
# [CPU] estimating 437x716x160 disparity using 437x716x8u tiles
# timings: rectify: 0.019375 disparity: 0.372104 borders: 0.010983 filter: 0.014683 fill: 0
# [CPU] estimating 379x732x160 disparity using 379x732x8u tiles
# timings: rectify: 0.012646 disparity: 0.33982 borders: 0.008311 filter: 0.012255 fill: 1e-06
# [CPU] estimating 326x681x192 disparity using 326x681x8u tiles
# timings: rectify: 0.011208 disparity: 0.275324 borders: 0.008565 filter: 0.011222 fill: 0
# [CPU] estimating 416x740x160 disparity using 416x740x8u tiles
# timings: rectify: 0.013163 disparity: 0.363211 borders: 0.009699 filter: 0.013648 fill: 0
# [CPU] estimating 451x718x128 disparity using 451x718x8u tiles
# timings: rectify: 0.014207 disparity: 0.359486 borders: 0.011166 filter: 0.015134 fill: 0
# [CPU] estimating 530x721x128 disparity using 530x721x8u tiles
# timings: rectify: 0.016779 disparity: 0.421624 borders: 0.014743 filter: 0.018949 fill: 0
# [CPU] estimating 498x810x128 disparity using 498x810x8u tiles
# timings: rectify: 0.018275 disparity: 0.439919 borders: 0.015996 filter: 0.020111 fill: 1e-06
# [CPU] estimating 438x729x128 disparity using 438x729x8u tiles
# timings: rectify: 0.013934 disparity: 0.368009 borders: 0.011399 filter: 0.014975 fill: 0
# [CPU] estimating 325x748x160 disparity using 325x748x8u tiles
# timings: rectify: 0.019087 disparity: 0.348049 borders: 0.010177 filter: 0.011595 fill: 0
# [CPU] estimating 238x648x160 disparity using 238x648x8u tiles
# timings: rectify: 0.009578 disparity: 0.18804 borders: 0.005005 filter: 0.006984 fill: 0
# [CPU] estimating 246x666x192 disparity using 246x666x8u tiles
# timings: rectify: 0.008488 disparity: 0.196314 borders: 0.005724 filter: 0.007869 fill: 1e-06
# [CPU] estimating 359x728x160 disparity using 359x728x8u tiles
# timings: rectify: 0.011967 disparity: 0.301031 borders: 0.008778 filter: 0.011938 fill: 0
# [CPU] estimating 437x716x160 disparity using 437x716x8u tiles
# timings: rectify: 0.013859 disparity: 0.354933 borders: 0.011484 filter: 0.015203 fill: 0
# [CPU] estimating 498x810x128 disparity using 498x810x8u tiles
# timings: rectify: 0.017944 disparity: 0.432142 borders: 0.014423 filter: 0.01892 fill: 0
# [CPU] estimating 459x736x128 disparity using 459x736x8u tiles
# timings: rectify: 0.015297 disparity: 0.371622 borders: 0.013022 filter: 0.017108 fill: 0
# [CPU] estimating 397x755x128 disparity using 397x755x8u tiles
# timings: rectify: 0.013073 disparity: 0.34998 borders: 0.010495 filter: 0.014318 fill: 0
# [CPU] estimating 306x727x128 disparity using 306x727x8u tiles
# timings: rectify: 0.009925 disparity: 0.263587 borders: 0.008372 filter: 0.011287 fill: 0
# [CPU] estimating 238x644x160 disparity using 238x644x8u tiles
# timings: rectify: 0.007096 disparity: 0.18866 borders: 0.006752 filter: 0.008992 fill: 0
# [CPU] estimating 238x644x160 disparity using 238x644x8u tiles
# timings: rectify: 0.007114 disparity: 0.173479 borders: 0.00552 filter: 0.007459 fill: 1e-06
# [CPU] estimating 314x714x128 disparity using 314x714x8u tiles
# timings: rectify: 0.009791 disparity: 0.267566 borders: 0.009309 filter: 0.012273 fill: 0
# [CPU] estimating 453x720x128 disparity using 453x720x8u tiles
# timings: rectify: 0.014125 disparity: 0.375325 borders: 0.012036 filter: 0.016153 fill: 0
# [CPU] estimating 555x754x128 disparity using 555x754x8u tiles
# timings: rectify: 0.018237 disparity: 0.459451 borders: 0.016183 filter: 0.02063 fill: 0
# [CPU] estimating 607x858x128 disparity using 607x858x8u tiles
# timings: rectify: 0.02247 disparity: 0.58388 borders: 0.020689 filter: 0.025537 fill: 0
# [CPU] estimating 529x783x160 disparity using 529x783x8u tiles
# timings: rectify: 0.018459 disparity: 0.480217 borders: 0.015105 filter: 0.019802 fill: 0
# [CPU] estimating 240x705x192 disparity using 240x705x8u tiles
# timings: rectify: 0.007859 disparity: 0.191914 borders: 0.006469 filter: 0.00855 fill: 0
# [CPU] estimating 331x757x160 disparity using 331x757x8u tiles
# timings: rectify: 0.011798 disparity: 0.283363 borders: 0.008902 filter: 0.012065 fill: 0
# [CPU] estimating 437x745x128 disparity using 437x745x8u tiles
# timings: rectify: 0.014609 disparity: 0.375835 borders: 0.012645 filter: 0.017178 fill: 1e-06
# [CPU] estimating 545x833x128 disparity using 545x833x8u tiles
# timings: rectify: 0.019937 disparity: 0.523806 borders: 0.020145 filter: 0.023024 fill: 1e-06
# [CPU] estimating 595x839x128 disparity using 595x839x8u tiles
# timings: rectify: 0.022188 disparity: 0.56483 borders: 0.018273 filter: 0.02389 fill: 0
# [CPU] estimating 546x738x128 disparity using 546x738x8u tiles
# timings: rectify: 0.017848 disparity: 0.483707 borders: 0.014038 filter: 0.018943 fill: 1e-06
# [CPU] estimating 454x732x160 disparity using 454x732x8u tiles
# timings: rectify: 0.014721 disparity: 0.450752 borders: 0.011935 filter: 0.016374 fill: 0
# [CPU] estimating 383x667x160 disparity using 383x667x8u tiles
# timings: rectify: 0.018029 disparity: 0.370181 borders: 0.009349 filter: 0.013246 fill: 0
# [CPU] estimating 238x648x160 disparity using 238x648x8u tiles
# timings: rectify: 0.009489 disparity: 0.178456 borders: 0.004772 filter: 0.006576 fill: 0
# [CPU] estimating 306x727x128 disparity using 306x727x8u tiles
# timings: rectify: 0.008421 disparity: 0.250523 borders: 0.008281 filter: 0.011181 fill: 0
# [CPU] estimating 380x724x128 disparity using 380x724x8u tiles
# timings: rectify: 0.010558 disparity: 0.309022 borders: 0.009028 filter: 0.012271 fill: 0
# [CPU] estimating 501x776x96 disparity using 501x776x8u tiles
# timings: rectify: 0.014537 disparity: 0.427264 borders: 0.015488 filter: 0.019663 fill: 0
# [CPU] estimating 555x754x128 disparity using 555x754x8u tiles
# timings: rectify: 0.018311 disparity: 0.457282 borders: 0.015877 filter: 0.020591 fill: 0
# [CPU] estimating 492x760x160 disparity using 492x760x8u tiles
# timings: rectify: 0.016037 disparity: 0.440298 borders: 0.013435 filter: 0.017687 fill: 0
# [CPU] estimating 415x786x160 disparity using 415x786x8u tiles
# timings: rectify: 0.013297 disparity: 0.394926 borders: 0.010539 filter: 0.014695 fill: 0
# [CPU] estimating 351x674x192 disparity using 351x674x8u tiles
# timings: rectify: 0.011042 disparity: 0.286599 borders: 0.00898 filter: 0.012054 fill: 0
# [CPU] estimating 441x738x160 disparity using 441x738x8u tiles
# timings: rectify: 0.014196 disparity: 0.388839 borders: 0.011039 filter: 0.015192 fill: 0
# [CPU] estimating 521x741x160 disparity using 521x741x8u tiles
# timings: rectify: 0.016974 disparity: 0.446609 borders: 0.014171 filter: 0.018475 fill: 0
# [CPU] estimating 559x823x128 disparity using 559x823x8u tiles
# timings: rectify: 0.020208 disparity: 0.5054 borders: 0.01731 filter: 0.022347 fill: 0
# [CPU] estimating 618x808x128 disparity using 618x808x8u tiles
# timings: rectify: 0.022026 disparity: 0.549066 borders: 0.018502 filter: 0.023973 fill: 0
# [CPU] estimating 451x718x128 disparity using 451x718x8u tiles
# timings: rectify: 0.014776 disparity: 0.380567 borders: 0.011736 filter: 0.015899 fill: 0
# [CPU] estimating 359x728x160 disparity using 359x728x8u tiles
# timings: rectify: 0.011759 disparity: 0.314123 borders: 0.008478 filter: 0.011767 fill: 0
# [CPU] estimating 383x667x160 disparity using 383x667x8u tiles
# timings: rectify: 0.011621 disparity: 0.307003 borders: 0.009249 filter: 0.012467 fill: 0
# [CPU] estimating 478x750x160 disparity using 478x750x8u tiles
# timings: rectify: 0.016105 disparity: 0.417583 borders: 0.012399 filter: 0.016716 fill: 0
# [CPU] estimating 552x753x128 disparity using 552x753x8u tiles
# timings: rectify: 0.018191 disparity: 0.475063 borders: 0.014928 filter: 0.019403 fill: 0
# [CPU] estimating 623x829x128 disparity using 623x829x8u tiles
# timings: rectify: 0.022664 disparity: 0.552216 borders: 0.019213 filter: 0.024943 fill: 0
# [CPU] estimating 559x823x128 disparity using 559x823x8u tiles
# timings: rectify: 0.020115 disparity: 0.51541 borders: 0.019778 filter: 0.023655 fill: 0
# [CPU] estimating 473x736x160 disparity using 473x736x8u tiles
# timings: rectify: 0.023988 disparity: 0.417413 borders: 0.011161 filter: 0.015057 fill: 0
# [CPU] estimating 416x740x160 disparity using 416x740x8u tiles
# timings: rectify: 0.011436 disparity: 0.366818 borders: 0.009484 filter: 0.013478 fill: 1e-06
# [CPU] estimating 336x695x160 disparity using 336x695x8u tiles
# timings: rectify: 0.008946 disparity: 0.27711 borders: 0.007644 filter: 0.010814 fill: 0
# [CPU] estimating 462x747x160 disparity using 462x747x8u tiles
# timings: rectify: 0.016435 disparity: 0.415725 borders: 0.011789 filter: 0.015786 fill: 0
# [CPU] estimating 546x738x128 disparity using 546x738x8u tiles
# timings: rectify: 0.018064 disparity: 0.457246 borders: 0.0144 filter: 0.018947 fill: 0
# [CPU] estimating 657x837x128 disparity using 657x837x8u tiles
# timings: rectify: 0.024148 disparity: 0.613084 borders: 0.01969 filter: 0.026004 fill: 0
# [CPU] estimating 598x826x128 disparity using 598x826x8u tiles
# timings: rectify: 0.022001 disparity: 0.546737 borders: 0.019428 filter: 0.024453 fill: 0
# [CPU] estimating 552x753x128 disparity using 552x753x8u tiles
# timings: rectify: 0.018361 disparity: 0.483136 borders: 0.015624 filter: 0.020261 fill: 1e-06
# [CPU] estimating 441x738x160 disparity using 441x738x8u tiles
# timings: rectify: 0.015356 disparity: 0.38242 borders: 0.01045 filter: 0.014196 fill: 0
# [CPU] estimating 341x689x192 disparity using 341x689x8u tiles
# timings: rectify: 0.010447 disparity: 0.29185 borders: 0.008895 filter: 0.011893 fill: 0
# [CPU] estimating 354x640x160 disparity using 354x640x8u tiles
# timings: rectify: 0.010582 disparity: 0.268916 borders: 0.010571 filter: 0.01226 fill: 0
# [CPU] estimating 454x732x160 disparity using 454x732x8u tiles
# timings: rectify: 0.014901 disparity: 0.392492 borders: 0.011631 filter: 0.015489 fill: 0
# [CPU] estimating 549x741x128 disparity using 549x741x8u tiles
# timings: rectify: 0.018254 disparity: 0.466783 borders: 0.014888 filter: 0.019658 fill: 0
# [CPU] estimating 598x826x128 disparity using 598x826x8u tiles
# timings: rectify: 0.021963 disparity: 0.524099 borders: 0.019368 filter: 0.024492 fill: 1e-06
# [CPU] estimating 623x829x128 disparity using 623x829x8u tiles
# timings: rectify: 0.022475 disparity: 0.544899 borders: 0.017402 filter: 0.023117 fill: 0
# [CPU] estimating 521x741x160 disparity using 521x741x8u tiles
# timings: rectify: 0.015435 disparity: 0.435072 borders: 0.011894 filter: 0.016343 fill: 1e-06
# [CPU] estimating 427x756x160 disparity using 427x756x8u tiles
# timings: rectify: 0.012752 disparity: 0.385173 borders: 0.010713 filter: 0.01453 fill: 0
# [CPU] estimating 326x681x192 disparity using 326x681x8u tiles
# timings: rectify: 0.010983 disparity: 0.276465 borders: 0.008782 filter: 0.011759 fill: 0
# [CPU] estimating 319x684x192 disparity using 319x684x8u tiles
# timings: rectify: 0.010114 disparity: 0.275383 borders: 0.008878 filter: 0.011974 fill: 0
# [CPU] estimating 410x724x160 disparity using 410x724x8u tiles
# timings: rectify: 0.013627 disparity: 0.361738 borders: 0.011101 filter: 0.017149 fill: 0
# [CPU] estimating 517x760x128 disparity using 517x760x8u tiles
# timings: rectify: 0.028232 disparity: 0.465897 borders: 0.014292 filter: 0.018809 fill: 0
# [CPU] estimating 595x839x128 disparity using 595x839x8u tiles
# timings: rectify: 0.022266 disparity: 0.544489 borders: 0.015853 filter: 0.021762 fill: 0
# [CPU] estimating 657x837x128 disparity using 657x837x8u tiles
# timings: rectify: 0.020628 disparity: 0.574808 borders: 0.01816 filter: 0.024346 fill: 0
# [CPU] estimating 549x741x128 disparity using 549x741x8u tiles
# timings: rectify: 0.015751 disparity: 0.447138 borders: 0.012994 filter: 0.017653 fill: 0
# [CPU] estimating 478x750x160 disparity using 478x750x8u tiles
# timings: rectify: 0.013684 disparity: 0.390047 borders: 0.011418 filter: 0.015825 fill: 0
# [CPU] estimating 351x674x192 disparity using 351x674x8u tiles
# timings: rectify: 0.009029 disparity: 0.268692 borders: 0.007632 filter: 0.010681 fill: 0
#
# Depth reconstruction devices performance:
#  - 100%	 done by CPU
# Total time: 61.0553 seconds
#
# BuildDenseCloud: point colors = 1
# selected 20 cameras in 0.100602 sec
# working volume: 1102x914x880
# tiles: 1x1x1
# selected 20 cameras in 7.2e-05 sec
# preloading data... done in 0.11733 sec
# filtering depth maps... done in 3.48647 sec
# preloading data... done in 7.37474 sec
# working volume: 1102x914x880
# tiles: 1x1x1
# accumulating data... done in 0.166222 sec
# building point cloud... done in 0.118185 sec
# 2130678 points extracted
# SaveProject: path = /scratch//projectname.psx
# saved project in 0.581788 sec
# LoadProject: path = /scratch//projectname.psx
# loaded project in 0.022948 sec
# stop time:  1563591987.388589

# %% [markdown]
# ## Export dense cloud
# If you want to export the dense cloud for use in other software, you can run the code boxes below. If you want to just continue with the next step in the photogrammetry process, you can skip it.

# %%
# Quinn - Im guessing at these extenstions, I have only used oc3
pointsFormatExt = { 'PointsFormatOBJ':'.obj', 'PointsFormatPLY':'.ply', 'PointsFormatXYZ':'.xyz', 'PointsFormatLAS':'.las', 'PointsFormatExpe':'.???',
'PointsFormatU3D':'.u3d', 'PointsFormatPDF':'.pdf', 'PointsFormatE57':'.e57', 'PointsFormatOC3':'.oc3', 'PointsFormatPotree':'.???',
'PointsFormatLAZ':'.laz', 'PointsFormatCL3':'.cl3', 'PointsFormatPTS':'.pts', 'PointsFormatDXF':'.dxf' }

ptsfchoice=widgets.Dropdown(description='Points Format', value='PointsFormatOC3', options= ['PointsFormatOBJ', 'PointsFormatPLY', 'PointsFormatXYZ', 'PointsFormatLAS', 'PointsFormatExpe',
'PointsFormatU3D', 'PointsFormatPDF', 'PointsFormatE57', 'PointsFormatOC3', 'PointsFormatPotree',
'PointsFormatLAZ', 'PointsFormatCL3', 'PointsFormatPTS', 'PointsFormatDXF']   )

# %%
interact(chc, txt=ptsfchoice)
# Out:
# interactive(children=(Dropdown(description='Points Format', index=8, options=('PointsFormatOBJ', 'PointsFormat…
# <function __main__.chc(txt)>

# %%
template = '#!/usr/bin/env python3 \n\
import PhotoScan \n\
doc = PhotoScan.app.document \n\
doc.open(\"{}\") \n\
chunk = doc.chunk \n\
chunk.exportPoints(path=\"{}\", format=PhotoScan.PointsFormat.{})  \n' 

output = template.format(singularitymountfolder + projectFile,  singularitymountfolder + 'photoscandemo' + pointsFormatExt[ptsfchoice.value], ptsfchoice.value)

print('output:', output)

with open(commandScript, 'w') as f:
    f.write(output)
# Out:
# output: #!/usr/bin/env python3
# import PhotoScan
# doc = PhotoScan.app.document
# doc.open("/scratch//projectname.psx")
# chunk = doc.chunk
# chunk.exportPoints(path="/scratch/photoscandemo.oc3", format=PhotoScan.PointsFormat.PointsFormatOC3)

# %%
out = !sbatch slurmscript.sh   
        
print (' Export the points  output: ', out ) 
jobId =  out[0].split()[3]
print (jobId)
# Out:
#  Export the points  output:  ['Submitted batch job 4810117']
# 4810117

# %%
# print the users queue and the job status by id
# !squeue -u $username
print('--------------------------------')
# !scontrol show job $jobId
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
# --------------------------------
# JobId=4810117 JobName=projectname
#    UserId=myashar(43974) GroupId=ucb(501) MCS_label=N/A
#    Priority=380401 Nice=0 Account=ac_scsguest QOS=savio_normal
#    JobState=COMPLETED Reason=None Dependency=(null)
#    Requeue=0 Restarts=0 BatchFlag=1 Reboot=0 ExitCode=0:0
#    RunTime=00:00:04 TimeLimit=00:05:00 TimeMin=N/A
#    SubmitTime=2019-07-19T20:09:53 EligibleTime=2019-07-19T20:09:53
#    StartTime=2019-07-19T20:09:54 EndTime=2019-07-19T20:09:58 Deadline=N/A
#    PreemptTime=None SuspendTime=None SecsPreSuspend=0
#    LastSchedEval=2019-07-19T20:09:54
#    Partition=savio AllocNode:Sid=jupyter:425871
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=n0159.savio1
#    BatchHost=n0159.savio1
#    NumNodes=1 NumCPUs=20 NumTasks=0 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    TRES=cpu=20,mem=62.50G,node=1,billing=20
#    Socks/Node=* NtasksPerN:B:S:C=0:0:*:* CoreSpec=*
#    MinCPUsNode=1 MinMemoryNode=62.50G MinTmpDiskNode=0
#    Features=(null) DelayBoot=00:00:00
#    Gres=(null) Reservation=(null)
#    OverSubscribe=NO Contiguous=0 Licenses=(null) Network=(null)
#    Command=/global/scratch/myashar/projectname/slurmscript.sh
#    WorkDir=/global/scratch/myashar/projectname
#    StdErr=/global/scratch/myashar/projectname/slurm-4810117.out
#    StdIn=/dev/null
#    StdOut=/global/scratch/myashar/projectname/slurm-4810117.out
#    Power=

# %% [markdown]
# ## Update project on Box
# After generating the dense cloud, the .psx file will be much larger and this may take a moment.
# **Maurice: add success message**

# %%
update_project_file_in_box()
# Out:
# find_folder_id folder_name:  myBoxFolderName
# find_folder_id folderlist:  [<Box Folder - 53223729428 (myBoxFolderName)>, <Box Folder - 52394687398 (myBoxFolderName_Test1)>]
# Box folder id:  53223729428
# project file list:  [<Box File - 317022687393 (projectname.psx)>]
# datazip file list:  [<Box File - 317017752277 (projectname.files.zip)>, <Box File - 319186364581 (README.docx)>, <Box File - 319043117371 (slurm-generate_model_output.txt)>, <Box File - 319044387168 (slurm-build_texture.txt)>, <Box File - 319044323866 (slurm-export_photomosaic_format_output.txt)>, <Box File - 319035518579 (slurm-export_dense_cloud.txt)>, <Box File - 319043284628 (slurm-pull_images_from_Box.txt)>, <Box File - 319043305927 (slurm-build_dense_cloud.txt)>, <Box File - 319041408570 (slurm-build_mesh.txt)>]
# project file id:  317022687393
# data zip file list:  317017752277
# begin project file update.
# update psx result:  <Box File - 317022687393>    update zip result:  <Box File - 317017752277>

# %% [markdown]
# ## OFFLINE: Dense cloud clean-up
# At this point, you may want to clean up the dense point cloud by removing stray points (e.g. for objects that have not been photographed in a lightbox, where there might be artifacts from the background, etc.) This should be done using the desktop version of Photoscan.
#
# Be sure to save the updated project file back to the same place in Box if you want to run the next processing steps through this notebook.

# %% [markdown]
# # Build Mesh
#
# First, retrieve the project file (.psx) from Box, in case it has been updated.

# %%
retrieve_project_file()
# Out:
# find_folder_id folder_name:  myBoxFolderName
# find_folder_id folderlist:  [<Box Folder - 53223729428 (myBoxFolderName)>, <Box Folder - 52394687398 (myBoxFolderName_Test1)>]
# downloading:  projectname.files.zip
# data zip file download complete.
# downloading:  projectname.psx
# new file:  <_io.BufferedWriter name='/global/scratch/myashar/projectname/projectname.psx'>
# project file download complete.

# %% [markdown]
# ## Choose parameters
# Running the code box below will create three sets of drop-downs where you can choose the surface type, face count, and data source.

# %%
stchoice=widgets.Dropdown(description='Surface type', value='Arbitrary', options=['Arbitrary', 'HeightField'])
fcchoice=widgets.Dropdown(description='Face count', value='HighFaceCount', options= ['LowFaceCount', 'MediumFaceCount', 'HighFaceCount'] )
dschoice=widgets.Dropdown(description='Data source', value='DenseCloudData', options=['PointCloudData', 'DenseCloudData', 'DepthMapsData', 'ModelData', 'TiledModelData', 'ElevationData',
'OrthomosaicData']  )

# %%
interact(chc, txt=stchoice)
interact(chc, txt=fcchoice)
interact(chc, txt=dschoice)
# Out:
# interactive(children=(Dropdown(description='Surface type', options=('Arbitrary', 'HeightField'), value='Arbitr…
# interactive(children=(Dropdown(description='Face count', index=2, options=('LowFaceCount', 'MediumFaceCount', …
# interactive(children=(Dropdown(description='Data source', index=1, options=('PointCloudData', 'DenseCloudData'…
# <function __main__.chc(txt)>

# %%
template = '#!/usr/bin/env python3 \n\
import PhotoScan \n\
import time \n\
print( "start time: ", time.time()) \n\
doc = PhotoScan.app.document \n\
doc.open(\"{}\") \n\
chunk = doc.chunk \n\
chunk.buildModel(surface=PhotoScan.{}, source=PhotoScan.{}, face_count=PhotoScan.{} ) \n\
doc.save(\"{}\") \n\
print( "stop time: ", time.time()) \n'

output = template.format(singularitymountfolder + projectFile, stchoice.value, dschoice.value, fcchoice.value, singularitymountfolder + projectFile)

print('output:', output)

with open(commandScript, 'w') as f:  
    f.write(output)


#set time limit for this batch run
outputbatchscript = batchtemplate.format('00:30:00')
with open(slurmScript, 'w') as f:  
    f.write(outputbatchscript)
# Out:
# output: #!/usr/bin/env python3
# import PhotoScan
# import time
# print( "start time: ", time.time())
# doc = PhotoScan.app.document
# doc.open("/scratch//projectname.psx")
# chunk = doc.chunk
# chunk.buildModel(surface=PhotoScan.Arbitrary, source=PhotoScan.DenseCloudData, face_count=PhotoScan.HighFaceCount )
# doc.save("/scratch//projectname.psx")
# print( "stop time: ", time.time())

# %% [markdown]
# ## Run mesh build
# The code box below will submit your job and print out your job ID.

# %%
out = !sbatch slurmscript.sh   
    
print ('Execute the mesh build output: ', out ) 
jobId =  out[0].split()[3]
print (jobId)
# Out:
# Execute the mesh build output:  ['Submitted batch job 4814475']
# 4814475

# %% [markdown]
# ## Check on mesh build status
# Run the code box below to get the current status of the mesh build job. You can run it multiple times for the most recent status.

# %%
# print the users queue and the job status by id
# !squeue -u $username
print('--------------------------------')
# !scontrol show job $jobId
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
# --------------------------------
# JobId=4814475 JobName=projectname
#    UserId=myashar(43974) GroupId=ucb(501) MCS_label=N/A
#    Priority=387228 Nice=0 Account=ac_scsguest QOS=savio_normal
#    JobState=COMPLETED Reason=None Dependency=(null)
#    Requeue=0 Restarts=0 BatchFlag=1 Reboot=0 ExitCode=0:0
#    RunTime=00:01:14 TimeLimit=00:30:00 TimeMin=N/A
#    SubmitTime=2019-07-20T16:31:51 EligibleTime=2019-07-20T16:31:51
#    StartTime=2019-07-20T16:32:38 EndTime=2019-07-20T16:33:52 Deadline=N/A
#    PreemptTime=None SuspendTime=None SecsPreSuspend=0
#    LastSchedEval=2019-07-20T16:32:38
#    Partition=savio AllocNode:Sid=jupyter:425871
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=n0070.savio1
#    BatchHost=n0070.savio1
#    NumNodes=1 NumCPUs=20 NumTasks=0 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    TRES=cpu=20,mem=62.50G,node=1,billing=20
#    Socks/Node=* NtasksPerN:B:S:C=0:0:*:* CoreSpec=*
#    MinCPUsNode=1 MinMemoryNode=62.50G MinTmpDiskNode=0
#    Features=(null) DelayBoot=00:00:00
#    Gres=(null) Reservation=(null)
#    OverSubscribe=NO Contiguous=0 Licenses=(null) Network=(null)
#    Command=/global/scratch/myashar/projectname/slurmscript.sh
#    WorkDir=/global/scratch/myashar/projectname
#    StdErr=/global/scratch/myashar/projectname/slurm-4814475.out
#    StdIn=/dev/null
#    StdOut=/global/scratch/myashar/projectname/slurm-4814475.out
#    Power=

# %% [markdown]
# ## Display log message
#
# As an optional step, you can run the code below to see the log file once the job is done.

# %%
# print the log file if necessary
slurmlogfilename = 'slurm-' + jobId + '.out'
with open(slurmlogfilename, 'r') as fin:
    print(fin.read(), end="")
# Out:
# Enabling debugging
# Ending argument loop
# Singularity version: 2.6-dist
# Exec'ing: /usr/libexec/singularity/cli/exec.exec
# Evaluating args: '-B /global/scratch/myashar/projectname/:/scratch/ /global/scratch/myashar/container/photoscan_1_4_3.simg /scratch/execscript.sh -platform offscreen'
# VERBOSE [U=43974,P=76523]  message_init()                            Set messagelevel to: 5
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Initialize configuration file: /etc/singularity/singularity.conf
# DEBUG   [U=43974,P=76523]  singularity_config_parse()                Starting parse of configuration file /etc/singularity/singularity.conf
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key allow setuid = 'yes'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key max loop devices = '256'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key allow pid ns = 'yes'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key config passwd = 'yes'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key config group = 'yes'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key config resolv_conf = 'yes'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key mount proc = 'yes'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key mount sys = 'yes'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key mount dev = 'yes'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key mount devpts = 'yes'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key mount home = 'no'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key mount tmp = 'yes'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key mount hostfs = 'no'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key bind path = '/etc/localtime'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key bind path = '/etc/hosts'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key bind path = '/global/scratch'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key bind path = '/global/home/users'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key user bind control = 'yes'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key enable overlay = 'no'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key mount slave = 'yes'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key sessiondir max size = '16'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key allow container squashfs = 'yes'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key allow container extfs = 'yes'
# VERBOSE [U=43974,P=76523]  singularity_config_parse()                Got config key allow container dir = 'yes'
# DEBUG   [U=43974,P=76523]  singularity_config_parse()                Finished parsing configuration file '/etc/singularity/singularity.conf'
# DEBUG   [U=43974,P=76523]  singularity_config_get_value_impl()       No configuration entry found for 'always use nv'; returning default value 'NULL'
# VERBOSE [U=0,P=76324]      message_init()                            Set messagelevel to: 5
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Initialize configuration file: /etc/singularity/singularity.conf
# DEBUG   [U=0,P=76324]      singularity_config_parse()                Starting parse of configuration file /etc/singularity/singularity.conf
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key allow setuid = 'yes'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key max loop devices = '256'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key allow pid ns = 'yes'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key config passwd = 'yes'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key config group = 'yes'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key config resolv_conf = 'yes'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key mount proc = 'yes'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key mount sys = 'yes'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key mount dev = 'yes'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key mount devpts = 'yes'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key mount home = 'no'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key mount tmp = 'yes'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key mount hostfs = 'no'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key bind path = '/etc/localtime'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key bind path = '/etc/hosts'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key bind path = '/global/scratch'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key bind path = '/global/home/users'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key user bind control = 'yes'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key enable overlay = 'no'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key mount slave = 'yes'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key sessiondir max size = '16'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key allow container squashfs = 'yes'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key allow container extfs = 'yes'
# VERBOSE [U=0,P=76324]      singularity_config_parse()                Got config key allow container dir = 'yes'
# DEBUG   [U=0,P=76324]      singularity_config_parse()                Finished parsing configuration file '/etc/singularity/singularity.conf'
# VERBOSE [U=0,P=76324]      singularity_registry_init()               Initializing Singularity Registry
# VERBOSE [U=0,P=76324]      singularity_registry_set()                Adding value to registry: 'LIBEXECDIR' = '/usr/libexec'
# DEBUG   [U=0,P=76324]      singularity_registry_set()                Returning singularity_registry_set(libexecdir, /usr/libexec) = 0
# VERBOSE [U=0,P=76324]      singularity_registry_set()                Adding value to registry: 'COMMAND' = 'exec'
# DEBUG   [U=0,P=76324]      singularity_registry_set()                Returning singularity_registry_set(COMMAND, exec) = 0
# VERBOSE [U=0,P=76324]      singularity_registry_set()                Adding value to registry: 'MESSAGELEVEL' = '5'
# DEBUG   [U=0,P=76324]      singularity_registry_set()                Returning singularity_registry_set(MESSAGELEVEL, 5) = 0
# VERBOSE [U=0,P=76324]      singularity_registry_set()                Adding value to registry: 'VERSION' = '2.6-dist'
# DEBUG   [U=0,P=76324]      singularity_registry_set()                Returning singularity_registry_set(version, 2.6-dist) = 0
# VERBOSE [U=0,P=76324]      singularity_registry_set()                Adding value to registry: 'LOCALSTATEDIR' = '/var'
# DEBUG   [U=0,P=76324]      singularity_registry_set()                Returning singularity_registry_set(localstatedir, /var) = 0
# VERBOSE [U=0,P=76324]      singularity_registry_set()                Adding value to registry: 'SYSCONFDIR' = '/etc'
# DEBUG   [U=0,P=76324]      singularity_registry_set()                Returning singularity_registry_set(sysconfdir, /etc) = 0
# VERBOSE [U=0,P=76324]      singularity_registry_set()                Adding value to registry: 'BINDPATH' = ',/global/scratch/myashar/projectname/:/scratch/'
# DEBUG   [U=0,P=76324]      singularity_registry_set()                Returning singularity_registry_set(BINDPATH, ,/global/scratch/myashar/projectname/:/scratch/) = 0
# VERBOSE [U=0,P=76324]      singularity_registry_set()                Adding value to registry: 'BINDIR' = '/usr/bin'
# DEBUG   [U=0,P=76324]      singularity_registry_set()                Returning singularity_registry_set(bindir, /usr/bin) = 0
# VERBOSE [U=0,P=76324]      singularity_registry_set()                Adding value to registry: 'IMAGE' = '/global/scratch/myashar/container/photoscan_1_4_3.simg'
# DEBUG   [U=0,P=76324]      singularity_registry_set()                Returning singularity_registry_set(IMAGE, /global/scratch/myashar/container/photoscan_1_4_3.simg) = 0
# DEBUG   [U=0,P=76324]      singularity_registry_get()                Returning NULL on 'HOME'
# DEBUG   [U=0,P=76324]      singularity_registry_get()                Returning NULL on 'TARGET_UID'
# DEBUG   [U=0,P=76324]      singularity_registry_get()                Returning NULL on 'TARGET_GID'
# DEBUG   [U=0,P=76324]      singularity_priv_init()                   Initializing user info
# DEBUG   [U=0,P=76324]      singularity_priv_init()                   Set the calling user's username to: myashar
# DEBUG   [U=0,P=76324]      singularity_priv_init()                   Marking uinfo structure as ready
# DEBUG   [U=0,P=76324]      singularity_priv_init()                   Obtaining home directory
# VERBOSE [U=0,P=76324]      singularity_priv_init()                   Set home (via getpwuid()) to: /global/home/users/myashar
# VERBOSE [U=0,P=76324]      singularity_suid_init()                   Running SUID program workflow
# VERBOSE [U=0,P=76324]      singularity_suid_init()                   Checking program has appropriate permissions
# VERBOSE [U=0,P=76324]      singularity_suid_init()                   Checking configuration file is properly owned by root
# VERBOSE [U=0,P=76324]      singularity_suid_init()                   Checking if singularity.conf allows us to run as suid
# DEBUG   [U=0,P=76324]      singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow setuid, yes)
# DEBUG   [U=0,P=76324]      singularity_config_get_value_impl()       Returning configuration value allow setuid='yes'
# DEBUG   [U=0,P=76324]      singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow setuid, yes) = 1
# DEBUG   [U=0,P=76324]      singularity_registry_get()                Returning NULL on 'NOSUID'
# VERBOSE [U=0,P=76324]      singularity_priv_userns()                 Invoking the user namespace
# DEBUG   [U=0,P=76324]      singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow user ns, yes)
# DEBUG   [U=0,P=76324]      singularity_config_get_value_impl()       No configuration entry found for 'allow user ns'; returning default value 'yes'
# DEBUG   [U=0,P=76324]      singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow user ns, yes) = 1
# VERBOSE [U=0,P=76324]      singularity_priv_userns()                 Not virtualizing USER namespace: running as SUID
# DEBUG   [U=0,P=76324]      singularity_priv_userns()                 Returning singularity_priv_init(void)
# DEBUG   [U=0,P=76324]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=76324]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=76324]  singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_multi_impl() No configuration entry found for 'autofs bug path'; returning default value ''
# VERBOSE [U=43974,P=76324]  singularity_runtime_autofs()              No autofs bug path in configuration, skipping
# VERBOSE [U=43974,P=76324]  singularity_registry_set()                Adding value to registry: 'DAEMON_START' = '(null)'
# DEBUG   [U=43974,P=76324]  singularity_registry_set()                Returning singularity_registry_set(DAEMON_START, (null)) = 0
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning value from registry: 'DAEMON_START' = '(null)'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=76324]  singularity_daemon_init()                 Not joining a daemon, daemon join not set
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'WRITABLE'
# VERBOSE [U=43974,P=76324]  main()                                    Instantiating read only container image object
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning value from registry: 'IMAGE' = '/global/scratch/myashar/container/photoscan_1_4_3.simg'
# DEBUG   [U=43974,P=76324]  singularity_image_init()                  Calling image_init for each file system module
# DEBUG   [U=43974,P=76324]  singularity_image_dir_init()              Opening file descriptor to directory: /global/scratch/myashar/container/photoscan_1_4_3.simg
# DEBUG   [U=43974,P=76324]  singularity_image_dir_init()              This is not a directory based image
# DEBUG   [U=43974,P=76324]  singularity_image_squashfs_init()         Checking if writable image requested
# DEBUG   [U=43974,P=76324]  singularity_image_squashfs_init()         Opening file descriptor to image: /global/scratch/myashar/container/photoscan_1_4_3.simg
# VERBOSE [U=43974,P=76324]  singularity_image_squashfs_init()         Checking that file pointer is a Singularity image
# DEBUG   [U=43974,P=76324]  singularity_image_squashfs_init()         Checking for magic in the top of the file
# VERBOSE [U=43974,P=76324]  singularity_image_squashfs_init()         File is a valid SquashFS image
# DEBUG   [U=43974,P=76324]  singularity_image_init()                  got image_init type for squashfs
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow container squashfs, yes)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value allow container squashfs='yes'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow container squashfs, yes) = 1
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       No configuration entry found for 'limit container paths'; returning default value 'NULL'
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       No configuration entry found for 'limit container owners'; returning default value 'NULL'
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       No configuration entry found for 'limit container groups'; returning default value 'NULL'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'CLEANUPDIR'
# VERBOSE [U=43974,P=76324]  singularity_registry_set()                Adding value to registry: 'CLEANUPD_FD' = '-1'
# DEBUG   [U=43974,P=76324]  singularity_registry_set()                Returning singularity_registry_set(CLEANUPD_FD, -1) = 0
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'NOSESSIONCLEANUP'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'NOCLEANUP'
# DEBUG   [U=43974,P=76324]  singularity_cleanupd()                    Not running a cleanup thread, no 'SINGULARITY_CLEANUPDIR' defined
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=76324]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_ipc()
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow ipc ns, yes)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       No configuration entry found for 'allow ipc ns'; returning default value 'yes'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow ipc ns, yes) = 1
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'UNSHARE_IPC'
# VERBOSE [U=43974,P=76324]  singularity_runtime_ns_ipc()              Not virtualizing IPC namespace on user request
# DEBUG   [U=43974,P=76324]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_pid()
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow pid ns, yes)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value allow pid ns='yes'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow pid ns, yes) = 1
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'UNSHARE_PID'
# VERBOSE [U=43974,P=76324]  singularity_runtime_ns_pid()              Not virtualizing PID namespace on user request
# DEBUG   [U=43974,P=76324]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_net()
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# VERBOSE [U=43974,P=76324]  singularity_runtime_ns_net()              Not virtualizing network namespace on user request
# DEBUG   [U=43974,P=76324]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_mnt()
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount slave, yes)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value mount slave='yes'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount slave, yes) = 1
# DEBUG   [U=43974,P=76324]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=76324]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=76324]      singularity_runtime_ns_mnt()              Virtualizing FS namespace
# DEBUG   [U=0,P=76324]      singularity_runtime_ns_mnt()              Virtualizing mount namespace
# DEBUG   [U=0,P=76324]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=76324]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=76324]  singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=76324]  singularity_runtime_ns_mnt()              Making mounts slave
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       No configuration entry found for 'memory fs type'; returning default value 'tmpfs'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=76324]  singularity_sessiondir()                  Setting sessiondir
# VERBOSE [U=43974,P=76324]  singularity_sessiondir()                  Using session directory: /var/singularity/mnt/session
# DEBUG   [U=43974,P=76324]  singularity_sessiondir()                  Checking for session directory: /var/singularity/mnt/session
# DEBUG   [U=43974,P=76324]  singularity_sessiondir()                  Obtaining the default sessiondir size
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value sessiondir max size='16'
# DEBUG   [U=43974,P=76324]  singularity_sessiondir()                  Converted sessiondir size to: 16
# DEBUG   [U=43974,P=76324]  singularity_sessiondir()                  Creating the sessiondir size mount option length
# DEBUG   [U=43974,P=76324]  singularity_sessiondir()                  Got size length of: 9
# DEBUG   [U=43974,P=76324]  singularity_sessiondir()                  Creating the sessiondir size mount option string
# DEBUG   [U=43974,P=76324]  singularity_sessiondir()                  Checking to make sure the string was allocated correctly
# DEBUG   [U=43974,P=76324]  singularity_sessiondir()                  Mounting sessiondir tmpfs: /var/singularity/mnt/session
# VERBOSE [U=43974,P=76324]  singularity_registry_set()                Adding value to registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=76324]  singularity_registry_set()                Returning singularity_registry_set(SESSIONDIR, /var/singularity/mnt/session) = 0
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=76324]  singularity_image_mount()                 Figuring out which mount module to use...
# DEBUG   [U=43974,P=76324]  singularity_image_mount()                 Calling squashfs_mount
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value max loop devices='256'
# DEBUG   [U=43974,P=76324]  singularity_image_bind()                  Entered singularity_image_bind()
# DEBUG   [U=43974,P=76324]  singularity_image_bind()                  Converting max_loop_devs_string to int: '256'
# DEBUG   [U=43974,P=76324]  singularity_image_bind()                  Converted max_loop_devs_string to int: '256' -> 256
# DEBUG   [U=43974,P=76324]  singularity_image_bind()                  Checking if this image has been properly opened
# DEBUG   [U=43974,P=76324]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=76324]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=76324]      singularity_image_bind()                  Finding next available loop device...
# DEBUG   [U=0,P=76324]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=76324]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=76324]  singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=76324]  singularity_image_bind()                  Found available loop device: /dev/loop0
# DEBUG   [U=43974,P=76324]  singularity_image_bind()                  Setting LO_FLAGS_AUTOCLEAR
# DEBUG   [U=43974,P=76324]  singularity_image_bind()                  Using image offset: 31
# DEBUG   [U=43974,P=76324]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=76324]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=76324]      singularity_image_bind()                  Setting loop device flags
# DEBUG   [U=0,P=76324]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=76324]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=76324]  singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=76324]  singularity_image_bind()                  Using loop device: /dev/loop0
# VERBOSE [U=43974,P=76324]  singularity_image_squashfs_mount()        Mounting squashfs image: /dev/loop0 -> /var/singularity/mnt/container
# DEBUG   [U=43974,P=76324]  action_ready()                            Checking if container is valid at: /var/singularity/mnt/container
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=76324]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=76324]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=76324]      singularity_runtime_overlayfs()           Creating overlay_final directory: /var/singularity/mnt/final
# DEBUG   [U=0,P=76324]      s_mkpath()                                Directory exists, returning '0': /var/singularity/mnt/final
# DEBUG   [U=0,P=76324]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=76324]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=76324]  singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=76324]  singularity_registry_set()                Adding value to registry: 'OVERLAYFS_ENABLED' = '(null)'
# DEBUG   [U=43974,P=76324]  singularity_registry_set()                Returning singularity_registry_set(OVERLAYFS_ENABLED, (null)) = 0
# DEBUG   [U=43974,P=76324]  singularity_runtime_overlayfs()           Checking if overlayfs should be used
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value enable overlay='no'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(enable overlay, try)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value enable overlay='no'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(enable overlay, try) = 0
# VERBOSE [U=43974,P=76324]  singularity_runtime_overlayfs()           Not enabling overlayFS via configuration
# DEBUG   [U=43974,P=76324]  singularity_runtime_overlayfs()           Binding container directory to final home /var/singularity/mnt/container->/var/singularity/mnt/final
# DEBUG   [U=43974,P=76324]  container_statdir_update()                Get stat for container directories
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# VERBOSE [U=43974,P=76324]  singularity_runtime_mounts()              Running all mount components
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value mount dev='yes'
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_dev()           Checking configuration file for 'mount dev'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount dev, yes)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value mount dev='yes'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount dev, yes) = 1
# VERBOSE [U=43974,P=76324]  singularity_runtime_mount_dev()           Bind mounting /dev
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_kernelfs()      Checking configuration file for 'mount proc'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount proc, yes)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value mount proc='yes'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount proc, yes) = 1
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'PIDNS_ENABLED'
# VERBOSE [U=43974,P=76324]  singularity_runtime_mount_kernelfs()      Bind-mounting host /proc
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_kernelfs()      Checking configuration file for 'mount sys'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount sys, yes)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value mount sys='yes'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount sys, yes) = 1
# VERBOSE [U=43974,P=76324]  singularity_runtime_mount_kernelfs()      Mounting /sys
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount hostfs, no)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value mount hostfs='no'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount hostfs, no) = 0
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_hostfs()        Not mounting host file systems per configuration
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_binds()         Checking configuration file for 'bind path'
# VERBOSE [U=43974,P=76324]  singularity_runtime_mount_binds()         Found 'bind path' = /etc/localtime, /etc/localtime
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /etc/localtime
# DEBUG   [U=43974,P=76324]  check_mounted()                           Checking if currently mounted: /etc/localtime
# DEBUG   [U=43974,P=76324]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=76324]  check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=76324]  singularity_runtime_mount_binds()         Binding '/etc/localtime' to '/var/singularity/mnt/final//etc/localtime'
# VERBOSE [U=43974,P=76324]  singularity_mount()                       Ignored, try to mount /var/singularity/mnt/final/etc/localtime outside of container /usr/share/zoneinfo/Etc/UTC
# VERBOSE [U=43974,P=76324]  singularity_mount()                       Ignored, try to mount /var/singularity/mnt/final/etc/localtime outside of container /usr/share/zoneinfo/Etc/UTC
# VERBOSE [U=43974,P=76324]  singularity_runtime_mount_binds()         Found 'bind path' = /etc/hosts, /etc/hosts
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /etc/hosts
# DEBUG   [U=43974,P=76324]  check_mounted()                           Checking if currently mounted: /etc/hosts
# DEBUG   [U=43974,P=76324]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=76324]  check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=76324]  singularity_runtime_mount_binds()         Binding '/etc/hosts' to '/var/singularity/mnt/final//etc/hosts'
# VERBOSE [U=43974,P=76324]  singularity_runtime_mount_binds()         Found 'bind path' = /global/scratch, /global/scratch
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /global/scratch
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning value from registry: 'OVERLAYFS_ENABLED' = '(null)'
# WARNING [U=43974,P=76324]  singularity_runtime_mount_binds()         Non existent bind point (directory) in container: '/global/scratch'
# VERBOSE [U=43974,P=76324]  singularity_runtime_mount_binds()         Found 'bind path' = /global/home/users, /global/home/users
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /global/home/users
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning value from registry: 'OVERLAYFS_ENABLED' = '(null)'
# WARNING [U=43974,P=76324]  singularity_runtime_mount_binds()         Non existent bind point (directory) in container: '/global/home/users'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_home()          Checking that home directry is configured: /global/home/users/myashar
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_home()          Checking if home directories are being influenced by user
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'NOHOME'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'HOME'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount home, yes)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value mount home='no'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount home, yes) = 0
# VERBOSE [U=43974,P=76324]  singularity_runtime_mount_home()          Skipping home dir mounting (per config)
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_userbinds()     Checking for environment variable 'SINGULARITY_BINDPATH'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning value from registry: 'BINDPATH' = ',/global/scratch/myashar/projectname/:/scratch/'
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_userbinds()     Checking for 'user bind control' in config
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(user bind control, yes)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value user bind control='yes'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(user bind control, yes) = 1
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_userbinds()     Parsing SINGULARITY_BINDPATH for user-specified bind mounts.
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_userbinds()     Found bind: /global/scratch/myashar/projectname/ -> container:/scratch/
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_userbinds()     Checking if bind point is already mounted: /scratch/
# DEBUG   [U=43974,P=76324]  check_mounted()                           Checking if currently mounted: /scratch/
# DEBUG   [U=43974,P=76324]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=76324]  check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=76324]  singularity_runtime_mount_userbinds()     Binding '/global/scratch/myashar/projectname/' to '/var/singularity/mnt/final//scratch/'
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_userbinds()     Unsetting environment variable 'SINGULARITY_BINDPATH'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount tmp, yes)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value mount tmp='yes'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount tmp, yes) = 1
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=76324]  check_mounted()                           Checking if currently mounted: /tmp
# DEBUG   [U=43974,P=76324]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=76324]  check_mounted()                           Iterating through /proc/mounts
# DEBUG   [U=43974,P=76324]  s_mkpath()                                Directory exists, returning '0': /tmp
# VERBOSE [U=43974,P=76324]  singularity_runtime_mount_tmp()           Mounting directory: /tmp
# DEBUG   [U=43974,P=76324]  check_mounted()                           Checking if currently mounted: /var/tmp
# DEBUG   [U=43974,P=76324]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=76324]  check_mounted()                           Iterating through /proc/mounts
# DEBUG   [U=43974,P=76324]  s_mkpath()                                Directory exists, returning '0': /var/tmp
# VERBOSE [U=43974,P=76324]  singularity_runtime_mount_tmp()           Mounting directory: /var/tmp
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_scratch()       Getting SINGULARITY_SCRATCHDIR from environment
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'SCRATCHDIR'
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_scratch()       Not mounting scratch directory: Not requested
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_cwd()           Checking to see if we should mount current working directory
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_cwd()           Getting current working directory
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_cwd()           Checking for contain option
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=76324]  singularity_runtime_mount_cwd()           Checking if current directory already available within container: /global/scratch/myashar/projectname
# VERBOSE [U=43974,P=76324]  singularity_runtime_mount_cwd()           Not mounting CWD, directory does not exist within container: /global/scratch/myashar/projectname
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# VERBOSE [U=43974,P=76324]  singularity_runtime_files()               Running file components
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=76324]  singularity_runtime_files_passwd()        Called singularity_file_passwd_create()
# DEBUG   [U=43974,P=76324]  singularity_runtime_files_passwd()        Checking configuration option: 'config passwd'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config passwd, yes)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value config passwd='yes'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config passwd, yes) = 1
# VERBOSE [U=43974,P=76324]  singularity_runtime_files_passwd()        Checking for template passwd file: /var/singularity/mnt/final/etc/passwd
# VERBOSE [U=43974,P=76324]  singularity_runtime_files_passwd()        Creating template of /etc/passwd
# DEBUG   [U=43974,P=76324]  copy_file()                               Called copy_file(/var/singularity/mnt/final/etc/passwd, /var/singularity/mnt/session/passwd)
# DEBUG   [U=43974,P=76324]  copy_file()                               Opening source file: /var/singularity/mnt/final/etc/passwd
# DEBUG   [U=43974,P=76324]  copy_file()                               Opening destination file: /var/singularity/mnt/session/passwd
# DEBUG   [U=43974,P=76324]  copy_file()                               Calling fstat() on source file descriptor: 6
# DEBUG   [U=43974,P=76324]  copy_file()                               Cloning permission string of source to dest
# DEBUG   [U=43974,P=76324]  copy_file()                               Copying file data...
# DEBUG   [U=43974,P=76324]  copy_file()                               Done copying data, closing file pointers
# DEBUG   [U=43974,P=76324]  copy_file()                               Returning copy_file(/var/singularity/mnt/final/etc/passwd, /var/singularity/mnt/session/passwd) = 0
# VERBOSE [U=43974,P=76324]  singularity_runtime_files_passwd()        Creating template passwd file and appending user data: /var/singularity/mnt/session/passwd
# DEBUG   [U=43974,P=76324]  container_file_bind()                     Called file_bind(/var/singularity/mnt/session/passwd, /etc/passwd)
# VERBOSE [U=43974,P=76324]  container_file_bind()                     Binding file '/var/singularity/mnt/session/passwd' to '/var/singularity/mnt/final/etc/passwd'
# DEBUG   [U=43974,P=76324]  envar_set()                               Setting environment variable: 'HOME' = '/global/home/users/myashar'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=76324]  singularity_runtime_files_group()         Called singularity_file_group_create()
# DEBUG   [U=43974,P=76324]  singularity_runtime_files_group()         Checking configuration option: 'config group'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config group, yes)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value config group='yes'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config group, yes) = 1
# VERBOSE [U=43974,P=76324]  singularity_runtime_files_group()         Creating template of /etc/group for containment
# DEBUG   [U=43974,P=76324]  copy_file()                               Called copy_file(/var/singularity/mnt/final/etc/group, /var/singularity/mnt/session/group)
# DEBUG   [U=43974,P=76324]  copy_file()                               Opening source file: /var/singularity/mnt/final/etc/group
# DEBUG   [U=43974,P=76324]  copy_file()                               Opening destination file: /var/singularity/mnt/session/group
# DEBUG   [U=43974,P=76324]  copy_file()                               Calling fstat() on source file descriptor: 6
# DEBUG   [U=43974,P=76324]  copy_file()                               Cloning permission string of source to dest
# DEBUG   [U=43974,P=76324]  copy_file()                               Copying file data...
# DEBUG   [U=43974,P=76324]  copy_file()                               Done copying data, closing file pointers
# DEBUG   [U=43974,P=76324]  copy_file()                               Returning copy_file(/var/singularity/mnt/final/etc/group, /var/singularity/mnt/session/group) = 0
# VERBOSE [U=43974,P=76324]  singularity_runtime_files_group()         Updating group file with user info
# DEBUG   [U=43974,P=76324]  singularity_runtime_files_group()         Getting supplementary group info
# DEBUG   [U=43974,P=76324]  singularity_runtime_files_group()         Skipping duplicate supplementary group
# VERBOSE [U=43974,P=76324]  singularity_runtime_files_group()         Found supplementary group membership in: 600
# VERBOSE [U=43974,P=76324]  singularity_runtime_files_group()         Adding user's supplementary group ('savio') info to template group file
# VERBOSE [U=43974,P=76324]  singularity_runtime_files_group()         Found supplementary group membership in: 6206
# VERBOSE [U=43974,P=76324]  singularity_runtime_files_group()         Adding user's supplementary group ('matlab') info to template group file
# VERBOSE [U=43974,P=76324]  singularity_runtime_files_group()         Found supplementary group membership in: 10000
# VERBOSE [U=43974,P=76324]  singularity_runtime_files_group()         Adding user's supplementary group ('ac_scsguest') info to template group file
# DEBUG   [U=43974,P=76324]  container_file_bind()                     Called file_bind(/var/singularity/mnt/session/group, /etc/group)
# VERBOSE [U=43974,P=76324]  container_file_bind()                     Binding file '/var/singularity/mnt/session/group' to '/var/singularity/mnt/final/etc/group'
# DEBUG   [U=43974,P=76324]  singularity_runtime_files_resolvconf()    Checking configuration option
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config resolv_conf, yes)
# DEBUG   [U=43974,P=76324]  singularity_config_get_value_impl()       Returning configuration value config resolv_conf='yes'
# DEBUG   [U=43974,P=76324]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config resolv_conf, yes) = 1
# DEBUG   [U=43974,P=76324]  container_file_bind()                     Called file_bind(/etc/resolv.conf, /etc/resolv.conf)
# VERBOSE [U=43974,P=76324]  container_file_bind()                     Binding file '/etc/resolv.conf' to '/var/singularity/mnt/final/etc/resolv.conf'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'CONTAINLIBS'
# VERBOSE [U=43974,P=76324]  singularity_runtime_enter()               Containing all rootfs components
# DEBUG   [U=43974,P=76324]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=76324]      singularity_priv_escalate()               Clearing supplementary GIDs.
# VERBOSE [U=0,P=76324]      singularity_runtime_enter_chroot()        Entering container file system root: /var/singularity/mnt/final
# DEBUG   [U=0,P=76324]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=76324]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=76324]  singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=76324]  singularity_runtime_enter_chroot()        Changing dir to '/' within the new root
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Cloning environment
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Counted 57 environment elements
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'CLEANENV'
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Cleaning environment
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_CHECKPOINT_IMAGE_DIR=/var/slurm/checkpoint
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NODELIST=n0070.savio1
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_NAME=projectname
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURMD_NODENAME=n0070.savio1
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_TOPOLOGY_ADDR=ib-savio.ib-savio-02.n0070.savio1
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: HOSTNAME=n0070.savio1
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_PRIO_PROCESS=0
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NODE_ALIASES=(null)
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SHELL=/bin/bash
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: TERM=xterm-color
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_QOS=savio_normal
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: CLICOLOR=1
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_TOPOLOGY_ADDR_PATTERN=switch.switch.node
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_libexecdir=/usr/libexec
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_libexecdir
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_COMMAND=exec
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_COMMAND
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NNODES=1
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: USER=myashar
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_MESSAGELEVEL=5
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_MESSAGELEVEL
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOBID=4814475
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: JPY_PARENT_PID=425707
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_version=2.6-dist
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_version
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: PAGER=cat
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_TASKS_PER_NODE=20
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: PATH=/bin:/usr/bin:/usr/local/bin:/sbin:/usr/sbin:/usr/local/sbin
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_localstatedir=/var
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_localstatedir
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_WORKING_CLUSTER=brc:master:6817:8192
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_ID=4814475
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_USER=myashar
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: PWD=/global/scratch/myashar/projectname
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITYENV_HISTFILE=
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: MPLBACKEND=module://ipykernel.pylab.backend_inline
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITYENV_PATH=/bin:/sbin:/usr/bin:/usr/sbin:/usr/local/bin:/usr/local/sbin
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_UID=43974
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NODEID=0
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_SUBMIT_DIR=/global/scratch/myashar/projectname
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: QT_QPA_PLATFORM=offscreen
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_TASK_PID=76260
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_CPUS_ON_NODE=20
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_PROCID=0
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: ENVIRONMENT=BATCH
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_NODELIST=n0070.savio1
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: HOME=/global/home/users/myashar
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SHLVL=2
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_LOCALID=0
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_GID=501
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_CPUS_PER_NODE=20
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_CLUSTER_NAME=brc
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_GTIDS=0
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_SUBMIT_HOST=jupyter.brc
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_PARTITION=savio
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_sysconfdir=/etc
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_sysconfdir
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_bindir=/usr/bin
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_bindir
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_ACCOUNT=ac_scsguest
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_NUM_NODES=1
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_IMAGE=/global/scratch/myashar/container/photoscan_1_4_3.simg
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_IMAGE
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: GIT_PAGER=cat
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_MEM_PER_NODE=64000
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Transposing environment
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Converting envar 'SINGULARITYENV_HISTFILE' to 'HISTFILE' = '(null)'
# DEBUG   [U=43974,P=76324]  envar_set()                               Unsetting environment variable: HISTFILE
# DEBUG   [U=43974,P=76324]  singularity_runtime_environment()         Converting envar 'SINGULARITYENV_PATH' to 'PATH' = '/bin:/sbin:/usr/bin:/usr/sbin:/usr/local/bin:/usr/local/sbin'
# DEBUG   [U=43974,P=76324]  envar_set()                               Setting environment variable: 'PATH' = '/bin:/sbin:/usr/bin:/usr/sbin:/usr/local/bin:/usr/local/sbin'
# DEBUG   [U=43974,P=76324]  singularity_priv_drop_perm()              Called singularity_priv_drop_perm(void)
# DEBUG   [U=43974,P=76324]  singularity_priv_drop_perm()              Escalating permissison so we can properly drop permission
# DEBUG   [U=43974,P=76324]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=76324]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=76324]      singularity_priv_drop_perm()              Resetting supplementary groups
# DEBUG   [U=0,P=76324]      singularity_priv_drop_perm()              Dropping to group ID '501'
# DEBUG   [U=0,P=76324]      singularity_priv_drop_perm()              Dropping real and effective privileges to GID = '501'
# DEBUG   [U=0,P=76324]      singularity_priv_drop_perm()              Dropping real and effective privileges to UID = '43974'
# DEBUG   [U=43974,P=76324]  singularity_priv_drop_perm()              Confirming we have correct GID
# DEBUG   [U=43974,P=76324]  singularity_priv_drop_perm()              Confirming we have correct UID
# DEBUG   [U=43974,P=76324]  singularity_priv_check_nonewprivs()       Setting NO_NEW_PRIVS to prevent future privilege escalations.
# DEBUG   [U=43974,P=76324]  singularity_priv_drop_perm()              Finished dropping privileges
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'PIDNS_ENABLED'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'TARGET_PWD'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=76324]  main()                                    Attempting to chdir to CWD: /global/scratch/myashar/projectname
# VERBOSE [U=43974,P=76324]  main()                                    Could not chdir to current dir: /global/scratch/myashar/projectname
# WARNING [U=43974,P=76324]  main()                                    Could not chdir to home: /global/home/users/myashar
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning value from registry: 'COMMAND' = 'exec'
# DEBUG   [U=43974,P=76324]  envar_set()                               Setting environment variable: 'SINGULARITY_CONTAINER' = 'photoscan_1_4_3.simg'
# DEBUG   [U=43974,P=76324]  envar_set()                               Setting environment variable: 'SINGULARITY_NAME' = 'photoscan_1_4_3.simg'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'SHELL'
# DEBUG   [U=43974,P=76324]  envar_set()                               Unsetting environment variable: SINGULARITY_SHELL
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'APPNAME'
# DEBUG   [U=43974,P=76324]  envar_set()                               Unsetting environment variable: SINGULARITY_APPNAME
# DEBUG   [U=43974,P=76324]  fd_cleanup()                              Cleanup file descriptor table
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=76324]  singularity_registry_get()                Returning value from registry: 'COMMAND' = 'exec'
# LOG     [U=43974,P=76324]  main()                                    USER=myashar, IMAGE='photoscan_1_4_3.simg', COMMAND='exec'
# DEBUG   [U=43974,P=76324]  action_exec()                             Checking for: /.singularity.d/actions/exec
# VERBOSE [U=43974,P=76324]  action_exec()                             Exec'ing /.singularity.d/actions/exec
# start time:  1563665561.322425
# LoadProject: path = /scratch//projectname.psx
# loaded project in 0.229496 sec
# BuildModel: surface type = Arbitrary, source data = Dense cloud, face count = High, interpolation = Enabled, vertex colors = 1
# Grid size: 914 x 880 x 1102
# Tree depth: 11
# Tree set in 10.855s (1533218 points)
# Leaves/Nodes: 10863350/12415257
# Laplacian constraints set in 2.72945s
# Depth[0/11]: 1
# 	Evaluated / Got / Solved in: 0 / 4.91142e-05 / 8.39233e-05
# Depth[1/11]: 8
# 	Evaluated / Got / Solved in: 0 / 0.000180721 / 0.00268579
# Depth[2/11]: 64
# 	Evaluated / Got / Solved in: 0 / 0.000698805 / 0.00538802
# Depth[3/11]: 512
# 	Evaluated / Got / Solved in: 0 / 0.00115395 / 0.0112739
# Depth[4/11]: 4096
# 	Evaluated / Got / Solved in: 0 / 0.00407052 / 0.0332537
# Depth[5/11]: 32768
# 	Evaluated / Got / Solved in: 0 / 0.0247517 / 0.0532866
# Depth[6/11]: 25984
# 	Evaluated / Got / Solved in: 0 / 0.0123518 / 0.0969357
# Depth[7/11]: 92688
# 	Evaluated / Got / Solved in: 0 / 0.0453432 / 0.184737
# Depth[8/11]: 336200
# 	Evaluated / Got / Solved in: 0 / 0.144703 / 0.428614
# Depth[9/11]: 1153320
# 	Evaluated / Got / Solved in: 0 / 0.418476 / 0.986207
# Depth[10/11]: 3543680
# 	Evaluated / Got / Solved in: 0 / 1.21638 / 2.20622
# Depth[11/11]: 7225936
# 	Evaluated / Got / Solved in: 0 / 2.30052 / 4.50684
# Linear system solved in 13.3021s
# Got Iso-value in 0.563034s
# Iso-Value 1.00491
# 4009108 faces extracted in 15.3532s
# decimating mesh (4000167 -> 306643)
# processing nodes...  done in 0.041571 sec
# calculating colors...  done in 0.916212 sec
# SaveProject: path = /scratch//projectname.psx
# saved project in 0.085596 sec
# LoadProject: path = /scratch//projectname.psx
# loaded project in 0.015602 sec
# stop time:  1563665631.080997

# %% [markdown]
# ## Update project on Box
# The next code box will return the project file to Box so you can make additional tweaks and changes offline.

# %%
update_project_file_in_box()
# Out:
# find_folder_id folder_name:  myBoxFolderName
# find_folder_id folderlist:  [<Box Folder - 53223729428 (myBoxFolderName)>, <Box Folder - 52394687398 (myBoxFolderName_Test1)>]
# Box folder id:  53223729428
# project file list:  [<Box File - 317022687393 (projectname.psx)>]
# datazip file list:  [<Box File - 317017752277 (projectname.files.zip)>, <Box File - 319186364581 (README.docx)>, <Box File - 319043117371 (slurm-generate_model_output.txt)>, <Box File - 319044387168 (slurm-build_texture.txt)>, <Box File - 319044323866 (slurm-export_photomosaic_format_output.txt)>, <Box File - 319035518579 (slurm-export_dense_cloud.txt)>, <Box File - 319043284628 (slurm-pull_images_from_Box.txt)>, <Box File - 319043305927 (slurm-build_dense_cloud.txt)>, <Box File - 319041408570 (slurm-build_mesh.txt)>]
# project file id:  317022687393
# data zip file list:  317017752277
# begin project file update.
# update psx result:  <Box File - 317022687393>    update zip result:  <Box File - 317017752277>

# %% [markdown]
# ## OFFLINE: Mesh cleanup
# If you need to add marker points in the Photoscan file (.psx), download the latest project file from Box, make the changes, and upload the edited .psx file back to Box.

# %% [markdown]
# # Build Texture
#
# First, retrieve the project file from Box in case it has been updated.

# %%
retrieve_project_file()
# Out:
# find_folder_id folder_name:  myBoxFolderName
# find_folder_id folderlist:  [<Box Folder - 53223729428 (myBoxFolderName)>, <Box Folder - 52394687398 (myBoxFolderName_Test1)>]
# downloading:  projectname.files.zip
# data zip file download complete.
# downloading:  projectname.psx
# new file:  <_io.BufferedWriter name='/global/scratch/myashar/projectname/projectname.psx'>
# project file download complete.

# %% [markdown]
# ## Choose parameters
# Choose the data source, and specify a coordinate system if desired, after running the next code box.

# %%
gmchoice=widgets.Dropdown(description='UV Mapping Mode', value='GenericMapping', options= ['GenericMapping', 'OrthophotoMapping', 'AdaptiveOrthophotoMapping', 'SphericalMapping',
'CameraMapping'])
ccchoice=widgets.Dropdown(description='Color Correction', value='True', options= ['True', 'False'] )
ds2choice=widgets.Dropdown(description='Data source', value='ModelData', options=['PointCloudData', 'DenseCloudData', 'DepthMapsData', 'ModelData', 'TiledModelData', 'ElevationData',
'OrthomosaicData']  )

# %%
interact(chc, txt=gmchoice)
interact(chc, txt=ds2choice)
interact(chc, txt=ccchoice)
interact(chc, txt=ds2choice)
# Out:
# interactive(children=(Dropdown(description='UV Mapping Mode', options=('GenericMapping', 'OrthophotoMapping', …
# interactive(children=(Dropdown(description='Data source', index=3, options=('PointCloudData', 'DenseCloudData'…
# interactive(children=(Dropdown(description='Color Correction', options=('True', 'False'), value='True'), Outpu…
# interactive(children=(Dropdown(description='Data source', index=3, options=('PointCloudData', 'DenseCloudData'…
# <function __main__.chc(txt)>

# %%
template = '#!/usr/bin/env python3 \n\
import PhotoScan \n\
import time \n\
print( "start time: ", time.time()) \n\
doc = PhotoScan.app.document \n\
doc.open(\"{}\") \n\
chunk = doc.chunk \n\
chunk.buildUV(mapping=PhotoScan.{}) \n\
chunk.calibrateColors( source_data=PhotoScan.DataSource.{}, color_balance={} ) \n\
chunk.buildTexture() \n\
doc.save(\"{}\") \n\
doc.open(\"{}\") \n\
chunk = doc.chunk \n\
chunk.buildOrthomosaic( surface=PhotoScan.DataSource.{} ) \n\
doc.save(\"{}\") \n\
print( "stop time: ", time.time()) \n'

output = template.format(singularitymountfolder + projectFile, gmchoice.value, ds2choice.value, ccchoice.value, singularitymountfolder + projectFile, singularitymountfolder + projectFile, ds2choice.value, singularitymountfolder + projectFile)

print('output:', output)

with open(commandScript, 'w') as f:  
    f.write(output)
# Out:
# output: #!/usr/bin/env python3
# import PhotoScan
# import time
# print( "start time: ", time.time())
# doc = PhotoScan.app.document
# doc.open("/scratch//projectname.psx")
# chunk = doc.chunk
# chunk.buildUV(mapping=PhotoScan.GenericMapping)
# chunk.calibrateColors( source_data=PhotoScan.DataSource.ModelData, color_balance=True )
# chunk.buildTexture()
# doc.save("/scratch//projectname.psx")
# doc.open("/scratch//projectname.psx")
# chunk = doc.chunk
# chunk.buildOrthomosaic( surface=PhotoScan.DataSource.ModelData )
# doc.save("/scratch//projectname.psx")
# print( "stop time: ", time.time())

# %% [markdown]
# ## Run texture build

# %%
os.system('export XAUTHORITY=/global/home/users/myashar/.Xauthority')
os.system('export DISPLAY=:0')
os.environ['QT_QPA_PLATFORM']='offscreen'
os.system("module load qt")
os.chdir(runFolder)

out = !sbatch slurmscript.sh   
    
print ('  texture and orthomosaic build output: ', out ) 
jobId =  out[0].split()[3]
print (jobId)
# Out:
#   texture and orthomosaic build output:  ['Submitted batch job 4814495']
# 4814495

# %%
# print the users queue and the job status by id
# !squeue -u $username
print('--------------------------------')
# !scontrol show job $jobId
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            4814495     savio projectn  myashar PD       0:00      1 (Priority)
# --------------------------------
# JobId=4814495 JobName=projectname
#    UserId=myashar(43974) GroupId=ucb(501) MCS_label=N/A
#    Priority=387240 Nice=0 Account=ac_scsguest QOS=savio_normal
#    JobState=PENDING Reason=Priority Dependency=(null)
#    Requeue=0 Restarts=0 BatchFlag=1 Reboot=0 ExitCode=0:0
#    RunTime=00:00:00 TimeLimit=00:30:00 TimeMin=N/A
#    SubmitTime=2019-07-20T17:29:35 EligibleTime=2019-07-20T17:29:35
#    StartTime=2019-07-20T17:33:43 EndTime=2019-07-20T18:03:43 Deadline=N/A
#    PreemptTime=None SuspendTime=None SecsPreSuspend=0
#    LastSchedEval=2019-07-20T17:33:30
#    Partition=savio AllocNode:Sid=jupyter:425871
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=(null) SchedNodeList=n0067.savio1
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    TRES=cpu=1,mem=62.50G,node=1
#    Socks/Node=* NtasksPerN:B:S:C=0:0:*:* CoreSpec=*
#    MinCPUsNode=1 MinMemoryNode=62.50G MinTmpDiskNode=0
#    Features=(null) DelayBoot=00:00:00
#    Gres=(null) Reservation=(null)
#    OverSubscribe=NO Contiguous=0 Licenses=(null) Network=(null)
#    Command=/global/scratch/myashar/projectname/slurmscript.sh
#    WorkDir=/global/scratch/myashar/projectname
#    StdErr=/global/scratch/myashar/projectname/slurm-4814495.out
#    StdIn=/dev/null
#    StdOut=/global/scratch/myashar/projectname/slurm-4814495.out
#    Power=

# %% [markdown]
# ## Display log message
#
# As an optional step, you can run the code below to see the log file once the job is done.

# %%
# print the log file if necessary
slurmlogfilename = 'slurm-' + jobId + '.out'
with open(slurmlogfilename, 'r') as fin:
    print(fin.read(), end="")
# Out:
# Enabling debugging
# Ending argument loop
# Singularity version: 2.6-dist
# Exec'ing: /usr/libexec/singularity/cli/exec.exec
# Evaluating args: '-B /global/scratch/myashar/projectname/:/scratch/ /global/scratch/myashar/container/photoscan_1_4_3.simg /scratch/execscript.sh -platform offscreen'
# VERBOSE [U=43974,P=104007] message_init()                            Set messagelevel to: 5
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Initialize configuration file: /etc/singularity/singularity.conf
# DEBUG   [U=43974,P=104007] singularity_config_parse()                Starting parse of configuration file /etc/singularity/singularity.conf
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key allow setuid = 'yes'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key max loop devices = '256'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key allow pid ns = 'yes'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key config passwd = 'yes'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key config group = 'yes'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key config resolv_conf = 'yes'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key mount proc = 'yes'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key mount sys = 'yes'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key mount dev = 'yes'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key mount devpts = 'yes'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key mount home = 'no'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key mount tmp = 'yes'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key mount hostfs = 'no'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key bind path = '/etc/localtime'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key bind path = '/etc/hosts'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key bind path = '/global/scratch'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key bind path = '/global/home/users'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key user bind control = 'yes'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key enable overlay = 'no'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key mount slave = 'yes'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key sessiondir max size = '16'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key allow container squashfs = 'yes'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key allow container extfs = 'yes'
# VERBOSE [U=43974,P=104007] singularity_config_parse()                Got config key allow container dir = 'yes'
# DEBUG   [U=43974,P=104007] singularity_config_parse()                Finished parsing configuration file '/etc/singularity/singularity.conf'
# DEBUG   [U=43974,P=104007] singularity_config_get_value_impl()       No configuration entry found for 'always use nv'; returning default value 'NULL'
# VERBOSE [U=0,P=103815]     message_init()                            Set messagelevel to: 5
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Initialize configuration file: /etc/singularity/singularity.conf
# DEBUG   [U=0,P=103815]     singularity_config_parse()                Starting parse of configuration file /etc/singularity/singularity.conf
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key allow setuid = 'yes'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key max loop devices = '256'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key allow pid ns = 'yes'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key config passwd = 'yes'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key config group = 'yes'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key config resolv_conf = 'yes'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key mount proc = 'yes'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key mount sys = 'yes'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key mount dev = 'yes'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key mount devpts = 'yes'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key mount home = 'no'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key mount tmp = 'yes'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key mount hostfs = 'no'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key bind path = '/etc/localtime'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key bind path = '/etc/hosts'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key bind path = '/global/scratch'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key bind path = '/global/home/users'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key user bind control = 'yes'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key enable overlay = 'no'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key mount slave = 'yes'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key sessiondir max size = '16'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key allow container squashfs = 'yes'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key allow container extfs = 'yes'
# VERBOSE [U=0,P=103815]     singularity_config_parse()                Got config key allow container dir = 'yes'
# DEBUG   [U=0,P=103815]     singularity_config_parse()                Finished parsing configuration file '/etc/singularity/singularity.conf'
# VERBOSE [U=0,P=103815]     singularity_registry_init()               Initializing Singularity Registry
# VERBOSE [U=0,P=103815]     singularity_registry_set()                Adding value to registry: 'LIBEXECDIR' = '/usr/libexec'
# DEBUG   [U=0,P=103815]     singularity_registry_set()                Returning singularity_registry_set(libexecdir, /usr/libexec) = 0
# VERBOSE [U=0,P=103815]     singularity_registry_set()                Adding value to registry: 'COMMAND' = 'exec'
# DEBUG   [U=0,P=103815]     singularity_registry_set()                Returning singularity_registry_set(COMMAND, exec) = 0
# VERBOSE [U=0,P=103815]     singularity_registry_set()                Adding value to registry: 'MESSAGELEVEL' = '5'
# DEBUG   [U=0,P=103815]     singularity_registry_set()                Returning singularity_registry_set(MESSAGELEVEL, 5) = 0
# VERBOSE [U=0,P=103815]     singularity_registry_set()                Adding value to registry: 'VERSION' = '2.6-dist'
# DEBUG   [U=0,P=103815]     singularity_registry_set()                Returning singularity_registry_set(version, 2.6-dist) = 0
# VERBOSE [U=0,P=103815]     singularity_registry_set()                Adding value to registry: 'LOCALSTATEDIR' = '/var'
# DEBUG   [U=0,P=103815]     singularity_registry_set()                Returning singularity_registry_set(localstatedir, /var) = 0
# VERBOSE [U=0,P=103815]     singularity_registry_set()                Adding value to registry: 'SYSCONFDIR' = '/etc'
# DEBUG   [U=0,P=103815]     singularity_registry_set()                Returning singularity_registry_set(sysconfdir, /etc) = 0
# VERBOSE [U=0,P=103815]     singularity_registry_set()                Adding value to registry: 'BINDPATH' = ',/global/scratch/myashar/projectname/:/scratch/'
# DEBUG   [U=0,P=103815]     singularity_registry_set()                Returning singularity_registry_set(BINDPATH, ,/global/scratch/myashar/projectname/:/scratch/) = 0
# VERBOSE [U=0,P=103815]     singularity_registry_set()                Adding value to registry: 'BINDIR' = '/usr/bin'
# DEBUG   [U=0,P=103815]     singularity_registry_set()                Returning singularity_registry_set(bindir, /usr/bin) = 0
# VERBOSE [U=0,P=103815]     singularity_registry_set()                Adding value to registry: 'IMAGE' = '/global/scratch/myashar/container/photoscan_1_4_3.simg'
# DEBUG   [U=0,P=103815]     singularity_registry_set()                Returning singularity_registry_set(IMAGE, /global/scratch/myashar/container/photoscan_1_4_3.simg) = 0
# DEBUG   [U=0,P=103815]     singularity_registry_get()                Returning NULL on 'HOME'
# DEBUG   [U=0,P=103815]     singularity_registry_get()                Returning NULL on 'TARGET_UID'
# DEBUG   [U=0,P=103815]     singularity_registry_get()                Returning NULL on 'TARGET_GID'
# DEBUG   [U=0,P=103815]     singularity_priv_init()                   Initializing user info
# DEBUG   [U=0,P=103815]     singularity_priv_init()                   Set the calling user's username to: myashar
# DEBUG   [U=0,P=103815]     singularity_priv_init()                   Marking uinfo structure as ready
# DEBUG   [U=0,P=103815]     singularity_priv_init()                   Obtaining home directory
# VERBOSE [U=0,P=103815]     singularity_priv_init()                   Set home (via getpwuid()) to: /global/home/users/myashar
# VERBOSE [U=0,P=103815]     singularity_suid_init()                   Running SUID program workflow
# VERBOSE [U=0,P=103815]     singularity_suid_init()                   Checking program has appropriate permissions
# VERBOSE [U=0,P=103815]     singularity_suid_init()                   Checking configuration file is properly owned by root
# VERBOSE [U=0,P=103815]     singularity_suid_init()                   Checking if singularity.conf allows us to run as suid
# DEBUG   [U=0,P=103815]     singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow setuid, yes)
# DEBUG   [U=0,P=103815]     singularity_config_get_value_impl()       Returning configuration value allow setuid='yes'
# DEBUG   [U=0,P=103815]     singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow setuid, yes) = 1
# DEBUG   [U=0,P=103815]     singularity_registry_get()                Returning NULL on 'NOSUID'
# VERBOSE [U=0,P=103815]     singularity_priv_userns()                 Invoking the user namespace
# DEBUG   [U=0,P=103815]     singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow user ns, yes)
# DEBUG   [U=0,P=103815]     singularity_config_get_value_impl()       No configuration entry found for 'allow user ns'; returning default value 'yes'
# DEBUG   [U=0,P=103815]     singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow user ns, yes) = 1
# VERBOSE [U=0,P=103815]     singularity_priv_userns()                 Not virtualizing USER namespace: running as SUID
# DEBUG   [U=0,P=103815]     singularity_priv_userns()                 Returning singularity_priv_init(void)
# DEBUG   [U=0,P=103815]     singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=103815]     singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=103815] singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=103815] singularity_config_get_value_multi_impl() No configuration entry found for 'autofs bug path'; returning default value ''
# VERBOSE [U=43974,P=103815] singularity_runtime_autofs()              No autofs bug path in configuration, skipping
# VERBOSE [U=43974,P=103815] singularity_registry_set()                Adding value to registry: 'DAEMON_START' = '(null)'
# DEBUG   [U=43974,P=103815] singularity_registry_set()                Returning singularity_registry_set(DAEMON_START, (null)) = 0
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning value from registry: 'DAEMON_START' = '(null)'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=103815] singularity_daemon_init()                 Not joining a daemon, daemon join not set
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'WRITABLE'
# VERBOSE [U=43974,P=103815] main()                                    Instantiating read only container image object
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning value from registry: 'IMAGE' = '/global/scratch/myashar/container/photoscan_1_4_3.simg'
# DEBUG   [U=43974,P=103815] singularity_image_init()                  Calling image_init for each file system module
# DEBUG   [U=43974,P=103815] singularity_image_dir_init()              Opening file descriptor to directory: /global/scratch/myashar/container/photoscan_1_4_3.simg
# DEBUG   [U=43974,P=103815] singularity_image_dir_init()              This is not a directory based image
# DEBUG   [U=43974,P=103815] singularity_image_squashfs_init()         Checking if writable image requested
# DEBUG   [U=43974,P=103815] singularity_image_squashfs_init()         Opening file descriptor to image: /global/scratch/myashar/container/photoscan_1_4_3.simg
# VERBOSE [U=43974,P=103815] singularity_image_squashfs_init()         Checking that file pointer is a Singularity image
# DEBUG   [U=43974,P=103815] singularity_image_squashfs_init()         Checking for magic in the top of the file
# VERBOSE [U=43974,P=103815] singularity_image_squashfs_init()         File is a valid SquashFS image
# DEBUG   [U=43974,P=103815] singularity_image_init()                  got image_init type for squashfs
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow container squashfs, yes)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value allow container squashfs='yes'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow container squashfs, yes) = 1
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       No configuration entry found for 'limit container paths'; returning default value 'NULL'
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       No configuration entry found for 'limit container owners'; returning default value 'NULL'
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       No configuration entry found for 'limit container groups'; returning default value 'NULL'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'CLEANUPDIR'
# VERBOSE [U=43974,P=103815] singularity_registry_set()                Adding value to registry: 'CLEANUPD_FD' = '-1'
# DEBUG   [U=43974,P=103815] singularity_registry_set()                Returning singularity_registry_set(CLEANUPD_FD, -1) = 0
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'NOSESSIONCLEANUP'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'NOCLEANUP'
# DEBUG   [U=43974,P=103815] singularity_cleanupd()                    Not running a cleanup thread, no 'SINGULARITY_CLEANUPDIR' defined
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=103815] singularity_runtime_ns()                  Calling: _singularity_runtime_ns_ipc()
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow ipc ns, yes)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       No configuration entry found for 'allow ipc ns'; returning default value 'yes'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow ipc ns, yes) = 1
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'UNSHARE_IPC'
# VERBOSE [U=43974,P=103815] singularity_runtime_ns_ipc()              Not virtualizing IPC namespace on user request
# DEBUG   [U=43974,P=103815] singularity_runtime_ns()                  Calling: _singularity_runtime_ns_pid()
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow pid ns, yes)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value allow pid ns='yes'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow pid ns, yes) = 1
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'UNSHARE_PID'
# VERBOSE [U=43974,P=103815] singularity_runtime_ns_pid()              Not virtualizing PID namespace on user request
# DEBUG   [U=43974,P=103815] singularity_runtime_ns()                  Calling: _singularity_runtime_ns_net()
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# VERBOSE [U=43974,P=103815] singularity_runtime_ns_net()              Not virtualizing network namespace on user request
# DEBUG   [U=43974,P=103815] singularity_runtime_ns()                  Calling: _singularity_runtime_ns_mnt()
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount slave, yes)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value mount slave='yes'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount slave, yes) = 1
# DEBUG   [U=43974,P=103815] singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=103815]     singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=103815]     singularity_runtime_ns_mnt()              Virtualizing FS namespace
# DEBUG   [U=0,P=103815]     singularity_runtime_ns_mnt()              Virtualizing mount namespace
# DEBUG   [U=0,P=103815]     singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=103815]     singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=103815] singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=103815] singularity_runtime_ns_mnt()              Making mounts slave
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       No configuration entry found for 'memory fs type'; returning default value 'tmpfs'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=103815] singularity_sessiondir()                  Setting sessiondir
# VERBOSE [U=43974,P=103815] singularity_sessiondir()                  Using session directory: /var/singularity/mnt/session
# DEBUG   [U=43974,P=103815] singularity_sessiondir()                  Checking for session directory: /var/singularity/mnt/session
# DEBUG   [U=43974,P=103815] singularity_sessiondir()                  Obtaining the default sessiondir size
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value sessiondir max size='16'
# DEBUG   [U=43974,P=103815] singularity_sessiondir()                  Converted sessiondir size to: 16
# DEBUG   [U=43974,P=103815] singularity_sessiondir()                  Creating the sessiondir size mount option length
# DEBUG   [U=43974,P=103815] singularity_sessiondir()                  Got size length of: 9
# DEBUG   [U=43974,P=103815] singularity_sessiondir()                  Creating the sessiondir size mount option string
# DEBUG   [U=43974,P=103815] singularity_sessiondir()                  Checking to make sure the string was allocated correctly
# DEBUG   [U=43974,P=103815] singularity_sessiondir()                  Mounting sessiondir tmpfs: /var/singularity/mnt/session
# VERBOSE [U=43974,P=103815] singularity_registry_set()                Adding value to registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=103815] singularity_registry_set()                Returning singularity_registry_set(SESSIONDIR, /var/singularity/mnt/session) = 0
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=103815] singularity_image_mount()                 Figuring out which mount module to use...
# DEBUG   [U=43974,P=103815] singularity_image_mount()                 Calling squashfs_mount
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value max loop devices='256'
# DEBUG   [U=43974,P=103815] singularity_image_bind()                  Entered singularity_image_bind()
# DEBUG   [U=43974,P=103815] singularity_image_bind()                  Converting max_loop_devs_string to int: '256'
# DEBUG   [U=43974,P=103815] singularity_image_bind()                  Converted max_loop_devs_string to int: '256' -> 256
# DEBUG   [U=43974,P=103815] singularity_image_bind()                  Checking if this image has been properly opened
# DEBUG   [U=43974,P=103815] singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=103815]     singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=103815]     singularity_image_bind()                  Finding next available loop device...
# DEBUG   [U=0,P=103815]     singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=103815]     singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=103815] singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=103815] singularity_image_bind()                  Found available loop device: /dev/loop0
# DEBUG   [U=43974,P=103815] singularity_image_bind()                  Setting LO_FLAGS_AUTOCLEAR
# DEBUG   [U=43974,P=103815] singularity_image_bind()                  Using image offset: 31
# DEBUG   [U=43974,P=103815] singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=103815]     singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=103815]     singularity_image_bind()                  Setting loop device flags
# DEBUG   [U=0,P=103815]     singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=103815]     singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=103815] singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=103815] singularity_image_bind()                  Using loop device: /dev/loop0
# VERBOSE [U=43974,P=103815] singularity_image_squashfs_mount()        Mounting squashfs image: /dev/loop0 -> /var/singularity/mnt/container
# DEBUG   [U=43974,P=103815] action_ready()                            Checking if container is valid at: /var/singularity/mnt/container
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=103815] singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=103815]     singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=103815]     singularity_runtime_overlayfs()           Creating overlay_final directory: /var/singularity/mnt/final
# DEBUG   [U=0,P=103815]     s_mkpath()                                Directory exists, returning '0': /var/singularity/mnt/final
# DEBUG   [U=0,P=103815]     singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=103815]     singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=103815] singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=103815] singularity_registry_set()                Adding value to registry: 'OVERLAYFS_ENABLED' = '(null)'
# DEBUG   [U=43974,P=103815] singularity_registry_set()                Returning singularity_registry_set(OVERLAYFS_ENABLED, (null)) = 0
# DEBUG   [U=43974,P=103815] singularity_runtime_overlayfs()           Checking if overlayfs should be used
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value enable overlay='no'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(enable overlay, try)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value enable overlay='no'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(enable overlay, try) = 0
# VERBOSE [U=43974,P=103815] singularity_runtime_overlayfs()           Not enabling overlayFS via configuration
# DEBUG   [U=43974,P=103815] singularity_runtime_overlayfs()           Binding container directory to final home /var/singularity/mnt/container->/var/singularity/mnt/final
# DEBUG   [U=43974,P=103815] container_statdir_update()                Get stat for container directories
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# VERBOSE [U=43974,P=103815] singularity_runtime_mounts()              Running all mount components
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value mount dev='yes'
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_dev()           Checking configuration file for 'mount dev'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount dev, yes)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value mount dev='yes'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount dev, yes) = 1
# VERBOSE [U=43974,P=103815] singularity_runtime_mount_dev()           Bind mounting /dev
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_kernelfs()      Checking configuration file for 'mount proc'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount proc, yes)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value mount proc='yes'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount proc, yes) = 1
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'PIDNS_ENABLED'
# VERBOSE [U=43974,P=103815] singularity_runtime_mount_kernelfs()      Bind-mounting host /proc
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_kernelfs()      Checking configuration file for 'mount sys'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount sys, yes)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value mount sys='yes'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount sys, yes) = 1
# VERBOSE [U=43974,P=103815] singularity_runtime_mount_kernelfs()      Mounting /sys
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount hostfs, no)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value mount hostfs='no'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount hostfs, no) = 0
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_hostfs()        Not mounting host file systems per configuration
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_binds()         Checking configuration file for 'bind path'
# VERBOSE [U=43974,P=103815] singularity_runtime_mount_binds()         Found 'bind path' = /etc/localtime, /etc/localtime
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_binds()         Checking if bind point is already mounted: /etc/localtime
# DEBUG   [U=43974,P=103815] check_mounted()                           Checking if currently mounted: /etc/localtime
# DEBUG   [U=43974,P=103815] check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=103815] check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=103815] singularity_runtime_mount_binds()         Binding '/etc/localtime' to '/var/singularity/mnt/final//etc/localtime'
# VERBOSE [U=43974,P=103815] singularity_mount()                       Ignored, try to mount /var/singularity/mnt/final/etc/localtime outside of container /usr/share/zoneinfo/Etc/UTC
# VERBOSE [U=43974,P=103815] singularity_mount()                       Ignored, try to mount /var/singularity/mnt/final/etc/localtime outside of container /usr/share/zoneinfo/Etc/UTC
# VERBOSE [U=43974,P=103815] singularity_runtime_mount_binds()         Found 'bind path' = /etc/hosts, /etc/hosts
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_binds()         Checking if bind point is already mounted: /etc/hosts
# DEBUG   [U=43974,P=103815] check_mounted()                           Checking if currently mounted: /etc/hosts
# DEBUG   [U=43974,P=103815] check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=103815] check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=103815] singularity_runtime_mount_binds()         Binding '/etc/hosts' to '/var/singularity/mnt/final//etc/hosts'
# VERBOSE [U=43974,P=103815] singularity_runtime_mount_binds()         Found 'bind path' = /global/scratch, /global/scratch
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_binds()         Checking if bind point is already mounted: /global/scratch
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning value from registry: 'OVERLAYFS_ENABLED' = '(null)'
# WARNING [U=43974,P=103815] singularity_runtime_mount_binds()         Non existent bind point (directory) in container: '/global/scratch'
# VERBOSE [U=43974,P=103815] singularity_runtime_mount_binds()         Found 'bind path' = /global/home/users, /global/home/users
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_binds()         Checking if bind point is already mounted: /global/home/users
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning value from registry: 'OVERLAYFS_ENABLED' = '(null)'
# WARNING [U=43974,P=103815] singularity_runtime_mount_binds()         Non existent bind point (directory) in container: '/global/home/users'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_home()          Checking that home directry is configured: /global/home/users/myashar
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_home()          Checking if home directories are being influenced by user
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'NOHOME'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'HOME'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount home, yes)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value mount home='no'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount home, yes) = 0
# VERBOSE [U=43974,P=103815] singularity_runtime_mount_home()          Skipping home dir mounting (per config)
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_userbinds()     Checking for environment variable 'SINGULARITY_BINDPATH'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning value from registry: 'BINDPATH' = ',/global/scratch/myashar/projectname/:/scratch/'
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_userbinds()     Checking for 'user bind control' in config
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(user bind control, yes)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value user bind control='yes'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(user bind control, yes) = 1
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_userbinds()     Parsing SINGULARITY_BINDPATH for user-specified bind mounts.
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_userbinds()     Found bind: /global/scratch/myashar/projectname/ -> container:/scratch/
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_userbinds()     Checking if bind point is already mounted: /scratch/
# DEBUG   [U=43974,P=103815] check_mounted()                           Checking if currently mounted: /scratch/
# DEBUG   [U=43974,P=103815] check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=103815] check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=103815] singularity_runtime_mount_userbinds()     Binding '/global/scratch/myashar/projectname/' to '/var/singularity/mnt/final//scratch/'
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_userbinds()     Unsetting environment variable 'SINGULARITY_BINDPATH'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount tmp, yes)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value mount tmp='yes'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount tmp, yes) = 1
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=103815] check_mounted()                           Checking if currently mounted: /tmp
# DEBUG   [U=43974,P=103815] check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=103815] check_mounted()                           Iterating through /proc/mounts
# DEBUG   [U=43974,P=103815] s_mkpath()                                Directory exists, returning '0': /tmp
# VERBOSE [U=43974,P=103815] singularity_runtime_mount_tmp()           Mounting directory: /tmp
# DEBUG   [U=43974,P=103815] check_mounted()                           Checking if currently mounted: /var/tmp
# DEBUG   [U=43974,P=103815] check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=103815] check_mounted()                           Iterating through /proc/mounts
# DEBUG   [U=43974,P=103815] s_mkpath()                                Directory exists, returning '0': /var/tmp
# VERBOSE [U=43974,P=103815] singularity_runtime_mount_tmp()           Mounting directory: /var/tmp
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_scratch()       Getting SINGULARITY_SCRATCHDIR from environment
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'SCRATCHDIR'
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_scratch()       Not mounting scratch directory: Not requested
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_cwd()           Checking to see if we should mount current working directory
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_cwd()           Getting current working directory
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_cwd()           Checking for contain option
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=103815] singularity_runtime_mount_cwd()           Checking if current directory already available within container: /global/scratch/myashar/projectname
# VERBOSE [U=43974,P=103815] singularity_runtime_mount_cwd()           Not mounting CWD, directory does not exist within container: /global/scratch/myashar/projectname
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# VERBOSE [U=43974,P=103815] singularity_runtime_files()               Running file components
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=103815] singularity_runtime_files_passwd()        Called singularity_file_passwd_create()
# DEBUG   [U=43974,P=103815] singularity_runtime_files_passwd()        Checking configuration option: 'config passwd'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config passwd, yes)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value config passwd='yes'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config passwd, yes) = 1
# VERBOSE [U=43974,P=103815] singularity_runtime_files_passwd()        Checking for template passwd file: /var/singularity/mnt/final/etc/passwd
# VERBOSE [U=43974,P=103815] singularity_runtime_files_passwd()        Creating template of /etc/passwd
# DEBUG   [U=43974,P=103815] copy_file()                               Called copy_file(/var/singularity/mnt/final/etc/passwd, /var/singularity/mnt/session/passwd)
# DEBUG   [U=43974,P=103815] copy_file()                               Opening source file: /var/singularity/mnt/final/etc/passwd
# DEBUG   [U=43974,P=103815] copy_file()                               Opening destination file: /var/singularity/mnt/session/passwd
# DEBUG   [U=43974,P=103815] copy_file()                               Calling fstat() on source file descriptor: 6
# DEBUG   [U=43974,P=103815] copy_file()                               Cloning permission string of source to dest
# DEBUG   [U=43974,P=103815] copy_file()                               Copying file data...
# DEBUG   [U=43974,P=103815] copy_file()                               Done copying data, closing file pointers
# DEBUG   [U=43974,P=103815] copy_file()                               Returning copy_file(/var/singularity/mnt/final/etc/passwd, /var/singularity/mnt/session/passwd) = 0
# VERBOSE [U=43974,P=103815] singularity_runtime_files_passwd()        Creating template passwd file and appending user data: /var/singularity/mnt/session/passwd
# DEBUG   [U=43974,P=103815] container_file_bind()                     Called file_bind(/var/singularity/mnt/session/passwd, /etc/passwd)
# VERBOSE [U=43974,P=103815] container_file_bind()                     Binding file '/var/singularity/mnt/session/passwd' to '/var/singularity/mnt/final/etc/passwd'
# DEBUG   [U=43974,P=103815] envar_set()                               Setting environment variable: 'HOME' = '/global/home/users/myashar'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=103815] singularity_runtime_files_group()         Called singularity_file_group_create()
# DEBUG   [U=43974,P=103815] singularity_runtime_files_group()         Checking configuration option: 'config group'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config group, yes)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value config group='yes'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config group, yes) = 1
# VERBOSE [U=43974,P=103815] singularity_runtime_files_group()         Creating template of /etc/group for containment
# DEBUG   [U=43974,P=103815] copy_file()                               Called copy_file(/var/singularity/mnt/final/etc/group, /var/singularity/mnt/session/group)
# DEBUG   [U=43974,P=103815] copy_file()                               Opening source file: /var/singularity/mnt/final/etc/group
# DEBUG   [U=43974,P=103815] copy_file()                               Opening destination file: /var/singularity/mnt/session/group
# DEBUG   [U=43974,P=103815] copy_file()                               Calling fstat() on source file descriptor: 6
# DEBUG   [U=43974,P=103815] copy_file()                               Cloning permission string of source to dest
# DEBUG   [U=43974,P=103815] copy_file()                               Copying file data...
# DEBUG   [U=43974,P=103815] copy_file()                               Done copying data, closing file pointers
# DEBUG   [U=43974,P=103815] copy_file()                               Returning copy_file(/var/singularity/mnt/final/etc/group, /var/singularity/mnt/session/group) = 0
# VERBOSE [U=43974,P=103815] singularity_runtime_files_group()         Updating group file with user info
# DEBUG   [U=43974,P=103815] singularity_runtime_files_group()         Getting supplementary group info
# DEBUG   [U=43974,P=103815] singularity_runtime_files_group()         Skipping duplicate supplementary group
# VERBOSE [U=43974,P=103815] singularity_runtime_files_group()         Found supplementary group membership in: 600
# VERBOSE [U=43974,P=103815] singularity_runtime_files_group()         Adding user's supplementary group ('savio') info to template group file
# VERBOSE [U=43974,P=103815] singularity_runtime_files_group()         Found supplementary group membership in: 6206
# VERBOSE [U=43974,P=103815] singularity_runtime_files_group()         Adding user's supplementary group ('matlab') info to template group file
# VERBOSE [U=43974,P=103815] singularity_runtime_files_group()         Found supplementary group membership in: 10000
# VERBOSE [U=43974,P=103815] singularity_runtime_files_group()         Adding user's supplementary group ('ac_scsguest') info to template group file
# DEBUG   [U=43974,P=103815] container_file_bind()                     Called file_bind(/var/singularity/mnt/session/group, /etc/group)
# VERBOSE [U=43974,P=103815] container_file_bind()                     Binding file '/var/singularity/mnt/session/group' to '/var/singularity/mnt/final/etc/group'
# DEBUG   [U=43974,P=103815] singularity_runtime_files_resolvconf()    Checking configuration option
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config resolv_conf, yes)
# DEBUG   [U=43974,P=103815] singularity_config_get_value_impl()       Returning configuration value config resolv_conf='yes'
# DEBUG   [U=43974,P=103815] singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config resolv_conf, yes) = 1
# DEBUG   [U=43974,P=103815] container_file_bind()                     Called file_bind(/etc/resolv.conf, /etc/resolv.conf)
# VERBOSE [U=43974,P=103815] container_file_bind()                     Binding file '/etc/resolv.conf' to '/var/singularity/mnt/final/etc/resolv.conf'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'CONTAINLIBS'
# VERBOSE [U=43974,P=103815] singularity_runtime_enter()               Containing all rootfs components
# DEBUG   [U=43974,P=103815] singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=103815]     singularity_priv_escalate()               Clearing supplementary GIDs.
# VERBOSE [U=0,P=103815]     singularity_runtime_enter_chroot()        Entering container file system root: /var/singularity/mnt/final
# DEBUG   [U=0,P=103815]     singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=103815]     singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=103815] singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=103815] singularity_runtime_enter_chroot()        Changing dir to '/' within the new root
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Cloning environment
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Counted 57 environment elements
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'CLEANENV'
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Cleaning environment
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_CHECKPOINT_IMAGE_DIR=/var/slurm/checkpoint
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_NODELIST=n0067.savio1
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_NAME=projectname
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURMD_NODENAME=n0067.savio1
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_TOPOLOGY_ADDR=ib-savio.ib-savio-02.n0067.savio1
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: HOSTNAME=n0067.savio1
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_PRIO_PROCESS=0
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_NODE_ALIASES=(null)
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SHELL=/bin/bash
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: TERM=xterm-color
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_QOS=savio_normal
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: CLICOLOR=1
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_TOPOLOGY_ADDR_PATTERN=switch.switch.node
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_libexecdir=/usr/libexec
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_libexecdir
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_COMMAND=exec
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_COMMAND
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_NNODES=1
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: USER=myashar
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_MESSAGELEVEL=5
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_MESSAGELEVEL
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOBID=4814495
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: JPY_PARENT_PID=425707
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_version=2.6-dist
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_version
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: PAGER=cat
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_TASKS_PER_NODE=20
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: PATH=/bin:/usr/bin:/usr/local/bin:/sbin:/usr/sbin:/usr/local/sbin
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_localstatedir=/var
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_localstatedir
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_WORKING_CLUSTER=brc:master:6817:8192
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_ID=4814495
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_USER=myashar
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: PWD=/global/scratch/myashar/projectname
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SINGULARITYENV_HISTFILE=
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: MPLBACKEND=module://ipykernel.pylab.backend_inline
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SINGULARITYENV_PATH=/bin:/sbin:/usr/bin:/usr/sbin:/usr/local/bin:/usr/local/sbin
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_UID=43974
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_NODEID=0
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_SUBMIT_DIR=/global/scratch/myashar/projectname
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: QT_QPA_PLATFORM=offscreen
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_TASK_PID=103765
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_CPUS_ON_NODE=20
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_PROCID=0
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: ENVIRONMENT=BATCH
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_NODELIST=n0067.savio1
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: HOME=/global/home/users/myashar
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SHLVL=2
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_LOCALID=0
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_GID=501
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_CPUS_PER_NODE=20
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_CLUSTER_NAME=brc
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_GTIDS=0
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_SUBMIT_HOST=jupyter.brc
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_PARTITION=savio
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_sysconfdir=/etc
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_sysconfdir
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_bindir=/usr/bin
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_bindir
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_ACCOUNT=ac_scsguest
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_NUM_NODES=1
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_IMAGE=/global/scratch/myashar/container/photoscan_1_4_3.simg
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_IMAGE
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: GIT_PAGER=cat
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Evaluating envar to clean: SLURM_MEM_PER_NODE=64000
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Transposing environment
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Converting envar 'SINGULARITYENV_HISTFILE' to 'HISTFILE' = '(null)'
# DEBUG   [U=43974,P=103815] envar_set()                               Unsetting environment variable: HISTFILE
# DEBUG   [U=43974,P=103815] singularity_runtime_environment()         Converting envar 'SINGULARITYENV_PATH' to 'PATH' = '/bin:/sbin:/usr/bin:/usr/sbin:/usr/local/bin:/usr/local/sbin'
# DEBUG   [U=43974,P=103815] envar_set()                               Setting environment variable: 'PATH' = '/bin:/sbin:/usr/bin:/usr/sbin:/usr/local/bin:/usr/local/sbin'
# DEBUG   [U=43974,P=103815] singularity_priv_drop_perm()              Called singularity_priv_drop_perm(void)
# DEBUG   [U=43974,P=103815] singularity_priv_drop_perm()              Escalating permissison so we can properly drop permission
# DEBUG   [U=43974,P=103815] singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=103815]     singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=103815]     singularity_priv_drop_perm()              Resetting supplementary groups
# DEBUG   [U=0,P=103815]     singularity_priv_drop_perm()              Dropping to group ID '501'
# DEBUG   [U=0,P=103815]     singularity_priv_drop_perm()              Dropping real and effective privileges to GID = '501'
# DEBUG   [U=0,P=103815]     singularity_priv_drop_perm()              Dropping real and effective privileges to UID = '43974'
# DEBUG   [U=43974,P=103815] singularity_priv_drop_perm()              Confirming we have correct GID
# DEBUG   [U=43974,P=103815] singularity_priv_drop_perm()              Confirming we have correct UID
# DEBUG   [U=43974,P=103815] singularity_priv_check_nonewprivs()       Setting NO_NEW_PRIVS to prevent future privilege escalations.
# DEBUG   [U=43974,P=103815] singularity_priv_drop_perm()              Finished dropping privileges
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'PIDNS_ENABLED'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'TARGET_PWD'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=103815] main()                                    Attempting to chdir to CWD: /global/scratch/myashar/projectname
# VERBOSE [U=43974,P=103815] main()                                    Could not chdir to current dir: /global/scratch/myashar/projectname
# WARNING [U=43974,P=103815] main()                                    Could not chdir to home: /global/home/users/myashar
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning value from registry: 'COMMAND' = 'exec'
# DEBUG   [U=43974,P=103815] envar_set()                               Setting environment variable: 'SINGULARITY_CONTAINER' = 'photoscan_1_4_3.simg'
# DEBUG   [U=43974,P=103815] envar_set()                               Setting environment variable: 'SINGULARITY_NAME' = 'photoscan_1_4_3.simg'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'SHELL'
# DEBUG   [U=43974,P=103815] envar_set()                               Unsetting environment variable: SINGULARITY_SHELL
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'APPNAME'
# DEBUG   [U=43974,P=103815] envar_set()                               Unsetting environment variable: SINGULARITY_APPNAME
# DEBUG   [U=43974,P=103815] fd_cleanup()                              Cleanup file descriptor table
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=103815] singularity_registry_get()                Returning value from registry: 'COMMAND' = 'exec'
# LOG     [U=43974,P=103815] main()                                    USER=myashar, IMAGE='photoscan_1_4_3.simg', COMMAND='exec'
# DEBUG   [U=43974,P=103815] action_exec()                             Checking for: /.singularity.d/actions/exec
# VERBOSE [U=43974,P=103815] action_exec()                             Exec'ing /.singularity.d/actions/exec
# start time:  1563669264.2668166
# LoadProject: path = /scratch//projectname.psx
# loaded project in 0.108683 sec
# BuildUV: mapping mode = Generic, texture count = 1
# Packing 50 charts
# Parameterizing done in 39.0857 sec
# CalibrateColors: source data = Model
# collecting control points... collected 137567 points in 1.08052 sec
# analyzing model... ******************** done in 0.23541 sec
# analyzing 20 images... ******************** done in 0.706361 sec
# estimating corrections...
# disabled 1408 out of 132548 points (rms error 0.0722249)
# adjusting: xxxxxxx 0.0682595 -> 0.0555103
# adjusting: xxxxxxxx 0.0695461 -> 0.0553696
# adjusting: xxxxxxxx 0.068948 -> 0.0542193
# disabled 3740 out of 132548 points (rms error 0.0537647)
# adjusting: xxxxxx 0.0491485 -> 0.0482608
# adjusting: xxxxxx 0.0487021 -> 0.0477439
# adjusting: xxxxxxx 0.0474039 -> 0.0463474
# disabled 4915 out of 132548 points (rms error 0.0468758)
# adjusting: xxxxxx 0.0459288 -> 0.0455199
# adjusting: xxxxxx 0.0453782 -> 0.044954
# adjusting: xxxxxx 0.0439151 -> 0.043448
# finished RBA in 20.3747 seconds
# BuildTexture: blending mode = Mosaic, texture size = 2048, fill holes = 1, ghosting filter = 1
# calculating mesh connectivity... done in 0.102164 sec
# detecting outliers... ******************** done in 9.46008 sec
# estimating quality... ******************** done in 11.3318 sec
# blending textures...  ******************** done in 11.998 sec
# postprocessing atlas... done in 0.385161 sec
# SaveProject: path = /scratch//projectname.psx
# saved project in 0.113171 sec
# LoadProject: path = /scratch//projectname.psx
# loaded project in 0.012539 sec
# LoadProject: path = /scratch//projectname.psx
# loaded project in 0.010909 sec
# BuildOrthomosaic: projection = Planar, surface = Mesh, blending mode = Mosaic, resolution = 0
# tessellating mesh... done (306642 -> 306642 faces)
# generating 2899x3459 orthomosaic (6 levels, 0.000348132 resolution)
# selected 20 cameras
# Orthorectifying 20 images
# IMG_0327: 2899x3459 -> 2676x3163
# IMG_0326: 2899x3459 -> 2090x3184
# IMG_0330: 2899x3408 -> 2864x3053
# IMG_0328: 2899x3459 -> 2888x3112
# IMG_0329: 2899x3459 -> 2890x3021
# IMG_0331: 2899x3408 -> 2836x3112
# IMG_0332: 2899x3408 -> 2844x3176
# IMG_0333: 2899x3408 -> 2844x3176
# IMG_0335: 2889x3408 -> 2011x3176
# IMG_0346: 2899x3459 -> 2458x3266
# IMG_0338: 2899x3459 -> 2794x3151
# IMG_0339: 2899x3459 -> 2858x3150
# IMG_0340: 2899x3459 -> 2888x3202
# IMG_0342: 2899x3459 -> 2899x3266
# IMG_0341: 2899x3459 -> 2899x3266
# IMG_0325: 2899x3459 -> 2029x3202
# IMG_0334: 2899x3408 -> 2844x3176
# IMG_0324: 2899x3459 -> 1897x3266
# IMG_0336: 2889x3408 -> 2050x3112
# IMG_0337: 2899x3408 -> 2229x3176
# Finished orthorectification in 9.95988 sec
# selected 1 tiles
# selected 1 tiles
# 20 of 20 processed in 1.28607 sec
# partition updated in 1.49285 sec
# selected 2 tiles
# loaded partition in 0.078006 sec
# boundaries extracted in 0.025828 sec
# 18 images blended in 2.27716 sec
# orthomosaic updated in 2.84187 sec
# SaveProject: path = /scratch//projectname.psx
# saved project in 0.015501 sec
# LoadProject: path = /scratch//projectname.psx
# loaded project in 0.019046 sec
# stop time:  1563669376.916963

# %% [markdown]
# ## Update project on Box

# %%
update_project_file_in_box()
# Out:
# find_folder_id folder_name:  myBoxFolderName
# find_folder_id folderlist:  [<Box Folder - 53223729428 (myBoxFolderName)>, <Box Folder - 52394687398 (myBoxFolderName_Test1)>]
# Box folder id:  53223729428
# project file list:  [<Box File - 317022687393 (projectname.psx)>]
# datazip file list:  [<Box File - 317017752277 (projectname.files.zip)>, <Box File - 319186364581 (README.docx)>, <Box File - 319043117371 (slurm-generate_model_output.txt)>, <Box File - 319044387168 (slurm-build_texture.txt)>, <Box File - 319044323866 (slurm-export_photomosaic_format_output.txt)>, <Box File - 319035518579 (slurm-export_dense_cloud.txt)>, <Box File - 319043284628 (slurm-pull_images_from_Box.txt)>, <Box File - 319043305927 (slurm-build_dense_cloud.txt)>, <Box File - 319041408570 (slurm-build_mesh.txt)>]
# project file id:  317022687393
# data zip file list:  317017752277
# begin project file update.
# update psx result:  <Box File - 317022687393>    update zip result:  <Box File - 317017752277>

# %% [markdown]
# # Export results

# %% [markdown]
# ## Export the orthomosaic

# %% [markdown]
# ## Choose parameters
# Choose the image format after running the next code box.

# %%
# QUINN guessing at some of these extensions
ifextension = {'ImageFormatJPEG':'.jpg', 'ImageFormatTIFF':'.tiff', 'ImageFormatPNG':'.png', 'ImageFormatBMP':'.bmp', 'ImageFormatEXR':'.exr',
'ImageFormatPNM':'.pnm', 'ImageFormatSGI':'.sgi', 'ImageFormatCR2':'.cr2', 'ImageFormatSEQ':'.seq', 'ImageFormatARA':'.ara'}

ifchoice=widgets.Dropdown(description='Image Format', value='ImageFormatTIFF', options=['ImageFormatJPEG', 'ImageFormatTIFF', 'ImageFormatPNG', 'ImageFormatBMP', 'ImageFormatEXR',
'ImageFormatPNM', 'ImageFormatSGI', 'ImageFormatCR2', 'ImageFormatSEQ', 'ImageFormatARA'] )

# %%
interact(chc, txt=ifchoice)
# Out:
# interactive(children=(Dropdown(description='Image Format', index=1, options=('ImageFormatJPEG', 'ImageFormatTI…
# <function __main__.chc(txt)>

# %%
template = '#!/usr/bin/env python3 \n\
import PhotoScan \n\
doc = PhotoScan.app.document \n\
doc.open(\"{}\") \n\
chunk = doc.chunk \n\
chunk.exportOrthomosaic(path=\"{}\", image_format=PhotoScan.ImageFormat.{},)  \n' 

orthoFile = projectname + ifextension[ifchoice.value]
output = template.format(singularitymountfolder + projectFile,  singularitymountfolder + orthoFile, ifchoice.value)

print('output:', output)

with open(commandScript, 'w') as f:
    f.write(output)
# Out:
# output: #!/usr/bin/env python3
# import PhotoScan
# doc = PhotoScan.app.document
# doc.open("/scratch//projectname.psx")
# chunk = doc.chunk
# chunk.exportOrthomosaic(path="/scratch/projectname.tiff", image_format=PhotoScan.ImageFormat.ImageFormatTIFF,)

# %% [markdown]
# ## Submit job to export the orthomosaic format output

# %%
out = !sbatch slurmscript.sh   
        
print (' Export the orthomosaic format output: ', out ) 
jobId =  out[0].split()[3]
print (jobId)
# Out:
#  Export the orthomosaic format output:  ['Submitted batch job 4814740']
# 4814740

# %%
# print the users queue and the job status by id
# !squeue -u $username
print('--------------------------------')
# !scontrol show job $jobId
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
# --------------------------------
# JobId=4814740 JobName=projectname
#    UserId=myashar(43974) GroupId=ucb(501) MCS_label=N/A
#    Priority=1001000 Nice=0 Account=ac_scsguest QOS=savio_normal
#    JobState=COMPLETED Reason=None Dependency=(null)
#    Requeue=0 Restarts=0 BatchFlag=1 Reboot=0 ExitCode=0:0
#    RunTime=00:00:06 TimeLimit=00:30:00 TimeMin=N/A
#    SubmitTime=2019-07-21T00:23:20 EligibleTime=2019-07-21T00:23:20
#    StartTime=2019-07-21T00:23:20 EndTime=2019-07-21T00:23:26 Deadline=N/A
#    PreemptTime=None SuspendTime=None SecsPreSuspend=0
#    LastSchedEval=2019-07-21T00:23:20
#    Partition=savio AllocNode:Sid=jupyter:425871
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=n0015.savio1
#    BatchHost=n0015.savio1
#    NumNodes=1 NumCPUs=20 NumTasks=0 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    TRES=cpu=20,mem=62.50G,node=1,billing=20
#    Socks/Node=* NtasksPerN:B:S:C=0:0:*:* CoreSpec=*
#    MinCPUsNode=1 MinMemoryNode=62.50G MinTmpDiskNode=0
#    Features=(null) DelayBoot=00:00:00
#    Gres=(null) Reservation=(null)
#    OverSubscribe=NO Contiguous=0 Licenses=(null) Network=(null)
#    Command=/global/scratch/myashar/projectname/slurmscript.sh
#    WorkDir=/global/scratch/myashar/projectname
#    StdErr=/global/scratch/myashar/projectname/slurm-4814740.out
#    StdIn=/dev/null
#    StdOut=/global/scratch/myashar/projectname/slurm-4814740.out
#    Power=

# %% [markdown]
# ## Display log message
#
# As an optional step, you can run the code below to see the log file once the job is done.

# %%
# print the log file if necessary
slurmlogfilename = 'slurm-' + jobId + '.out'
with open(slurmlogfilename, 'r') as fin:
    print(fin.read(), end="")
# Out:
# Enabling debugging
# Ending argument loop
# Singularity version: 2.6-dist
# Exec'ing: /usr/libexec/singularity/cli/exec.exec
# Evaluating args: '-B /global/scratch/myashar/projectname/:/scratch/ /global/scratch/myashar/container/photoscan_1_4_3.simg /scratch/execscript.sh -platform offscreen'
# VERBOSE [U=43974,P=72899]  message_init()                            Set messagelevel to: 5
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Initialize configuration file: /etc/singularity/singularity.conf
# DEBUG   [U=43974,P=72899]  singularity_config_parse()                Starting parse of configuration file /etc/singularity/singularity.conf
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key allow setuid = 'yes'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key max loop devices = '256'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key allow pid ns = 'yes'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key config passwd = 'yes'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key config group = 'yes'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key config resolv_conf = 'yes'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key mount proc = 'yes'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key mount sys = 'yes'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key mount dev = 'yes'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key mount devpts = 'yes'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key mount home = 'no'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key mount tmp = 'yes'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key mount hostfs = 'no'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key bind path = '/etc/localtime'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key bind path = '/etc/hosts'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key bind path = '/global/scratch'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key bind path = '/global/home/users'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key user bind control = 'yes'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key enable overlay = 'no'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key mount slave = 'yes'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key sessiondir max size = '16'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key allow container squashfs = 'yes'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key allow container extfs = 'yes'
# VERBOSE [U=43974,P=72899]  singularity_config_parse()                Got config key allow container dir = 'yes'
# DEBUG   [U=43974,P=72899]  singularity_config_parse()                Finished parsing configuration file '/etc/singularity/singularity.conf'
# DEBUG   [U=43974,P=72899]  singularity_config_get_value_impl()       No configuration entry found for 'always use nv'; returning default value 'NULL'
# VERBOSE [U=0,P=72706]      message_init()                            Set messagelevel to: 5
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Initialize configuration file: /etc/singularity/singularity.conf
# DEBUG   [U=0,P=72706]      singularity_config_parse()                Starting parse of configuration file /etc/singularity/singularity.conf
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key allow setuid = 'yes'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key max loop devices = '256'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key allow pid ns = 'yes'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key config passwd = 'yes'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key config group = 'yes'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key config resolv_conf = 'yes'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key mount proc = 'yes'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key mount sys = 'yes'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key mount dev = 'yes'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key mount devpts = 'yes'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key mount home = 'no'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key mount tmp = 'yes'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key mount hostfs = 'no'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key bind path = '/etc/localtime'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key bind path = '/etc/hosts'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key bind path = '/global/scratch'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key bind path = '/global/home/users'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key user bind control = 'yes'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key enable overlay = 'no'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key mount slave = 'yes'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key sessiondir max size = '16'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key allow container squashfs = 'yes'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key allow container extfs = 'yes'
# VERBOSE [U=0,P=72706]      singularity_config_parse()                Got config key allow container dir = 'yes'
# DEBUG   [U=0,P=72706]      singularity_config_parse()                Finished parsing configuration file '/etc/singularity/singularity.conf'
# VERBOSE [U=0,P=72706]      singularity_registry_init()               Initializing Singularity Registry
# VERBOSE [U=0,P=72706]      singularity_registry_set()                Adding value to registry: 'LIBEXECDIR' = '/usr/libexec'
# DEBUG   [U=0,P=72706]      singularity_registry_set()                Returning singularity_registry_set(libexecdir, /usr/libexec) = 0
# VERBOSE [U=0,P=72706]      singularity_registry_set()                Adding value to registry: 'COMMAND' = 'exec'
# DEBUG   [U=0,P=72706]      singularity_registry_set()                Returning singularity_registry_set(COMMAND, exec) = 0
# VERBOSE [U=0,P=72706]      singularity_registry_set()                Adding value to registry: 'MESSAGELEVEL' = '5'
# DEBUG   [U=0,P=72706]      singularity_registry_set()                Returning singularity_registry_set(MESSAGELEVEL, 5) = 0
# VERBOSE [U=0,P=72706]      singularity_registry_set()                Adding value to registry: 'VERSION' = '2.6-dist'
# DEBUG   [U=0,P=72706]      singularity_registry_set()                Returning singularity_registry_set(version, 2.6-dist) = 0
# VERBOSE [U=0,P=72706]      singularity_registry_set()                Adding value to registry: 'LOCALSTATEDIR' = '/var'
# DEBUG   [U=0,P=72706]      singularity_registry_set()                Returning singularity_registry_set(localstatedir, /var) = 0
# VERBOSE [U=0,P=72706]      singularity_registry_set()                Adding value to registry: 'SYSCONFDIR' = '/etc'
# DEBUG   [U=0,P=72706]      singularity_registry_set()                Returning singularity_registry_set(sysconfdir, /etc) = 0
# VERBOSE [U=0,P=72706]      singularity_registry_set()                Adding value to registry: 'BINDPATH' = ',/global/scratch/myashar/projectname/:/scratch/'
# DEBUG   [U=0,P=72706]      singularity_registry_set()                Returning singularity_registry_set(BINDPATH, ,/global/scratch/myashar/projectname/:/scratch/) = 0
# VERBOSE [U=0,P=72706]      singularity_registry_set()                Adding value to registry: 'BINDIR' = '/usr/bin'
# DEBUG   [U=0,P=72706]      singularity_registry_set()                Returning singularity_registry_set(bindir, /usr/bin) = 0
# VERBOSE [U=0,P=72706]      singularity_registry_set()                Adding value to registry: 'IMAGE' = '/global/scratch/myashar/container/photoscan_1_4_3.simg'
# DEBUG   [U=0,P=72706]      singularity_registry_set()                Returning singularity_registry_set(IMAGE, /global/scratch/myashar/container/photoscan_1_4_3.simg) = 0
# DEBUG   [U=0,P=72706]      singularity_registry_get()                Returning NULL on 'HOME'
# DEBUG   [U=0,P=72706]      singularity_registry_get()                Returning NULL on 'TARGET_UID'
# DEBUG   [U=0,P=72706]      singularity_registry_get()                Returning NULL on 'TARGET_GID'
# DEBUG   [U=0,P=72706]      singularity_priv_init()                   Initializing user info
# DEBUG   [U=0,P=72706]      singularity_priv_init()                   Set the calling user's username to: myashar
# DEBUG   [U=0,P=72706]      singularity_priv_init()                   Marking uinfo structure as ready
# DEBUG   [U=0,P=72706]      singularity_priv_init()                   Obtaining home directory
# VERBOSE [U=0,P=72706]      singularity_priv_init()                   Set home (via getpwuid()) to: /global/home/users/myashar
# VERBOSE [U=0,P=72706]      singularity_suid_init()                   Running SUID program workflow
# VERBOSE [U=0,P=72706]      singularity_suid_init()                   Checking program has appropriate permissions
# VERBOSE [U=0,P=72706]      singularity_suid_init()                   Checking configuration file is properly owned by root
# VERBOSE [U=0,P=72706]      singularity_suid_init()                   Checking if singularity.conf allows us to run as suid
# DEBUG   [U=0,P=72706]      singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow setuid, yes)
# DEBUG   [U=0,P=72706]      singularity_config_get_value_impl()       Returning configuration value allow setuid='yes'
# DEBUG   [U=0,P=72706]      singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow setuid, yes) = 1
# DEBUG   [U=0,P=72706]      singularity_registry_get()                Returning NULL on 'NOSUID'
# VERBOSE [U=0,P=72706]      singularity_priv_userns()                 Invoking the user namespace
# DEBUG   [U=0,P=72706]      singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow user ns, yes)
# DEBUG   [U=0,P=72706]      singularity_config_get_value_impl()       No configuration entry found for 'allow user ns'; returning default value 'yes'
# DEBUG   [U=0,P=72706]      singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow user ns, yes) = 1
# VERBOSE [U=0,P=72706]      singularity_priv_userns()                 Not virtualizing USER namespace: running as SUID
# DEBUG   [U=0,P=72706]      singularity_priv_userns()                 Returning singularity_priv_init(void)
# DEBUG   [U=0,P=72706]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=72706]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=72706]  singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_multi_impl() No configuration entry found for 'autofs bug path'; returning default value ''
# VERBOSE [U=43974,P=72706]  singularity_runtime_autofs()              No autofs bug path in configuration, skipping
# VERBOSE [U=43974,P=72706]  singularity_registry_set()                Adding value to registry: 'DAEMON_START' = '(null)'
# DEBUG   [U=43974,P=72706]  singularity_registry_set()                Returning singularity_registry_set(DAEMON_START, (null)) = 0
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning value from registry: 'DAEMON_START' = '(null)'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=72706]  singularity_daemon_init()                 Not joining a daemon, daemon join not set
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'WRITABLE'
# VERBOSE [U=43974,P=72706]  main()                                    Instantiating read only container image object
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning value from registry: 'IMAGE' = '/global/scratch/myashar/container/photoscan_1_4_3.simg'
# DEBUG   [U=43974,P=72706]  singularity_image_init()                  Calling image_init for each file system module
# DEBUG   [U=43974,P=72706]  singularity_image_dir_init()              Opening file descriptor to directory: /global/scratch/myashar/container/photoscan_1_4_3.simg
# DEBUG   [U=43974,P=72706]  singularity_image_dir_init()              This is not a directory based image
# DEBUG   [U=43974,P=72706]  singularity_image_squashfs_init()         Checking if writable image requested
# DEBUG   [U=43974,P=72706]  singularity_image_squashfs_init()         Opening file descriptor to image: /global/scratch/myashar/container/photoscan_1_4_3.simg
# VERBOSE [U=43974,P=72706]  singularity_image_squashfs_init()         Checking that file pointer is a Singularity image
# DEBUG   [U=43974,P=72706]  singularity_image_squashfs_init()         Checking for magic in the top of the file
# VERBOSE [U=43974,P=72706]  singularity_image_squashfs_init()         File is a valid SquashFS image
# DEBUG   [U=43974,P=72706]  singularity_image_init()                  got image_init type for squashfs
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow container squashfs, yes)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value allow container squashfs='yes'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow container squashfs, yes) = 1
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       No configuration entry found for 'limit container paths'; returning default value 'NULL'
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       No configuration entry found for 'limit container owners'; returning default value 'NULL'
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       No configuration entry found for 'limit container groups'; returning default value 'NULL'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'CLEANUPDIR'
# VERBOSE [U=43974,P=72706]  singularity_registry_set()                Adding value to registry: 'CLEANUPD_FD' = '-1'
# DEBUG   [U=43974,P=72706]  singularity_registry_set()                Returning singularity_registry_set(CLEANUPD_FD, -1) = 0
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'NOSESSIONCLEANUP'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'NOCLEANUP'
# DEBUG   [U=43974,P=72706]  singularity_cleanupd()                    Not running a cleanup thread, no 'SINGULARITY_CLEANUPDIR' defined
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=72706]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_ipc()
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow ipc ns, yes)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       No configuration entry found for 'allow ipc ns'; returning default value 'yes'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow ipc ns, yes) = 1
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'UNSHARE_IPC'
# VERBOSE [U=43974,P=72706]  singularity_runtime_ns_ipc()              Not virtualizing IPC namespace on user request
# DEBUG   [U=43974,P=72706]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_pid()
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow pid ns, yes)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value allow pid ns='yes'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow pid ns, yes) = 1
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'UNSHARE_PID'
# VERBOSE [U=43974,P=72706]  singularity_runtime_ns_pid()              Not virtualizing PID namespace on user request
# DEBUG   [U=43974,P=72706]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_net()
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# VERBOSE [U=43974,P=72706]  singularity_runtime_ns_net()              Not virtualizing network namespace on user request
# DEBUG   [U=43974,P=72706]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_mnt()
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount slave, yes)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value mount slave='yes'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount slave, yes) = 1
# DEBUG   [U=43974,P=72706]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=72706]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=72706]      singularity_runtime_ns_mnt()              Virtualizing FS namespace
# DEBUG   [U=0,P=72706]      singularity_runtime_ns_mnt()              Virtualizing mount namespace
# DEBUG   [U=0,P=72706]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=72706]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=72706]  singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=72706]  singularity_runtime_ns_mnt()              Making mounts slave
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       No configuration entry found for 'memory fs type'; returning default value 'tmpfs'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=72706]  singularity_sessiondir()                  Setting sessiondir
# VERBOSE [U=43974,P=72706]  singularity_sessiondir()                  Using session directory: /var/singularity/mnt/session
# DEBUG   [U=43974,P=72706]  singularity_sessiondir()                  Checking for session directory: /var/singularity/mnt/session
# DEBUG   [U=43974,P=72706]  singularity_sessiondir()                  Obtaining the default sessiondir size
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value sessiondir max size='16'
# DEBUG   [U=43974,P=72706]  singularity_sessiondir()                  Converted sessiondir size to: 16
# DEBUG   [U=43974,P=72706]  singularity_sessiondir()                  Creating the sessiondir size mount option length
# DEBUG   [U=43974,P=72706]  singularity_sessiondir()                  Got size length of: 9
# DEBUG   [U=43974,P=72706]  singularity_sessiondir()                  Creating the sessiondir size mount option string
# DEBUG   [U=43974,P=72706]  singularity_sessiondir()                  Checking to make sure the string was allocated correctly
# DEBUG   [U=43974,P=72706]  singularity_sessiondir()                  Mounting sessiondir tmpfs: /var/singularity/mnt/session
# VERBOSE [U=43974,P=72706]  singularity_registry_set()                Adding value to registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=72706]  singularity_registry_set()                Returning singularity_registry_set(SESSIONDIR, /var/singularity/mnt/session) = 0
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=72706]  singularity_image_mount()                 Figuring out which mount module to use...
# DEBUG   [U=43974,P=72706]  singularity_image_mount()                 Calling squashfs_mount
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value max loop devices='256'
# DEBUG   [U=43974,P=72706]  singularity_image_bind()                  Entered singularity_image_bind()
# DEBUG   [U=43974,P=72706]  singularity_image_bind()                  Converting max_loop_devs_string to int: '256'
# DEBUG   [U=43974,P=72706]  singularity_image_bind()                  Converted max_loop_devs_string to int: '256' -> 256
# DEBUG   [U=43974,P=72706]  singularity_image_bind()                  Checking if this image has been properly opened
# DEBUG   [U=43974,P=72706]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=72706]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=72706]      singularity_image_bind()                  Finding next available loop device...
# DEBUG   [U=0,P=72706]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=72706]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=72706]  singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=72706]  singularity_image_bind()                  Found available loop device: /dev/loop0
# DEBUG   [U=43974,P=72706]  singularity_image_bind()                  Setting LO_FLAGS_AUTOCLEAR
# DEBUG   [U=43974,P=72706]  singularity_image_bind()                  Using image offset: 31
# DEBUG   [U=43974,P=72706]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=72706]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=72706]      singularity_image_bind()                  Setting loop device flags
# DEBUG   [U=0,P=72706]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=72706]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=72706]  singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=72706]  singularity_image_bind()                  Using loop device: /dev/loop0
# VERBOSE [U=43974,P=72706]  singularity_image_squashfs_mount()        Mounting squashfs image: /dev/loop0 -> /var/singularity/mnt/container
# DEBUG   [U=43974,P=72706]  action_ready()                            Checking if container is valid at: /var/singularity/mnt/container
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=72706]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=72706]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=72706]      singularity_runtime_overlayfs()           Creating overlay_final directory: /var/singularity/mnt/final
# DEBUG   [U=0,P=72706]      s_mkpath()                                Directory exists, returning '0': /var/singularity/mnt/final
# DEBUG   [U=0,P=72706]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=72706]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=72706]  singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=72706]  singularity_registry_set()                Adding value to registry: 'OVERLAYFS_ENABLED' = '(null)'
# DEBUG   [U=43974,P=72706]  singularity_registry_set()                Returning singularity_registry_set(OVERLAYFS_ENABLED, (null)) = 0
# DEBUG   [U=43974,P=72706]  singularity_runtime_overlayfs()           Checking if overlayfs should be used
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value enable overlay='no'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(enable overlay, try)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value enable overlay='no'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(enable overlay, try) = 0
# VERBOSE [U=43974,P=72706]  singularity_runtime_overlayfs()           Not enabling overlayFS via configuration
# DEBUG   [U=43974,P=72706]  singularity_runtime_overlayfs()           Binding container directory to final home /var/singularity/mnt/container->/var/singularity/mnt/final
# DEBUG   [U=43974,P=72706]  container_statdir_update()                Get stat for container directories
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# VERBOSE [U=43974,P=72706]  singularity_runtime_mounts()              Running all mount components
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value mount dev='yes'
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_dev()           Checking configuration file for 'mount dev'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount dev, yes)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value mount dev='yes'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount dev, yes) = 1
# VERBOSE [U=43974,P=72706]  singularity_runtime_mount_dev()           Bind mounting /dev
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_kernelfs()      Checking configuration file for 'mount proc'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount proc, yes)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value mount proc='yes'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount proc, yes) = 1
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'PIDNS_ENABLED'
# VERBOSE [U=43974,P=72706]  singularity_runtime_mount_kernelfs()      Bind-mounting host /proc
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_kernelfs()      Checking configuration file for 'mount sys'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount sys, yes)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value mount sys='yes'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount sys, yes) = 1
# VERBOSE [U=43974,P=72706]  singularity_runtime_mount_kernelfs()      Mounting /sys
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount hostfs, no)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value mount hostfs='no'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount hostfs, no) = 0
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_hostfs()        Not mounting host file systems per configuration
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_binds()         Checking configuration file for 'bind path'
# VERBOSE [U=43974,P=72706]  singularity_runtime_mount_binds()         Found 'bind path' = /etc/localtime, /etc/localtime
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /etc/localtime
# DEBUG   [U=43974,P=72706]  check_mounted()                           Checking if currently mounted: /etc/localtime
# DEBUG   [U=43974,P=72706]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=72706]  check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=72706]  singularity_runtime_mount_binds()         Binding '/etc/localtime' to '/var/singularity/mnt/final//etc/localtime'
# VERBOSE [U=43974,P=72706]  singularity_mount()                       Ignored, try to mount /var/singularity/mnt/final/etc/localtime outside of container /usr/share/zoneinfo/Etc/UTC
# VERBOSE [U=43974,P=72706]  singularity_mount()                       Ignored, try to mount /var/singularity/mnt/final/etc/localtime outside of container /usr/share/zoneinfo/Etc/UTC
# VERBOSE [U=43974,P=72706]  singularity_runtime_mount_binds()         Found 'bind path' = /etc/hosts, /etc/hosts
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /etc/hosts
# DEBUG   [U=43974,P=72706]  check_mounted()                           Checking if currently mounted: /etc/hosts
# DEBUG   [U=43974,P=72706]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=72706]  check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=72706]  singularity_runtime_mount_binds()         Binding '/etc/hosts' to '/var/singularity/mnt/final//etc/hosts'
# VERBOSE [U=43974,P=72706]  singularity_runtime_mount_binds()         Found 'bind path' = /global/scratch, /global/scratch
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /global/scratch
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning value from registry: 'OVERLAYFS_ENABLED' = '(null)'
# WARNING [U=43974,P=72706]  singularity_runtime_mount_binds()         Non existent bind point (directory) in container: '/global/scratch'
# VERBOSE [U=43974,P=72706]  singularity_runtime_mount_binds()         Found 'bind path' = /global/home/users, /global/home/users
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /global/home/users
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning value from registry: 'OVERLAYFS_ENABLED' = '(null)'
# WARNING [U=43974,P=72706]  singularity_runtime_mount_binds()         Non existent bind point (directory) in container: '/global/home/users'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_home()          Checking that home directry is configured: /global/home/users/myashar
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_home()          Checking if home directories are being influenced by user
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'NOHOME'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'HOME'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount home, yes)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value mount home='no'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount home, yes) = 0
# VERBOSE [U=43974,P=72706]  singularity_runtime_mount_home()          Skipping home dir mounting (per config)
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_userbinds()     Checking for environment variable 'SINGULARITY_BINDPATH'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning value from registry: 'BINDPATH' = ',/global/scratch/myashar/projectname/:/scratch/'
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_userbinds()     Checking for 'user bind control' in config
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(user bind control, yes)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value user bind control='yes'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(user bind control, yes) = 1
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_userbinds()     Parsing SINGULARITY_BINDPATH for user-specified bind mounts.
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_userbinds()     Found bind: /global/scratch/myashar/projectname/ -> container:/scratch/
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_userbinds()     Checking if bind point is already mounted: /scratch/
# DEBUG   [U=43974,P=72706]  check_mounted()                           Checking if currently mounted: /scratch/
# DEBUG   [U=43974,P=72706]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=72706]  check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=72706]  singularity_runtime_mount_userbinds()     Binding '/global/scratch/myashar/projectname/' to '/var/singularity/mnt/final//scratch/'
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_userbinds()     Unsetting environment variable 'SINGULARITY_BINDPATH'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount tmp, yes)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value mount tmp='yes'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount tmp, yes) = 1
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=72706]  check_mounted()                           Checking if currently mounted: /tmp
# DEBUG   [U=43974,P=72706]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=72706]  check_mounted()                           Iterating through /proc/mounts
# DEBUG   [U=43974,P=72706]  s_mkpath()                                Directory exists, returning '0': /tmp
# VERBOSE [U=43974,P=72706]  singularity_runtime_mount_tmp()           Mounting directory: /tmp
# DEBUG   [U=43974,P=72706]  check_mounted()                           Checking if currently mounted: /var/tmp
# DEBUG   [U=43974,P=72706]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=72706]  check_mounted()                           Iterating through /proc/mounts
# DEBUG   [U=43974,P=72706]  s_mkpath()                                Directory exists, returning '0': /var/tmp
# VERBOSE [U=43974,P=72706]  singularity_runtime_mount_tmp()           Mounting directory: /var/tmp
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_scratch()       Getting SINGULARITY_SCRATCHDIR from environment
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'SCRATCHDIR'
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_scratch()       Not mounting scratch directory: Not requested
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_cwd()           Checking to see if we should mount current working directory
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_cwd()           Getting current working directory
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_cwd()           Checking for contain option
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=72706]  singularity_runtime_mount_cwd()           Checking if current directory already available within container: /global/scratch/myashar/projectname
# VERBOSE [U=43974,P=72706]  singularity_runtime_mount_cwd()           Not mounting CWD, directory does not exist within container: /global/scratch/myashar/projectname
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# VERBOSE [U=43974,P=72706]  singularity_runtime_files()               Running file components
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=72706]  singularity_runtime_files_passwd()        Called singularity_file_passwd_create()
# DEBUG   [U=43974,P=72706]  singularity_runtime_files_passwd()        Checking configuration option: 'config passwd'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config passwd, yes)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value config passwd='yes'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config passwd, yes) = 1
# VERBOSE [U=43974,P=72706]  singularity_runtime_files_passwd()        Checking for template passwd file: /var/singularity/mnt/final/etc/passwd
# VERBOSE [U=43974,P=72706]  singularity_runtime_files_passwd()        Creating template of /etc/passwd
# DEBUG   [U=43974,P=72706]  copy_file()                               Called copy_file(/var/singularity/mnt/final/etc/passwd, /var/singularity/mnt/session/passwd)
# DEBUG   [U=43974,P=72706]  copy_file()                               Opening source file: /var/singularity/mnt/final/etc/passwd
# DEBUG   [U=43974,P=72706]  copy_file()                               Opening destination file: /var/singularity/mnt/session/passwd
# DEBUG   [U=43974,P=72706]  copy_file()                               Calling fstat() on source file descriptor: 6
# DEBUG   [U=43974,P=72706]  copy_file()                               Cloning permission string of source to dest
# DEBUG   [U=43974,P=72706]  copy_file()                               Copying file data...
# DEBUG   [U=43974,P=72706]  copy_file()                               Done copying data, closing file pointers
# DEBUG   [U=43974,P=72706]  copy_file()                               Returning copy_file(/var/singularity/mnt/final/etc/passwd, /var/singularity/mnt/session/passwd) = 0
# VERBOSE [U=43974,P=72706]  singularity_runtime_files_passwd()        Creating template passwd file and appending user data: /var/singularity/mnt/session/passwd
# DEBUG   [U=43974,P=72706]  container_file_bind()                     Called file_bind(/var/singularity/mnt/session/passwd, /etc/passwd)
# VERBOSE [U=43974,P=72706]  container_file_bind()                     Binding file '/var/singularity/mnt/session/passwd' to '/var/singularity/mnt/final/etc/passwd'
# DEBUG   [U=43974,P=72706]  envar_set()                               Setting environment variable: 'HOME' = '/global/home/users/myashar'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=72706]  singularity_runtime_files_group()         Called singularity_file_group_create()
# DEBUG   [U=43974,P=72706]  singularity_runtime_files_group()         Checking configuration option: 'config group'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config group, yes)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value config group='yes'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config group, yes) = 1
# VERBOSE [U=43974,P=72706]  singularity_runtime_files_group()         Creating template of /etc/group for containment
# DEBUG   [U=43974,P=72706]  copy_file()                               Called copy_file(/var/singularity/mnt/final/etc/group, /var/singularity/mnt/session/group)
# DEBUG   [U=43974,P=72706]  copy_file()                               Opening source file: /var/singularity/mnt/final/etc/group
# DEBUG   [U=43974,P=72706]  copy_file()                               Opening destination file: /var/singularity/mnt/session/group
# DEBUG   [U=43974,P=72706]  copy_file()                               Calling fstat() on source file descriptor: 6
# DEBUG   [U=43974,P=72706]  copy_file()                               Cloning permission string of source to dest
# DEBUG   [U=43974,P=72706]  copy_file()                               Copying file data...
# DEBUG   [U=43974,P=72706]  copy_file()                               Done copying data, closing file pointers
# DEBUG   [U=43974,P=72706]  copy_file()                               Returning copy_file(/var/singularity/mnt/final/etc/group, /var/singularity/mnt/session/group) = 0
# VERBOSE [U=43974,P=72706]  singularity_runtime_files_group()         Updating group file with user info
# DEBUG   [U=43974,P=72706]  singularity_runtime_files_group()         Getting supplementary group info
# DEBUG   [U=43974,P=72706]  singularity_runtime_files_group()         Skipping duplicate supplementary group
# VERBOSE [U=43974,P=72706]  singularity_runtime_files_group()         Found supplementary group membership in: 600
# VERBOSE [U=43974,P=72706]  singularity_runtime_files_group()         Adding user's supplementary group ('savio') info to template group file
# VERBOSE [U=43974,P=72706]  singularity_runtime_files_group()         Found supplementary group membership in: 6206
# VERBOSE [U=43974,P=72706]  singularity_runtime_files_group()         Adding user's supplementary group ('matlab') info to template group file
# VERBOSE [U=43974,P=72706]  singularity_runtime_files_group()         Found supplementary group membership in: 10000
# VERBOSE [U=43974,P=72706]  singularity_runtime_files_group()         Adding user's supplementary group ('ac_scsguest') info to template group file
# DEBUG   [U=43974,P=72706]  container_file_bind()                     Called file_bind(/var/singularity/mnt/session/group, /etc/group)
# VERBOSE [U=43974,P=72706]  container_file_bind()                     Binding file '/var/singularity/mnt/session/group' to '/var/singularity/mnt/final/etc/group'
# DEBUG   [U=43974,P=72706]  singularity_runtime_files_resolvconf()    Checking configuration option
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config resolv_conf, yes)
# DEBUG   [U=43974,P=72706]  singularity_config_get_value_impl()       Returning configuration value config resolv_conf='yes'
# DEBUG   [U=43974,P=72706]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config resolv_conf, yes) = 1
# DEBUG   [U=43974,P=72706]  container_file_bind()                     Called file_bind(/etc/resolv.conf, /etc/resolv.conf)
# VERBOSE [U=43974,P=72706]  container_file_bind()                     Binding file '/etc/resolv.conf' to '/var/singularity/mnt/final/etc/resolv.conf'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'CONTAINLIBS'
# VERBOSE [U=43974,P=72706]  singularity_runtime_enter()               Containing all rootfs components
# DEBUG   [U=43974,P=72706]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=72706]      singularity_priv_escalate()               Clearing supplementary GIDs.
# VERBOSE [U=0,P=72706]      singularity_runtime_enter_chroot()        Entering container file system root: /var/singularity/mnt/final
# DEBUG   [U=0,P=72706]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=72706]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=72706]  singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=72706]  singularity_runtime_enter_chroot()        Changing dir to '/' within the new root
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Cloning environment
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Counted 57 environment elements
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'CLEANENV'
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Cleaning environment
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_CHECKPOINT_IMAGE_DIR=/var/slurm/checkpoint
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NODELIST=n0015.savio1
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_NAME=projectname
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURMD_NODENAME=n0015.savio1
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_TOPOLOGY_ADDR=ib-savio.ib-savio-00.n0015.savio1
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: HOSTNAME=n0015.savio1
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_PRIO_PROCESS=0
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NODE_ALIASES=(null)
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SHELL=/bin/bash
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: TERM=xterm-color
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_QOS=savio_normal
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: CLICOLOR=1
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_TOPOLOGY_ADDR_PATTERN=switch.switch.node
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_libexecdir=/usr/libexec
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_libexecdir
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_COMMAND=exec
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_COMMAND
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NNODES=1
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: USER=myashar
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_MESSAGELEVEL=5
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_MESSAGELEVEL
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOBID=4814740
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: JPY_PARENT_PID=425707
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_version=2.6-dist
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_version
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: PAGER=cat
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_TASKS_PER_NODE=20
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: PATH=/bin:/usr/bin:/usr/local/bin:/sbin:/usr/sbin:/usr/local/sbin
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_localstatedir=/var
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_localstatedir
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_WORKING_CLUSTER=brc:master:6817:8192
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_ID=4814740
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_USER=myashar
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: PWD=/global/scratch/myashar/projectname
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITYENV_HISTFILE=
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: MPLBACKEND=module://ipykernel.pylab.backend_inline
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITYENV_PATH=/bin:/sbin:/usr/bin:/usr/sbin:/usr/local/bin:/usr/local/sbin
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_UID=43974
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NODEID=0
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_SUBMIT_DIR=/global/scratch/myashar/projectname
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: QT_QPA_PLATFORM=offscreen
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_TASK_PID=72611
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_CPUS_ON_NODE=20
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_PROCID=0
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: ENVIRONMENT=BATCH
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_NODELIST=n0015.savio1
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: HOME=/global/home/users/myashar
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SHLVL=2
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_LOCALID=0
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_GID=501
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_CPUS_PER_NODE=20
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_CLUSTER_NAME=brc
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_GTIDS=0
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_SUBMIT_HOST=jupyter.brc
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_PARTITION=savio
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_sysconfdir=/etc
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_sysconfdir
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_bindir=/usr/bin
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_bindir
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_ACCOUNT=ac_scsguest
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_NUM_NODES=1
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_IMAGE=/global/scratch/myashar/container/photoscan_1_4_3.simg
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_IMAGE
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: GIT_PAGER=cat
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_MEM_PER_NODE=64000
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Transposing environment
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Converting envar 'SINGULARITYENV_HISTFILE' to 'HISTFILE' = '(null)'
# DEBUG   [U=43974,P=72706]  envar_set()                               Unsetting environment variable: HISTFILE
# DEBUG   [U=43974,P=72706]  singularity_runtime_environment()         Converting envar 'SINGULARITYENV_PATH' to 'PATH' = '/bin:/sbin:/usr/bin:/usr/sbin:/usr/local/bin:/usr/local/sbin'
# DEBUG   [U=43974,P=72706]  envar_set()                               Setting environment variable: 'PATH' = '/bin:/sbin:/usr/bin:/usr/sbin:/usr/local/bin:/usr/local/sbin'
# DEBUG   [U=43974,P=72706]  singularity_priv_drop_perm()              Called singularity_priv_drop_perm(void)
# DEBUG   [U=43974,P=72706]  singularity_priv_drop_perm()              Escalating permissison so we can properly drop permission
# DEBUG   [U=43974,P=72706]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=72706]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=72706]      singularity_priv_drop_perm()              Resetting supplementary groups
# DEBUG   [U=0,P=72706]      singularity_priv_drop_perm()              Dropping to group ID '501'
# DEBUG   [U=0,P=72706]      singularity_priv_drop_perm()              Dropping real and effective privileges to GID = '501'
# DEBUG   [U=0,P=72706]      singularity_priv_drop_perm()              Dropping real and effective privileges to UID = '43974'
# DEBUG   [U=43974,P=72706]  singularity_priv_drop_perm()              Confirming we have correct GID
# DEBUG   [U=43974,P=72706]  singularity_priv_drop_perm()              Confirming we have correct UID
# DEBUG   [U=43974,P=72706]  singularity_priv_check_nonewprivs()       Setting NO_NEW_PRIVS to prevent future privilege escalations.
# DEBUG   [U=43974,P=72706]  singularity_priv_drop_perm()              Finished dropping privileges
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'PIDNS_ENABLED'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'TARGET_PWD'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=72706]  main()                                    Attempting to chdir to CWD: /global/scratch/myashar/projectname
# VERBOSE [U=43974,P=72706]  main()                                    Could not chdir to current dir: /global/scratch/myashar/projectname
# WARNING [U=43974,P=72706]  main()                                    Could not chdir to home: /global/home/users/myashar
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning value from registry: 'COMMAND' = 'exec'
# DEBUG   [U=43974,P=72706]  envar_set()                               Setting environment variable: 'SINGULARITY_CONTAINER' = 'photoscan_1_4_3.simg'
# DEBUG   [U=43974,P=72706]  envar_set()                               Setting environment variable: 'SINGULARITY_NAME' = 'photoscan_1_4_3.simg'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'SHELL'
# DEBUG   [U=43974,P=72706]  envar_set()                               Unsetting environment variable: SINGULARITY_SHELL
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'APPNAME'
# DEBUG   [U=43974,P=72706]  envar_set()                               Unsetting environment variable: SINGULARITY_APPNAME
# DEBUG   [U=43974,P=72706]  fd_cleanup()                              Cleanup file descriptor table
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=72706]  singularity_registry_get()                Returning value from registry: 'COMMAND' = 'exec'
# LOG     [U=43974,P=72706]  main()                                    USER=myashar, IMAGE='photoscan_1_4_3.simg', COMMAND='exec'
# DEBUG   [U=43974,P=72706]  action_exec()                             Checking for: /.singularity.d/actions/exec
# VERBOSE [U=43974,P=72706]  action_exec()                             Exec'ing /.singularity.d/actions/exec
# LoadProject: path = /scratch//projectname.psx
# loaded project in 0.250962 sec
# ExportRaster: image_format = TIFF, path = /scratch/projectname.tiff, tile_height = 0, tile_width = 0
# generating 2898 x 3459 raster in 1 x 1 tiles

# %% [markdown]
# ## Move the orthomosaic file to Box

# %%
newFolderId = find_folder_id(boxProjectFolder)
upload_folder = client.folder(folder_id=newFolderId).get()
orthoUploaded = upload_folder.upload( runFolder + orthoFile)  
print ("orthomosaic file: ", orthoFile)
print ("orthomosaic file id: ", orthoUploaded['id'] )
# Out:
# find_folder_id folder_name:  myBoxFolderName
# find_folder_id folderlist:  [<Box Folder - 53223729428 (myBoxFolderName)>, <Box Folder - 52394687398 (myBoxFolderName_Test1)>]
# orthomosaic file:  projectname.tiff
# orthomosaic file id:  494460543876

# %% [markdown]
# ## Generate the Model export

# %% [markdown]
# ## Choose parameters
# Choose the output file extensions and model formats after running the next code box.

# %%
# QUINN guessing at some of these extensions
mfextension = { 'ModelFormatOBJ':'.obj', 'ModelFormat3DS':'.3ds', 'ModelFormatVRML':'.vrml', 'ModelFormatPLY':'.ply', 'ModelFormatCOLLADA':'.col',
'ModelFormatU3D':'.u3d', 'ModelFormatPDF':'.pdf', 'ModelFormatDXF':'.dxf', 'ModelFormatFBX':'.fbx', 'ModelFormatKMZ':'.kmz',
'ModelFormatCTM':'.ctm', 'ModelFormatSTL':'.stl', 'ModelFormatDXF_3DF':'.3df', 'ModelFormatTLS':'.tls' }

mfchoice=widgets.Dropdown(description='Model Format', value='ModelFormatOBJ', options= ['ModelFormatOBJ', 'ModelFormat3DS', 'ModelFormatVRML', 'ModelFormatPLY', 'ModelFormatCOLLADA',
'ModelFormatU3D', 'ModelFormatPDF', 'ModelFormatDXF', 'ModelFormatFBX', 'ModelFormatKMZ',
'ModelFormatCTM', 'ModelFormatSTL', 'ModelFormatDXF_3DF', 'ModelFormatTLS'] )

# %%
interact(chc, txt=mfchoice)
# Out:
# interactive(children=(Dropdown(description='Model Format', options=('ModelFormatOBJ', 'ModelFormat3DS', 'Model…
# <function __main__.chc(txt)>

# %%
template = '#!/usr/bin/env python3 \n\
import PhotoScan \n\
doc = PhotoScan.app.document \n\
doc.open(\"{}\") \n\
chunk = doc.chunk \n\
chunk.exportModel(path=\"{}\", format=PhotoScan.ModelFormat.{})  \n' 

modelFile = projectname + mfextension[mfchoice.value]
output = template.format(singularitymountfolder + projectFile, singularitymountfolder + modelFile, mfchoice.value)
print('output:', output)

with open(commandScript, 'w') as f:
    f.write(output)
# Out:
# output: #!/usr/bin/env python3
# import PhotoScan
# doc = PhotoScan.app.document
# doc.open("/scratch//projectname.psx")
# chunk = doc.chunk
# chunk.exportModel(path="/scratch/projectname.obj", format=PhotoScan.ModelFormat.ModelFormatOBJ)

# %% [markdown]
# ## Submit job to generate model output

# %%
out = !sbatch slurmscript.sh   
        
print (' Generate model output: ', out ) 
jobId =  out[0].split()[3]
print (jobId)
# Out:
#  Generate model output:  ['Submitted batch job 4816678']
# 4816678

# %%
# print the users queue and the job status by id
# !squeue -u $username
print('--------------------------------')
# !scontrol show job $jobId
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
# --------------------------------
# JobId=4816678 JobName=projectname
#    UserId=myashar(43974) GroupId=ucb(501) MCS_label=N/A
#    Priority=304763 Nice=0 Account=ac_scsguest QOS=savio_normal
#    JobState=COMPLETED Reason=None Dependency=(null)
#    Requeue=0 Restarts=0 BatchFlag=1 Reboot=0 ExitCode=0:0
#    RunTime=00:00:06 TimeLimit=00:30:00 TimeMin=N/A
#    SubmitTime=2019-07-21T16:49:37 EligibleTime=2019-07-21T16:49:37
#    StartTime=2019-07-21T16:49:38 EndTime=2019-07-21T16:49:44 Deadline=N/A
#    PreemptTime=None SuspendTime=None SecsPreSuspend=0
#    LastSchedEval=2019-07-21T16:49:38
#    Partition=savio AllocNode:Sid=jupyter:425871
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=n0127.savio1
#    BatchHost=n0127.savio1
#    NumNodes=1 NumCPUs=20 NumTasks=0 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    TRES=cpu=20,mem=62.50G,node=1,billing=20
#    Socks/Node=* NtasksPerN:B:S:C=0:0:*:* CoreSpec=*
#    MinCPUsNode=1 MinMemoryNode=62.50G MinTmpDiskNode=0
#    Features=(null) DelayBoot=00:00:00
#    Gres=(null) Reservation=(null)
#    OverSubscribe=NO Contiguous=0 Licenses=(null) Network=(null)
#    Command=/global/scratch/myashar/projectname/slurmscript.sh
#    WorkDir=/global/scratch/myashar/projectname
#    StdErr=/global/scratch/myashar/projectname/slurm-4816678.out
#    StdIn=/dev/null
#    StdOut=/global/scratch/myashar/projectname/slurm-4816678.out
#    Power=

# %% [markdown]
# ## Display log message
#
# As an optional step, you can run the code below to see the log file once the job is done.

# %%
# print the log file if necessary
slurmlogfilename = 'slurm-' + jobId + '.out'
with open(slurmlogfilename, 'r') as fin:
    print(fin.read(), end="")
# Out:
# Enabling debugging
# Ending argument loop
# Singularity version: 2.6-dist
# Exec'ing: /usr/libexec/singularity/cli/exec.exec
# Evaluating args: '-B /global/scratch/myashar/projectname/:/scratch/ /global/scratch/myashar/container/photoscan_1_4_3.simg /scratch/execscript.sh -platform offscreen'
# VERBOSE [U=43974,P=29120]  message_init()                            Set messagelevel to: 5
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Initialize configuration file: /etc/singularity/singularity.conf
# DEBUG   [U=43974,P=29120]  singularity_config_parse()                Starting parse of configuration file /etc/singularity/singularity.conf
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key allow setuid = 'yes'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key max loop devices = '256'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key allow pid ns = 'yes'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key config passwd = 'yes'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key config group = 'yes'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key config resolv_conf = 'yes'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key mount proc = 'yes'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key mount sys = 'yes'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key mount dev = 'yes'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key mount devpts = 'yes'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key mount home = 'no'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key mount tmp = 'yes'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key mount hostfs = 'no'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key bind path = '/etc/localtime'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key bind path = '/etc/hosts'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key bind path = '/global/scratch'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key bind path = '/global/home/users'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key user bind control = 'yes'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key enable overlay = 'no'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key mount slave = 'yes'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key sessiondir max size = '16'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key allow container squashfs = 'yes'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key allow container extfs = 'yes'
# VERBOSE [U=43974,P=29120]  singularity_config_parse()                Got config key allow container dir = 'yes'
# DEBUG   [U=43974,P=29120]  singularity_config_parse()                Finished parsing configuration file '/etc/singularity/singularity.conf'
# DEBUG   [U=43974,P=29120]  singularity_config_get_value_impl()       No configuration entry found for 'always use nv'; returning default value 'NULL'
# VERBOSE [U=0,P=29082]      message_init()                            Set messagelevel to: 5
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Initialize configuration file: /etc/singularity/singularity.conf
# DEBUG   [U=0,P=29082]      singularity_config_parse()                Starting parse of configuration file /etc/singularity/singularity.conf
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key allow setuid = 'yes'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key max loop devices = '256'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key allow pid ns = 'yes'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key config passwd = 'yes'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key config group = 'yes'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key config resolv_conf = 'yes'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key mount proc = 'yes'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key mount sys = 'yes'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key mount dev = 'yes'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key mount devpts = 'yes'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key mount home = 'no'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key mount tmp = 'yes'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key mount hostfs = 'no'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key bind path = '/etc/localtime'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key bind path = '/etc/hosts'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key bind path = '/global/scratch'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key bind path = '/global/home/users'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key user bind control = 'yes'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key enable overlay = 'no'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key mount slave = 'yes'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key sessiondir max size = '16'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key allow container squashfs = 'yes'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key allow container extfs = 'yes'
# VERBOSE [U=0,P=29082]      singularity_config_parse()                Got config key allow container dir = 'yes'
# DEBUG   [U=0,P=29082]      singularity_config_parse()                Finished parsing configuration file '/etc/singularity/singularity.conf'
# VERBOSE [U=0,P=29082]      singularity_registry_init()               Initializing Singularity Registry
# VERBOSE [U=0,P=29082]      singularity_registry_set()                Adding value to registry: 'LIBEXECDIR' = '/usr/libexec'
# DEBUG   [U=0,P=29082]      singularity_registry_set()                Returning singularity_registry_set(libexecdir, /usr/libexec) = 0
# VERBOSE [U=0,P=29082]      singularity_registry_set()                Adding value to registry: 'COMMAND' = 'exec'
# DEBUG   [U=0,P=29082]      singularity_registry_set()                Returning singularity_registry_set(COMMAND, exec) = 0
# VERBOSE [U=0,P=29082]      singularity_registry_set()                Adding value to registry: 'MESSAGELEVEL' = '5'
# DEBUG   [U=0,P=29082]      singularity_registry_set()                Returning singularity_registry_set(MESSAGELEVEL, 5) = 0
# VERBOSE [U=0,P=29082]      singularity_registry_set()                Adding value to registry: 'VERSION' = '2.6-dist'
# DEBUG   [U=0,P=29082]      singularity_registry_set()                Returning singularity_registry_set(version, 2.6-dist) = 0
# VERBOSE [U=0,P=29082]      singularity_registry_set()                Adding value to registry: 'LOCALSTATEDIR' = '/var'
# DEBUG   [U=0,P=29082]      singularity_registry_set()                Returning singularity_registry_set(localstatedir, /var) = 0
# VERBOSE [U=0,P=29082]      singularity_registry_set()                Adding value to registry: 'SYSCONFDIR' = '/etc'
# DEBUG   [U=0,P=29082]      singularity_registry_set()                Returning singularity_registry_set(sysconfdir, /etc) = 0
# VERBOSE [U=0,P=29082]      singularity_registry_set()                Adding value to registry: 'BINDPATH' = ',/global/scratch/myashar/projectname/:/scratch/'
# DEBUG   [U=0,P=29082]      singularity_registry_set()                Returning singularity_registry_set(BINDPATH, ,/global/scratch/myashar/projectname/:/scratch/) = 0
# VERBOSE [U=0,P=29082]      singularity_registry_set()                Adding value to registry: 'BINDIR' = '/usr/bin'
# DEBUG   [U=0,P=29082]      singularity_registry_set()                Returning singularity_registry_set(bindir, /usr/bin) = 0
# VERBOSE [U=0,P=29082]      singularity_registry_set()                Adding value to registry: 'IMAGE' = '/global/scratch/myashar/container/photoscan_1_4_3.simg'
# DEBUG   [U=0,P=29082]      singularity_registry_set()                Returning singularity_registry_set(IMAGE, /global/scratch/myashar/container/photoscan_1_4_3.simg) = 0
# DEBUG   [U=0,P=29082]      singularity_registry_get()                Returning NULL on 'HOME'
# DEBUG   [U=0,P=29082]      singularity_registry_get()                Returning NULL on 'TARGET_UID'
# DEBUG   [U=0,P=29082]      singularity_registry_get()                Returning NULL on 'TARGET_GID'
# DEBUG   [U=0,P=29082]      singularity_priv_init()                   Initializing user info
# DEBUG   [U=0,P=29082]      singularity_priv_init()                   Set the calling user's username to: myashar
# DEBUG   [U=0,P=29082]      singularity_priv_init()                   Marking uinfo structure as ready
# DEBUG   [U=0,P=29082]      singularity_priv_init()                   Obtaining home directory
# VERBOSE [U=0,P=29082]      singularity_priv_init()                   Set home (via getpwuid()) to: /global/home/users/myashar
# VERBOSE [U=0,P=29082]      singularity_suid_init()                   Running SUID program workflow
# VERBOSE [U=0,P=29082]      singularity_suid_init()                   Checking program has appropriate permissions
# VERBOSE [U=0,P=29082]      singularity_suid_init()                   Checking configuration file is properly owned by root
# VERBOSE [U=0,P=29082]      singularity_suid_init()                   Checking if singularity.conf allows us to run as suid
# DEBUG   [U=0,P=29082]      singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow setuid, yes)
# DEBUG   [U=0,P=29082]      singularity_config_get_value_impl()       Returning configuration value allow setuid='yes'
# DEBUG   [U=0,P=29082]      singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow setuid, yes) = 1
# DEBUG   [U=0,P=29082]      singularity_registry_get()                Returning NULL on 'NOSUID'
# VERBOSE [U=0,P=29082]      singularity_priv_userns()                 Invoking the user namespace
# DEBUG   [U=0,P=29082]      singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow user ns, yes)
# DEBUG   [U=0,P=29082]      singularity_config_get_value_impl()       No configuration entry found for 'allow user ns'; returning default value 'yes'
# DEBUG   [U=0,P=29082]      singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow user ns, yes) = 1
# VERBOSE [U=0,P=29082]      singularity_priv_userns()                 Not virtualizing USER namespace: running as SUID
# DEBUG   [U=0,P=29082]      singularity_priv_userns()                 Returning singularity_priv_init(void)
# DEBUG   [U=0,P=29082]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=29082]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=29082]  singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_multi_impl() No configuration entry found for 'autofs bug path'; returning default value ''
# VERBOSE [U=43974,P=29082]  singularity_runtime_autofs()              No autofs bug path in configuration, skipping
# VERBOSE [U=43974,P=29082]  singularity_registry_set()                Adding value to registry: 'DAEMON_START' = '(null)'
# DEBUG   [U=43974,P=29082]  singularity_registry_set()                Returning singularity_registry_set(DAEMON_START, (null)) = 0
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning value from registry: 'DAEMON_START' = '(null)'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=29082]  singularity_daemon_init()                 Not joining a daemon, daemon join not set
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'WRITABLE'
# VERBOSE [U=43974,P=29082]  main()                                    Instantiating read only container image object
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning value from registry: 'IMAGE' = '/global/scratch/myashar/container/photoscan_1_4_3.simg'
# DEBUG   [U=43974,P=29082]  singularity_image_init()                  Calling image_init for each file system module
# DEBUG   [U=43974,P=29082]  singularity_image_dir_init()              Opening file descriptor to directory: /global/scratch/myashar/container/photoscan_1_4_3.simg
# DEBUG   [U=43974,P=29082]  singularity_image_dir_init()              This is not a directory based image
# DEBUG   [U=43974,P=29082]  singularity_image_squashfs_init()         Checking if writable image requested
# DEBUG   [U=43974,P=29082]  singularity_image_squashfs_init()         Opening file descriptor to image: /global/scratch/myashar/container/photoscan_1_4_3.simg
# VERBOSE [U=43974,P=29082]  singularity_image_squashfs_init()         Checking that file pointer is a Singularity image
# DEBUG   [U=43974,P=29082]  singularity_image_squashfs_init()         Checking for magic in the top of the file
# VERBOSE [U=43974,P=29082]  singularity_image_squashfs_init()         File is a valid SquashFS image
# DEBUG   [U=43974,P=29082]  singularity_image_init()                  got image_init type for squashfs
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow container squashfs, yes)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value allow container squashfs='yes'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow container squashfs, yes) = 1
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       No configuration entry found for 'limit container paths'; returning default value 'NULL'
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       No configuration entry found for 'limit container owners'; returning default value 'NULL'
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       No configuration entry found for 'limit container groups'; returning default value 'NULL'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'CLEANUPDIR'
# VERBOSE [U=43974,P=29082]  singularity_registry_set()                Adding value to registry: 'CLEANUPD_FD' = '-1'
# DEBUG   [U=43974,P=29082]  singularity_registry_set()                Returning singularity_registry_set(CLEANUPD_FD, -1) = 0
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'NOSESSIONCLEANUP'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'NOCLEANUP'
# DEBUG   [U=43974,P=29082]  singularity_cleanupd()                    Not running a cleanup thread, no 'SINGULARITY_CLEANUPDIR' defined
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=29082]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_ipc()
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow ipc ns, yes)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       No configuration entry found for 'allow ipc ns'; returning default value 'yes'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow ipc ns, yes) = 1
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'UNSHARE_IPC'
# VERBOSE [U=43974,P=29082]  singularity_runtime_ns_ipc()              Not virtualizing IPC namespace on user request
# DEBUG   [U=43974,P=29082]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_pid()
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(allow pid ns, yes)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value allow pid ns='yes'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(allow pid ns, yes) = 1
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'UNSHARE_PID'
# VERBOSE [U=43974,P=29082]  singularity_runtime_ns_pid()              Not virtualizing PID namespace on user request
# DEBUG   [U=43974,P=29082]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_net()
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# VERBOSE [U=43974,P=29082]  singularity_runtime_ns_net()              Not virtualizing network namespace on user request
# DEBUG   [U=43974,P=29082]  singularity_runtime_ns()                  Calling: _singularity_runtime_ns_mnt()
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount slave, yes)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value mount slave='yes'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount slave, yes) = 1
# DEBUG   [U=43974,P=29082]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=29082]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=29082]      singularity_runtime_ns_mnt()              Virtualizing FS namespace
# DEBUG   [U=0,P=29082]      singularity_runtime_ns_mnt()              Virtualizing mount namespace
# DEBUG   [U=0,P=29082]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=29082]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=29082]  singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=29082]  singularity_runtime_ns_mnt()              Making mounts slave
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       No configuration entry found for 'memory fs type'; returning default value 'tmpfs'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=29082]  singularity_sessiondir()                  Setting sessiondir
# VERBOSE [U=43974,P=29082]  singularity_sessiondir()                  Using session directory: /var/singularity/mnt/session
# DEBUG   [U=43974,P=29082]  singularity_sessiondir()                  Checking for session directory: /var/singularity/mnt/session
# DEBUG   [U=43974,P=29082]  singularity_sessiondir()                  Obtaining the default sessiondir size
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value sessiondir max size='16'
# DEBUG   [U=43974,P=29082]  singularity_sessiondir()                  Converted sessiondir size to: 16
# DEBUG   [U=43974,P=29082]  singularity_sessiondir()                  Creating the sessiondir size mount option length
# DEBUG   [U=43974,P=29082]  singularity_sessiondir()                  Got size length of: 9
# DEBUG   [U=43974,P=29082]  singularity_sessiondir()                  Creating the sessiondir size mount option string
# DEBUG   [U=43974,P=29082]  singularity_sessiondir()                  Checking to make sure the string was allocated correctly
# DEBUG   [U=43974,P=29082]  singularity_sessiondir()                  Mounting sessiondir tmpfs: /var/singularity/mnt/session
# VERBOSE [U=43974,P=29082]  singularity_registry_set()                Adding value to registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=29082]  singularity_registry_set()                Returning singularity_registry_set(SESSIONDIR, /var/singularity/mnt/session) = 0
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=29082]  singularity_image_mount()                 Figuring out which mount module to use...
# DEBUG   [U=43974,P=29082]  singularity_image_mount()                 Calling squashfs_mount
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value max loop devices='256'
# DEBUG   [U=43974,P=29082]  singularity_image_bind()                  Entered singularity_image_bind()
# DEBUG   [U=43974,P=29082]  singularity_image_bind()                  Converting max_loop_devs_string to int: '256'
# DEBUG   [U=43974,P=29082]  singularity_image_bind()                  Converted max_loop_devs_string to int: '256' -> 256
# DEBUG   [U=43974,P=29082]  singularity_image_bind()                  Checking if this image has been properly opened
# DEBUG   [U=43974,P=29082]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=29082]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=29082]      singularity_image_bind()                  Finding next available loop device...
# DEBUG   [U=0,P=29082]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=29082]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=29082]  singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=29082]  singularity_image_bind()                  Found available loop device: /dev/loop0
# DEBUG   [U=43974,P=29082]  singularity_image_bind()                  Setting LO_FLAGS_AUTOCLEAR
# DEBUG   [U=43974,P=29082]  singularity_image_bind()                  Using image offset: 31
# DEBUG   [U=43974,P=29082]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=29082]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=29082]      singularity_image_bind()                  Setting loop device flags
# DEBUG   [U=0,P=29082]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=29082]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=29082]  singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=29082]  singularity_image_bind()                  Using loop device: /dev/loop0
# VERBOSE [U=43974,P=29082]  singularity_image_squashfs_mount()        Mounting squashfs image: /dev/loop0 -> /var/singularity/mnt/container
# DEBUG   [U=43974,P=29082]  action_ready()                            Checking if container is valid at: /var/singularity/mnt/container
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=29082]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=29082]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=29082]      singularity_runtime_overlayfs()           Creating overlay_final directory: /var/singularity/mnt/final
# DEBUG   [U=0,P=29082]      s_mkpath()                                Directory exists, returning '0': /var/singularity/mnt/final
# DEBUG   [U=0,P=29082]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=29082]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=29082]  singularity_priv_drop()                   Confirming we have correct UID/GID
# VERBOSE [U=43974,P=29082]  singularity_registry_set()                Adding value to registry: 'OVERLAYFS_ENABLED' = '(null)'
# DEBUG   [U=43974,P=29082]  singularity_registry_set()                Returning singularity_registry_set(OVERLAYFS_ENABLED, (null)) = 0
# DEBUG   [U=43974,P=29082]  singularity_runtime_overlayfs()           Checking if overlayfs should be used
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value enable overlay='no'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(enable overlay, try)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value enable overlay='no'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(enable overlay, try) = 0
# VERBOSE [U=43974,P=29082]  singularity_runtime_overlayfs()           Not enabling overlayFS via configuration
# DEBUG   [U=43974,P=29082]  singularity_runtime_overlayfs()           Binding container directory to final home /var/singularity/mnt/container->/var/singularity/mnt/final
# DEBUG   [U=43974,P=29082]  container_statdir_update()                Get stat for container directories
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# VERBOSE [U=43974,P=29082]  singularity_runtime_mounts()              Running all mount components
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value mount dev='yes'
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_dev()           Checking configuration file for 'mount dev'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount dev, yes)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value mount dev='yes'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount dev, yes) = 1
# VERBOSE [U=43974,P=29082]  singularity_runtime_mount_dev()           Bind mounting /dev
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_kernelfs()      Checking configuration file for 'mount proc'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount proc, yes)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value mount proc='yes'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount proc, yes) = 1
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'PIDNS_ENABLED'
# VERBOSE [U=43974,P=29082]  singularity_runtime_mount_kernelfs()      Bind-mounting host /proc
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_kernelfs()      Checking configuration file for 'mount sys'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount sys, yes)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value mount sys='yes'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount sys, yes) = 1
# VERBOSE [U=43974,P=29082]  singularity_runtime_mount_kernelfs()      Mounting /sys
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount hostfs, no)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value mount hostfs='no'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount hostfs, no) = 0
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_hostfs()        Not mounting host file systems per configuration
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_binds()         Checking configuration file for 'bind path'
# VERBOSE [U=43974,P=29082]  singularity_runtime_mount_binds()         Found 'bind path' = /etc/localtime, /etc/localtime
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /etc/localtime
# DEBUG   [U=43974,P=29082]  check_mounted()                           Checking if currently mounted: /etc/localtime
# DEBUG   [U=43974,P=29082]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=29082]  check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=29082]  singularity_runtime_mount_binds()         Binding '/etc/localtime' to '/var/singularity/mnt/final//etc/localtime'
# VERBOSE [U=43974,P=29082]  singularity_mount()                       Ignored, try to mount /var/singularity/mnt/final/etc/localtime outside of container /usr/share/zoneinfo/Etc/UTC
# VERBOSE [U=43974,P=29082]  singularity_mount()                       Ignored, try to mount /var/singularity/mnt/final/etc/localtime outside of container /usr/share/zoneinfo/Etc/UTC
# VERBOSE [U=43974,P=29082]  singularity_runtime_mount_binds()         Found 'bind path' = /etc/hosts, /etc/hosts
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /etc/hosts
# DEBUG   [U=43974,P=29082]  check_mounted()                           Checking if currently mounted: /etc/hosts
# DEBUG   [U=43974,P=29082]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=29082]  check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=29082]  singularity_runtime_mount_binds()         Binding '/etc/hosts' to '/var/singularity/mnt/final//etc/hosts'
# VERBOSE [U=43974,P=29082]  singularity_runtime_mount_binds()         Found 'bind path' = /global/scratch, /global/scratch
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /global/scratch
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning value from registry: 'OVERLAYFS_ENABLED' = '(null)'
# WARNING [U=43974,P=29082]  singularity_runtime_mount_binds()         Non existent bind point (directory) in container: '/global/scratch'
# VERBOSE [U=43974,P=29082]  singularity_runtime_mount_binds()         Found 'bind path' = /global/home/users, /global/home/users
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_binds()         Checking if bind point is already mounted: /global/home/users
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning value from registry: 'OVERLAYFS_ENABLED' = '(null)'
# WARNING [U=43974,P=29082]  singularity_runtime_mount_binds()         Non existent bind point (directory) in container: '/global/home/users'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_home()          Checking that home directry is configured: /global/home/users/myashar
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_home()          Checking if home directories are being influenced by user
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'NOHOME'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'HOME'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount home, yes)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value mount home='no'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount home, yes) = 0
# VERBOSE [U=43974,P=29082]  singularity_runtime_mount_home()          Skipping home dir mounting (per config)
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_userbinds()     Checking for environment variable 'SINGULARITY_BINDPATH'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning value from registry: 'BINDPATH' = ',/global/scratch/myashar/projectname/:/scratch/'
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_userbinds()     Checking for 'user bind control' in config
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(user bind control, yes)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value user bind control='yes'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(user bind control, yes) = 1
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_userbinds()     Parsing SINGULARITY_BINDPATH for user-specified bind mounts.
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_userbinds()     Found bind: /global/scratch/myashar/projectname/ -> container:/scratch/
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_userbinds()     Checking if bind point is already mounted: /scratch/
# DEBUG   [U=43974,P=29082]  check_mounted()                           Checking if currently mounted: /scratch/
# DEBUG   [U=43974,P=29082]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=29082]  check_mounted()                           Iterating through /proc/mounts
# VERBOSE [U=43974,P=29082]  singularity_runtime_mount_userbinds()     Binding '/global/scratch/myashar/projectname/' to '/var/singularity/mnt/final//scratch/'
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_userbinds()     Unsetting environment variable 'SINGULARITY_BINDPATH'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(mount tmp, yes)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value mount tmp='yes'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(mount tmp, yes) = 1
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=29082]  check_mounted()                           Checking if currently mounted: /tmp
# DEBUG   [U=43974,P=29082]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=29082]  check_mounted()                           Iterating through /proc/mounts
# DEBUG   [U=43974,P=29082]  s_mkpath()                                Directory exists, returning '0': /tmp
# VERBOSE [U=43974,P=29082]  singularity_runtime_mount_tmp()           Mounting directory: /tmp
# DEBUG   [U=43974,P=29082]  check_mounted()                           Checking if currently mounted: /var/tmp
# DEBUG   [U=43974,P=29082]  check_mounted()                           Opening /proc/mounts
# DEBUG   [U=43974,P=29082]  check_mounted()                           Iterating through /proc/mounts
# DEBUG   [U=43974,P=29082]  s_mkpath()                                Directory exists, returning '0': /var/tmp
# VERBOSE [U=43974,P=29082]  singularity_runtime_mount_tmp()           Mounting directory: /var/tmp
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_scratch()       Getting SINGULARITY_SCRATCHDIR from environment
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'SCRATCHDIR'
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_scratch()       Not mounting scratch directory: Not requested
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_cwd()           Checking to see if we should mount current working directory
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_cwd()           Getting current working directory
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_cwd()           Checking for contain option
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=29082]  singularity_runtime_mount_cwd()           Checking if current directory already available within container: /global/scratch/myashar/projectname
# VERBOSE [U=43974,P=29082]  singularity_runtime_mount_cwd()           Not mounting CWD, directory does not exist within container: /global/scratch/myashar/projectname
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# VERBOSE [U=43974,P=29082]  singularity_runtime_files()               Running file components
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=29082]  singularity_runtime_files_passwd()        Called singularity_file_passwd_create()
# DEBUG   [U=43974,P=29082]  singularity_runtime_files_passwd()        Checking configuration option: 'config passwd'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config passwd, yes)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value config passwd='yes'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config passwd, yes) = 1
# VERBOSE [U=43974,P=29082]  singularity_runtime_files_passwd()        Checking for template passwd file: /var/singularity/mnt/final/etc/passwd
# VERBOSE [U=43974,P=29082]  singularity_runtime_files_passwd()        Creating template of /etc/passwd
# DEBUG   [U=43974,P=29082]  copy_file()                               Called copy_file(/var/singularity/mnt/final/etc/passwd, /var/singularity/mnt/session/passwd)
# DEBUG   [U=43974,P=29082]  copy_file()                               Opening source file: /var/singularity/mnt/final/etc/passwd
# DEBUG   [U=43974,P=29082]  copy_file()                               Opening destination file: /var/singularity/mnt/session/passwd
# DEBUG   [U=43974,P=29082]  copy_file()                               Calling fstat() on source file descriptor: 6
# DEBUG   [U=43974,P=29082]  copy_file()                               Cloning permission string of source to dest
# DEBUG   [U=43974,P=29082]  copy_file()                               Copying file data...
# DEBUG   [U=43974,P=29082]  copy_file()                               Done copying data, closing file pointers
# DEBUG   [U=43974,P=29082]  copy_file()                               Returning copy_file(/var/singularity/mnt/final/etc/passwd, /var/singularity/mnt/session/passwd) = 0
# VERBOSE [U=43974,P=29082]  singularity_runtime_files_passwd()        Creating template passwd file and appending user data: /var/singularity/mnt/session/passwd
# DEBUG   [U=43974,P=29082]  container_file_bind()                     Called file_bind(/var/singularity/mnt/session/passwd, /etc/passwd)
# VERBOSE [U=43974,P=29082]  container_file_bind()                     Binding file '/var/singularity/mnt/session/passwd' to '/var/singularity/mnt/final/etc/passwd'
# DEBUG   [U=43974,P=29082]  envar_set()                               Setting environment variable: 'HOME' = '/global/home/users/myashar'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=29082]  singularity_runtime_files_group()         Called singularity_file_group_create()
# DEBUG   [U=43974,P=29082]  singularity_runtime_files_group()         Checking configuration option: 'config group'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config group, yes)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value config group='yes'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config group, yes) = 1
# VERBOSE [U=43974,P=29082]  singularity_runtime_files_group()         Creating template of /etc/group for containment
# DEBUG   [U=43974,P=29082]  copy_file()                               Called copy_file(/var/singularity/mnt/final/etc/group, /var/singularity/mnt/session/group)
# DEBUG   [U=43974,P=29082]  copy_file()                               Opening source file: /var/singularity/mnt/final/etc/group
# DEBUG   [U=43974,P=29082]  copy_file()                               Opening destination file: /var/singularity/mnt/session/group
# DEBUG   [U=43974,P=29082]  copy_file()                               Calling fstat() on source file descriptor: 6
# DEBUG   [U=43974,P=29082]  copy_file()                               Cloning permission string of source to dest
# DEBUG   [U=43974,P=29082]  copy_file()                               Copying file data...
# DEBUG   [U=43974,P=29082]  copy_file()                               Done copying data, closing file pointers
# DEBUG   [U=43974,P=29082]  copy_file()                               Returning copy_file(/var/singularity/mnt/final/etc/group, /var/singularity/mnt/session/group) = 0
# VERBOSE [U=43974,P=29082]  singularity_runtime_files_group()         Updating group file with user info
# DEBUG   [U=43974,P=29082]  singularity_runtime_files_group()         Getting supplementary group info
# DEBUG   [U=43974,P=29082]  singularity_runtime_files_group()         Skipping duplicate supplementary group
# VERBOSE [U=43974,P=29082]  singularity_runtime_files_group()         Found supplementary group membership in: 600
# VERBOSE [U=43974,P=29082]  singularity_runtime_files_group()         Adding user's supplementary group ('savio') info to template group file
# VERBOSE [U=43974,P=29082]  singularity_runtime_files_group()         Found supplementary group membership in: 6206
# VERBOSE [U=43974,P=29082]  singularity_runtime_files_group()         Adding user's supplementary group ('matlab') info to template group file
# VERBOSE [U=43974,P=29082]  singularity_runtime_files_group()         Found supplementary group membership in: 10000
# VERBOSE [U=43974,P=29082]  singularity_runtime_files_group()         Adding user's supplementary group ('ac_scsguest') info to template group file
# DEBUG   [U=43974,P=29082]  container_file_bind()                     Called file_bind(/var/singularity/mnt/session/group, /etc/group)
# VERBOSE [U=43974,P=29082]  container_file_bind()                     Binding file '/var/singularity/mnt/session/group' to '/var/singularity/mnt/final/etc/group'
# DEBUG   [U=43974,P=29082]  singularity_runtime_files_resolvconf()    Checking configuration option
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Called singularity_config_get_bool(config resolv_conf, yes)
# DEBUG   [U=43974,P=29082]  singularity_config_get_value_impl()       Returning configuration value config resolv_conf='yes'
# DEBUG   [U=43974,P=29082]  singularity_config_get_bool_char_impl()   Return singularity_config_get_bool(config resolv_conf, yes) = 1
# DEBUG   [U=43974,P=29082]  container_file_bind()                     Called file_bind(/etc/resolv.conf, /etc/resolv.conf)
# VERBOSE [U=43974,P=29082]  container_file_bind()                     Binding file '/etc/resolv.conf' to '/var/singularity/mnt/final/etc/resolv.conf'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning value from registry: 'SESSIONDIR' = '/var/singularity/mnt/session'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'CONTAINLIBS'
# VERBOSE [U=43974,P=29082]  singularity_runtime_enter()               Containing all rootfs components
# DEBUG   [U=43974,P=29082]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=29082]      singularity_priv_escalate()               Clearing supplementary GIDs.
# VERBOSE [U=0,P=29082]      singularity_runtime_enter_chroot()        Entering container file system root: /var/singularity/mnt/final
# DEBUG   [U=0,P=29082]      singularity_priv_drop()                   Dropping privileges to UID=43974, GID=501 (4 supplementary GIDs)
# DEBUG   [U=0,P=29082]      singularity_priv_drop()                   Restoring supplementary groups
# DEBUG   [U=43974,P=29082]  singularity_priv_drop()                   Confirming we have correct UID/GID
# DEBUG   [U=43974,P=29082]  singularity_runtime_enter_chroot()        Changing dir to '/' within the new root
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Cloning environment
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Counted 57 environment elements
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'CLEANENV'
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Cleaning environment
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_CHECKPOINT_IMAGE_DIR=/var/slurm/checkpoint
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NODELIST=n0127.savio1
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_NAME=projectname
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURMD_NODENAME=n0127.savio1
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_TOPOLOGY_ADDR=ib-savio.ib-savio-05.n0127.savio1
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: HOSTNAME=n0127.savio1
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_PRIO_PROCESS=0
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NODE_ALIASES=(null)
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SHELL=/bin/bash
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: TERM=xterm-color
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_QOS=savio_normal
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: CLICOLOR=1
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_TOPOLOGY_ADDR_PATTERN=switch.switch.node
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_libexecdir=/usr/libexec
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_libexecdir
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_COMMAND=exec
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_COMMAND
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NNODES=1
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: USER=myashar
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_MESSAGELEVEL=5
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_MESSAGELEVEL
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOBID=4816678
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: JPY_PARENT_PID=425707
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_version=2.6-dist
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_version
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: PAGER=cat
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_TASKS_PER_NODE=20
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: PATH=/bin:/usr/bin:/usr/local/bin:/sbin:/usr/sbin:/usr/local/sbin
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_localstatedir=/var
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_localstatedir
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_WORKING_CLUSTER=brc:master:6817:8192
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_ID=4816678
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_USER=myashar
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: PWD=/global/scratch/myashar/projectname
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITYENV_HISTFILE=
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: MPLBACKEND=module://ipykernel.pylab.backend_inline
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITYENV_PATH=/bin:/sbin:/usr/bin:/usr/sbin:/usr/local/bin:/usr/local/sbin
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_UID=43974
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_NODEID=0
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_SUBMIT_DIR=/global/scratch/myashar/projectname
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: QT_QPA_PLATFORM=offscreen
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_TASK_PID=29006
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_CPUS_ON_NODE=20
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_PROCID=0
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: ENVIRONMENT=BATCH
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_NODELIST=n0127.savio1
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: HOME=/global/home/users/myashar
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SHLVL=2
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_LOCALID=0
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_GID=501
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_CPUS_PER_NODE=20
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_CLUSTER_NAME=brc
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_GTIDS=0
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_SUBMIT_HOST=jupyter.brc
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_PARTITION=savio
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_sysconfdir=/etc
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_sysconfdir
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_bindir=/usr/bin
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_bindir
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_ACCOUNT=ac_scsguest
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_JOB_NUM_NODES=1
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SINGULARITY_IMAGE=/global/scratch/myashar/container/photoscan_1_4_3.simg
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Unsetting environment variable: SINGULARITY_IMAGE
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: GIT_PAGER=cat
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Evaluating envar to clean: SLURM_MEM_PER_NODE=64000
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Transposing environment
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Converting envar 'SINGULARITYENV_HISTFILE' to 'HISTFILE' = '(null)'
# DEBUG   [U=43974,P=29082]  envar_set()                               Unsetting environment variable: HISTFILE
# DEBUG   [U=43974,P=29082]  singularity_runtime_environment()         Converting envar 'SINGULARITYENV_PATH' to 'PATH' = '/bin:/sbin:/usr/bin:/usr/sbin:/usr/local/bin:/usr/local/sbin'
# DEBUG   [U=43974,P=29082]  envar_set()                               Setting environment variable: 'PATH' = '/bin:/sbin:/usr/bin:/usr/sbin:/usr/local/bin:/usr/local/sbin'
# DEBUG   [U=43974,P=29082]  singularity_priv_drop_perm()              Called singularity_priv_drop_perm(void)
# DEBUG   [U=43974,P=29082]  singularity_priv_drop_perm()              Escalating permissison so we can properly drop permission
# DEBUG   [U=43974,P=29082]  singularity_priv_escalate()               Temporarily escalating privileges (U=43974)
# DEBUG   [U=0,P=29082]      singularity_priv_escalate()               Clearing supplementary GIDs.
# DEBUG   [U=0,P=29082]      singularity_priv_drop_perm()              Resetting supplementary groups
# DEBUG   [U=0,P=29082]      singularity_priv_drop_perm()              Dropping to group ID '501'
# DEBUG   [U=0,P=29082]      singularity_priv_drop_perm()              Dropping real and effective privileges to GID = '501'
# DEBUG   [U=0,P=29082]      singularity_priv_drop_perm()              Dropping real and effective privileges to UID = '43974'
# DEBUG   [U=43974,P=29082]  singularity_priv_drop_perm()              Confirming we have correct GID
# DEBUG   [U=43974,P=29082]  singularity_priv_drop_perm()              Confirming we have correct UID
# DEBUG   [U=43974,P=29082]  singularity_priv_check_nonewprivs()       Setting NO_NEW_PRIVS to prevent future privilege escalations.
# DEBUG   [U=43974,P=29082]  singularity_priv_drop_perm()              Finished dropping privileges
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'DAEMON_JOIN'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'PIDNS_ENABLED'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'TARGET_PWD'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'CONTAIN'
# DEBUG   [U=43974,P=29082]  main()                                    Attempting to chdir to CWD: /global/scratch/myashar/projectname
# VERBOSE [U=43974,P=29082]  main()                                    Could not chdir to current dir: /global/scratch/myashar/projectname
# WARNING [U=43974,P=29082]  main()                                    Could not chdir to home: /global/home/users/myashar
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning value from registry: 'COMMAND' = 'exec'
# DEBUG   [U=43974,P=29082]  envar_set()                               Setting environment variable: 'SINGULARITY_CONTAINER' = 'photoscan_1_4_3.simg'
# DEBUG   [U=43974,P=29082]  envar_set()                               Setting environment variable: 'SINGULARITY_NAME' = 'photoscan_1_4_3.simg'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'SHELL'
# DEBUG   [U=43974,P=29082]  envar_set()                               Unsetting environment variable: SINGULARITY_SHELL
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'APPNAME'
# DEBUG   [U=43974,P=29082]  envar_set()                               Unsetting environment variable: SINGULARITY_APPNAME
# DEBUG   [U=43974,P=29082]  fd_cleanup()                              Cleanup file descriptor table
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning NULL on 'UNSHARE_NET'
# DEBUG   [U=43974,P=29082]  singularity_registry_get()                Returning value from registry: 'COMMAND' = 'exec'
# LOG     [U=43974,P=29082]  main()                                    USER=myashar, IMAGE='photoscan_1_4_3.simg', COMMAND='exec'
# DEBUG   [U=43974,P=29082]  action_exec()                             Checking for: /.singularity.d/actions/exec
# VERBOSE [U=43974,P=29082]  action_exec()                             Exec'ing /.singularity.d/actions/exec
# LoadProject: path = /scratch//projectname.psx
# loaded project in 0.807471 sec
# ExportModel: format = ModelFormatOBJ, path = /scratch/projectname.obj

# %% [markdown]
# ## Move the OBJ and associated JPG to Box
# You can download the files from Box and preview using http://3dviewer.net/

# %%
newFolderId = find_folder_id(boxProjectFolder)
upload_folder = client.folder(folder_id=newFolderId).get()
objUploaded = upload_folder.upload(runFolder + modelFile)  
print ("obj file id: ", objUploaded['id'] )
jpgUploaded = upload_folder.upload(runFolder + jpgFile)  
print ("jpeg file id: ", jpgUploaded['id'] )
print("obj file: ", modelFile)
print("jpeg file: ", jpgFile)
# Out:
# find_folder_id folder_name:  myBoxFolderName
# find_folder_id folderlist:  [<Box Folder - 53223729428 (myBoxFolderName)>, <Box Folder - 52394687398 (myBoxFolderName_Test1)>]
# obj file id:  494632908572
# jpeg file id:  494626805638
# obj file:  projectname.obj
# jpeg file:  projectname.jpg

# %% [markdown]
# # Software license
# This software is available under the terms of the Educational Community License, Version 2.0 (ECL 2.0). This software is Copyright 2016 The Regents of the University of California, Berkeley ("Berkeley").
#
# The text of the ECL license is reproduced below.
#
# Educational Community License, Version 2.0
# *************************************
# Copyright 2016 The Regents of the University of California, Berkeley ("Berkeley")
#
# Educational Community License, Version 2.0, April 2007
#
# The Educational Community License version 2.0 ("ECL") consists of the
# Apache 2.0 license, modified to change the scope of the patent grant in
# section 3 to be specific to the needs of the education communities using
# this license. The original Apache 2.0 license can be found at:[http://www.apache.org/licenses/LICENSE-2.0]
